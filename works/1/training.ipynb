# %% [markdown]
# # Reinforcement Learning 2025 - Final Assignment
#
# **Authors:** Amit Ezer, Gal Yaacov Noy.

# %%
# !pip install minigrid gymnasium matplotlib
# Out:
# Requirement already satisfied: minigrid in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: gymnasium in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: matplotlib in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: numpy>=1.18.0 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from minigrid) (2.2.6)
# Requirement already satisfied: pygame>=2.4.0 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from minigrid) (2.6.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from gymnasium) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: pillow>=8 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: six>=1.5 in /home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import os
import random
import numpy as np
import torch
import torch.optim as optim
import torch.nn.functional as F
import matplotlib.pyplot as plt
import minigrid
from collections import deque
from gymnasium.vector import SyncVectorEnv
from shared_utils import device, set_seeds, preprocess, create_env, QNetwork, ActorCritic

set_seeds(42)

print(f"Using device: {device}")
# Out:
# Using device: cuda

# %% [markdown]
# ## DoubleDQN

# %%
class ReplayBuffer:
    """Experience replay buffer for DQN."""
    
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def push(self, transition):
        self.buffer.append(transition)

    def sample(self, batch_size):
        batch = random.sample(self.buffer, batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)
        return (
            torch.stack(states).to(device),
            torch.stack(actions).to(device),
            torch.stack(rewards).to(device),
            torch.stack(next_states).to(device),
            torch.stack(dones).to(device),
        )

    def __len__(self):
        return len(self.buffer)

def select_action(model, state, epsilon, num_actions):
    """
    Selects an action using an epsilon-greedy strategy:
    - With probability `epsilon`, a random action is chosen (exploration).
    - With probability `1 - epsilon`, the action with the highest Q-value is chosen (exploitation).
    """
    if random.random() < epsilon:
        return torch.tensor([random.randint(0, num_actions - 1)], device=device)
    with torch.no_grad():
        q_values = model(state.unsqueeze(0))
        return q_values.argmax(dim=1)

# %%
def train_double_dqn(
    env_name="MiniGrid-Dynamic-Obstacles-16x16-v0",
    num_episodes=5000,
    max_steps=500,             
    batch_size=64,
    gamma=0.99,
    lr=1e-4,
    target_update_freq=1000,
    replay_capacity=50_000,
    epsilon_start=1.0,
    epsilon_end=0.05,
    epsilon_decay=0.9995
):
    env = create_env(env_name)

    num_actions = env.action_space.n
    obs, _ = env.reset()
    input_size = obs.shape[0]

    # Models
    policy_net = QNetwork(num_actions, input_size=input_size).to(device)
    target_net = QNetwork(num_actions, input_size=input_size).to(device)
    target_net.load_state_dict(policy_net.state_dict())
    target_net.eval()

    optimizer = optim.Adam(policy_net.parameters(), lr=lr)
    replay_buffer = ReplayBuffer(capacity=replay_capacity)

    # Tracking
    episode_rewards = []
    episode_lengths = []
    losses = []
    epsilons = []
    global_step = 0
    epsilon = epsilon_start

    print(f"\n{'='*60}")
    print(f"TRAINING DOUBLE DQN ON {env_name.upper()}")
    print(f"{'='*60}")
    print(f"Episodes: {num_episodes} | Batch Size: {batch_size} | Learning Rate: {lr}")
    print(f"Gamma: {gamma} | Target Update: {target_update_freq} | Replay Capacity: {replay_capacity:,}")
    print(f"Epsilon: {epsilon_start} -> {epsilon_end} (decay: {epsilon_decay})")
    print(f"{'='*60}")

    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = preprocess(obs).to(device)
        total_reward = 0
        steps = 0

        for _ in range(max_steps):
            action = select_action(policy_net, state, epsilon, num_actions)

            next_obs, reward, terminated, truncated, _ = env.step(action.item())
            next_state = preprocess(next_obs).to(device)
            done = terminated or truncated

            # Store transition
            transition = (
                state.cpu(),
                torch.tensor([action.item()], dtype=torch.long),
                torch.tensor([reward], dtype=torch.float32),
                next_state.cpu(),
                torch.tensor([done], dtype=torch.float32)
            )
            replay_buffer.push(transition)

            state = next_state
            total_reward += reward
            steps += 1
            global_step += 1

            # Train step
            if len(replay_buffer) >= batch_size:
                states, actions, rewards, next_states, dones = replay_buffer.sample(batch_size)

                # Current Q-values for taken actions
                q_values = policy_net(states).gather(1, actions.view(-1, 1)).squeeze()

                with torch.no_grad():
                    # Double DQN: use policy network to select actions, target network to evaluate
                    next_actions = policy_net(next_states).argmax(dim=1, keepdim=True)
                    next_q_values = target_net(next_states).gather(1, next_actions).squeeze()
                    targets = rewards.squeeze() + gamma * next_q_values * (1 - dones.squeeze())

                loss = F.mse_loss(q_values, targets)
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                losses.append(loss.item())

            # Learn
            if global_step % target_update_freq == 0:
                target_net.load_state_dict(policy_net.state_dict())

            if done:
                break

        episode_rewards.append(total_reward)
        episode_lengths.append(steps)
        epsilons.append(epsilon)

        epsilon = max(epsilon_end, epsilon * epsilon_decay)

        if episode % 100 == 0:
            recent_rewards = np.mean(episode_rewards[-50:]) if len(episode_rewards) >= 50 else np.mean(episode_rewards)
            recent_steps = np.mean(episode_lengths[-50:]) if len(episode_lengths) >= 50 else np.mean(episode_lengths)
            recent_loss = np.mean(losses[-100:]) if len(losses) >= 100 else (np.mean(losses) if losses else 0)
            print(f"[Double DQN] Ep {episode:4d} | Reward: {total_reward:6.2f} | Avg Reward: {recent_rewards:6.2f} | Steps: {steps:3d} | Avg Steps: {recent_steps:5.1f} | Epsilon: {epsilon:.3f} | Loss: {recent_loss:.4f}")

    env.close()

    print(f"\n{'='*60}")
    print(f"TRAINING COMPLETED!")
    print(f"Final Average Reward (last 100 episodes): {np.mean(episode_rewards[-100:]):.3f}")
    print(f"Final Average Steps (last 100 episodes): {np.mean(episode_lengths[-100:]):.1f}")
    print(f"Total Training Steps: {global_step:,}")
    print(f"{'='*60}")

    return {
        "name": "Double DQN",
        "rewards": episode_rewards,
        "steps": episode_lengths,
        "losses": losses,
        "epsilons": epsilons,
        "model": policy_net,
    }

# %% [markdown]
# ## PPO

# %%
def compute_gae(rewards, values, dones, gamma=0.99, lam=0.95):
    """
    Compute Generalized Advantage Estimation (GAE).
    
    Args:
        rewards: list of tensors (num_envs,)
        values: list of tensors (num_envs,) + 1 bootstrap value
        dones: list of tensors (num_envs,)
        gamma: discount factor
        lam: GAE parameter
        
    Returns:
        tensor of shape (T, num_envs)
    """
    advs = []
    gae = torch.zeros_like(rewards[0]).to(device)

    for t in reversed(range(len(rewards))):
        delta = rewards[t] + gamma * values[t + 1] * (1 - dones[t]) - values[t]
        gae = delta + gamma * lam * (1 - dones[t]) * gae
        advs.insert(0, gae)

    return torch.stack(advs).to(device)

# %%
def initialize_model(envs, input_size, lr, device):
    num_actions = envs.single_action_space.n
    model = ActorCritic(num_actions=num_actions, input_size=input_size).to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)
    return model, optimizer


def collect_rollouts(envs, model, states, max_steps, num_envs, gamma, lam, device, finished_episodes, total_episodes):
    # Buffers to store rollout data
    log_probs, actions, rewards, values, dones, state_buffer = [], [], [], [], [], []
    
    # Track rewards and lengths per environment
    ep_rewards = np.zeros(num_envs)
    ep_lengths = np.zeros(num_envs)
    episode_rewards, episode_lengths = [], []

    for _ in range(max_steps):
        with torch.no_grad():
            # Sample action and value from current policy
            action, log_prob, _ = model.get_action(states)
            _, value = model(states)

        next_obs, reward, terminated, truncated, _ = envs.step(action.cpu().numpy())
        done = np.logical_or(terminated, truncated)
        next_states = preprocess(next_obs, target_size=(56, 56)).to(device)

        state_buffer.append(states)
        actions.append(action.to(device))
        log_probs.append(log_prob)
        rewards.append(torch.tensor(reward, dtype=torch.float32).to(device))
        values.append(value.squeeze(-1))
        dones.append(torch.tensor(done, dtype=torch.float32).to(device))

        # Track per-environment episode stats
        for i in range(num_envs):
            ep_rewards[i] += reward[i]
            ep_lengths[i] += 1
            if done[i]:
                episode_rewards.append(ep_rewards[i])
                episode_lengths.append(ep_lengths[i])
                ep_rewards[i] = 0.0
                ep_lengths[i] = 0
                finished_episodes += 1

        states = next_states
        if finished_episodes >= total_episodes:
            break

    # Bootstrap final value for GAE
    with torch.no_grad():
        _, next_value = model(states)
    values.append(next_value.squeeze(-1))

    advantages = compute_gae(rewards, values, dones, gamma, lam)
    advantages = (advantages - advantages.mean()) / (advantages.std() + 1e-8)
    returns = advantages + torch.stack(values[:-1])

    # Flatten training data
    dataset = list(zip(
        torch.cat(state_buffer),
        torch.cat(actions),
        torch.cat(log_probs),
        returns.flatten(),
        advantages.flatten()
    ))

    return dataset, states, episode_rewards, episode_lengths, finished_episodes


def ppo_update(model, optimizer, dataset, update_epochs, minibatch_size, clip_eps, vf_coef, entropy_coef, device, losses, target_kl=None):
    for _ in range(update_epochs):
        random.shuffle(dataset)
        for i in range(0, len(dataset), minibatch_size):
            batch = dataset[i:i + minibatch_size]
            if len(batch) < minibatch_size:
                continue

            b_states, b_actions, b_old_log_probs, b_returns, b_advs = zip(*batch)
            b_states = torch.stack(b_states).to(device)
            b_actions = torch.stack(b_actions).to(device)
            b_old_log_probs = torch.stack(b_old_log_probs).to(device)
            b_returns = torch.stack(b_returns).to(device)
            b_advs = torch.stack(b_advs).to(device)

            # Evaluate model on batch
            log_probs, values, entropy = model.evaluate(b_states, b_actions)
            log_probs = log_probs.squeeze(-1)
            values = values.squeeze(-1)

            # Compute clipped policy loss
            ratio = torch.exp(log_probs - b_old_log_probs.squeeze(-1))
            surr1 = ratio * b_advs.squeeze(-1)
            surr2 = torch.clamp(ratio, 1 - clip_eps, 1 + clip_eps) * b_advs.squeeze(-1)
            policy_loss = -torch.min(surr1, surr2).mean()
            
            # Compute value function loss
            value_loss = F.mse_loss(values, b_returns.squeeze(-1))
            
            # Combine losses
            loss = policy_loss + vf_coef * value_loss - entropy_coef * entropy.mean()
            
            # Calculate KL divergence
            with torch.no_grad():
                log_ratio = log_probs - b_old_log_probs.squeeze(-1)
                approx_kl = ((torch.exp(log_ratio) - 1) - log_ratio).mean().item()

            if target_kl is not None and approx_kl > 1.5 * target_kl:
                print(f"[Early Stop] KL divergence {approx_kl:.4f} exceeded target {target_kl}")
                return  # Early stop PPO update

            optimizer.zero_grad()
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 0.5)
            optimizer.step()
            losses.append(loss.item())


def log_progress(finished_episodes, episode_rewards, episode_lengths, losses):
    recent_rewards = np.mean(episode_rewards[-50:]) if episode_rewards else 0
    recent_steps = np.mean(episode_lengths[-50:]) if episode_lengths else 0
    recent_loss = np.mean(losses[-100:]) if losses else 0
    print(f"[PPO] Ep {finished_episodes:4d} | Avg Reward: {recent_rewards:6.2f} | Avg Steps: {recent_steps:5.1f} | Loss: {recent_loss:.4f}")

def train_ppo(
    env_name="MiniGrid-Dynamic-Obstacles-16x16-v0",
    num_episodes=5000,
    max_steps=500,
    num_envs=16,
    gamma=0.99,
    lam=0.95,
    clip_eps=0.2,
    lr=3e-4,
    update_epochs=4,
    minibatch_size=64,
    entropy_coef=0.01,
    vf_coef=0.5,
    target_kl=None
):
    
    # Create multiple parallel environments for vectorized rollout collection
    envs = SyncVectorEnv([lambda: create_env(env_name) for _ in range(num_envs)])
    
    obs, _ = envs.reset()
    states = preprocess(obs, target_size=(56, 56)).to(device)
    input_size = states.shape[1:][1]
    
    model, optimizer = initialize_model(envs, input_size, lr, device)

    # Tracks
    episode_rewards, episode_lengths, losses = [], [], []
    finished_episodes = 0

    print(f"\n{'='*60}")
    print(f"TRAINING PPO ON {env_name.upper()} WITH {num_envs} ACTORS")
    print(f"{'='*60}")

    while finished_episodes < num_episodes:
        dataset, states, new_rewards, new_lengths, finished_episodes = collect_rollouts(
            envs, model, states, max_steps, num_envs, gamma, lam, device,
            finished_episodes, num_episodes
        )

        episode_rewards.extend(new_rewards)
        episode_lengths.extend(new_lengths)

        ppo_update(model, optimizer, dataset, update_epochs, minibatch_size,
                   clip_eps, vf_coef, entropy_coef, device, losses, target_kl)

        log_progress(finished_episodes, episode_rewards, episode_lengths, losses)

    envs.close()
    print(f"\n{'='*60}\nTRAINING COMPLETED!\n{'='*60}")

    return {
        "name": "PPO",
        "rewards": episode_rewards,
        "steps": episode_lengths,
        "losses": losses,
        "model": model,
    }

# %%
EXPERIMENTS = {
    'Double DQN': train_double_dqn,
    'PPO': train_ppo
}

# %%
def export_model(model, name, env_name, models_dir="models"):
    """Export trained model to a file."""
    env_suffix = env_name.split('-')[-2].replace('v0', '').strip()
    model_dir = os.path.join(models_dir, env_suffix)
    
    os.makedirs(model_dir, exist_ok=True)
    
    filename = f"{name.replace(' ', '_').lower()}_model.pth"
    model_path = os.path.join(model_dir, filename)
    
    torch.save(model.state_dict(), model_path)
    print(f"Model exported to: {model_path}")
    return model_path

def plot_training_results(logs, window=50, title="Training Results"):
    """Plot training rewards, steps, losses and (optionally) epsilon decay."""

    def moving_average(data, window):
        if len(data) < window:
            return data
        return np.convolve(data, np.ones(window)/window, mode='valid')

    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle(title, fontsize=16, fontweight='bold')

    # Episode Rewards
    axes[0, 0].plot(logs["rewards"], alpha=0.3, label="Raw", color='blue')
    if len(logs["rewards"]) >= window:
        smooth_rewards = moving_average(logs["rewards"], window)
        axes[0, 0].plot(range(window-1, len(logs["rewards"])), smooth_rewards,
                       label=f"Moving Avg ({window})", linewidth=2, color='red')
    axes[0, 0].set_title("Episode Rewards")
    axes[0, 0].set_xlabel("Episode")
    axes[0, 0].set_ylabel("Reward")
    axes[0, 0].legend()
    axes[0, 0].grid(alpha=0.3)

    # Episode Lengths
    axes[0, 1].plot(logs["steps"], alpha=0.3, label="Raw", color='green')
    if len(logs["steps"]) >= window:
        smooth_steps = moving_average(logs["steps"], window)
        axes[0, 1].plot(range(window-1, len(logs["steps"])), smooth_steps,
                       label=f"Moving Avg ({window})", linewidth=2, color='orange')
    axes[0, 1].set_title("Episode Length")
    axes[0, 1].set_xlabel("Episode")
    axes[0, 1].set_ylabel("Steps")
    axes[0, 1].legend()
    axes[0, 1].grid(alpha=0.3)

    # Loss
    if logs.get("losses"):
        axes[1, 0].plot(logs["losses"], alpha=0.6, color='purple')
        if len(logs["losses"]) >= window:
            smooth_loss = moving_average(logs["losses"], window)
            axes[1, 0].plot(range(window-1, len(logs["losses"])), smooth_loss,
                           label=f"Moving Avg ({window})", linewidth=2, color='red')
            axes[1, 0].legend()
        axes[1, 0].set_title("Training Loss")
        axes[1, 0].set_xlabel("Training Step")
        axes[1, 0].set_ylabel("Loss")
        axes[1, 0].grid(alpha=0.3)

    # Epsilon (if available)
    if "epsilons" in logs and logs["epsilons"]:
        axes[1, 1].plot(logs["epsilons"], color='brown', linewidth=2)
        axes[1, 1].set_title("Exploration Rate (Epsilon)")
        axes[1, 1].set_xlabel("Episode")
        axes[1, 1].set_ylabel("Epsilon")
        axes[1, 1].grid(alpha=0.3)
    else:
        axes[1, 1].axis("off")

    plt.tight_layout()
    plt.show()

def print_performance_summary(logs):
    """Print performance summary."""
    print(f"\n{'='*60}")
    print(f"PERFORMANCE SUMMARY - {logs['name'].upper()}")
    print(f"{'='*60}")

    final_rewards = np.mean(logs["rewards"][-100:]) if len(logs["rewards"]) >= 100 else np.mean(logs["rewards"])
    best_rewards = max([np.mean(logs["rewards"][i:i+100]) for i in range(len(logs["rewards"])-99)]) if len(logs["rewards"]) >= 100 else max(logs["rewards"])
    final_steps = np.mean(logs["steps"][-100:]) if len(logs["steps"]) >= 100 else np.mean(logs["steps"])
    final_loss = np.mean(logs["losses"][-1000:]) if len(logs["losses"]) >= 1000 else (np.mean(logs["losses"]) if logs["losses"] else 0)

    print(f"Final Performance (last 100 episodes):")
    print(f"  Average Reward: {final_rewards:.3f}")
    print(f"  Average Steps: {final_steps:.1f}")
    print(f"  Training Loss: {final_loss:.4f}")
    print(f"\nBest Performance:")
    print(f"  Best 100-episode Average Reward: {best_rewards:.3f}")
    print(f"  Total Episodes: {len(logs['rewards'])}")
    print(f"  Total Training Steps: {len(logs['losses']):,}")
    print(f"{'='*60}")

# %%
def run_experiment(name, env_name="MiniGrid-Dynamic-Obstacles-16x16-v0", log_and_export=True, **kwargs):
    """Run complete experiment: train agent, analyze, and plot."""
    # Train agent
    out = EXPERIMENTS[name](env_name=env_name, **kwargs)

    if log_and_export:
        # Analyze and visualize
        print_performance_summary(out)
        plot_training_results(out, title=f"{name} Training Results")
        export_model(out["model"], name, env_name)

    return out

# %%
# dqn_logs = run_experiment('Double DQN', env_name="MiniGrid-Dynamic-Obstacles-6x6-v0", num_episodes=1500, max_steps=100, epsilon_decay=0.995)

# %%
import itertools
import random
import time
import csv

# Define hyperparameter grid
lr_list = [1e-3, 3e-4, 1e-4]
entropy_coef_list = [0.01, 0.0]
max_steps_list = [250, 500]
update_epochs_list = [4, 8, 16]

# Sample 10 random combinations
combinations = random.sample(
    list(itertools.product(lr_list, entropy_coef_list, max_steps_list, update_epochs_list)), 10
)

print(f"\nRandom Search: Running {len(combinations)} sampled configurations")

results = []
for i, (lr, entropy_coef, max_steps, update_epochs) in enumerate(combinations):
    print(f"\n[{i+1}/10] PPO with lr={lr}, entropy={entropy_coef}, steps={max_steps}, epochs={update_epochs}")

    try:
        ppo_logs = run_experiment(
            'PPO',
            env_name="MiniGrid-Dynamic-Obstacles-16x16-v0",
            num_episodes=3000,
            log_and_export=False,
            max_steps=max_steps,
            num_envs=16,
            lr=lr,
            update_epochs=update_epochs,
            minibatch_size=64,
            entropy_coef=entropy_coef,
        )

        avg_reward = sum(ppo_logs["rewards"][-100:]) / min(100, len(ppo_logs["rewards"]))
        avg_steps = sum(ppo_logs["steps"][-100:]) / min(100, len(ppo_logs["steps"]))

        results.append([lr, entropy_coef, max_steps, update_epochs, round(avg_reward, 4), round(avg_steps, 2)])
        print("✅ Success")

    except Exception as e:
        print(f"❌ Failed: {e}")
        time.sleep(1)

# Sort results by descending reward and write to CSV
results.sort(key=lambda row: row[4], reverse=True)
with open("ppo_runs_summary.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["lr", "entropy_coef", "max_steps", "update_epochs", "avg_reward_last_100", "avg_steps_last_100"])
    writer.writerows(results)

print(f"\n{'='*60}\nSaved summary to ppo_runs_summary.csv\n{'='*60}")
# Out:
# Random Search: Running 10 sampled configurations
#
# [1/10] PPO with lr=0.001, entropy=0.0, steps=250, epochs=8
#
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  289 | Avg Reward:  -1.00 | Avg Steps:  14.8 | Loss: 0.4003
# [PPO] Ep  483 | Avg Reward:  -1.00 | Avg Steps:  17.8 | Loss: 0.4117
# [PPO] Ep  563 | Avg Reward:  -1.00 | Avg Steps:  39.6 | Loss: 0.4306
# [PPO] Ep  595 | Avg Reward:  -1.00 | Avg Steps:  53.6 | Loss: 0.3093
# [PPO] Ep  597 | Avg Reward:  -1.00 | Avg Steps:  59.8 | Loss: 0.0362
# [PPO] Ep  662 | Avg Reward:  -1.00 | Avg Steps:  48.4 | Loss: 0.0973
# [PPO] Ep  697 | Avg Reward:  -1.00 | Avg Steps:  61.4 | Loss: 0.2880
# [PPO] Ep  707 | Avg Reward:  -1.00 | Avg Steps:  64.1 | Loss: 0.0828
# [PPO] Ep  708 | Avg Reward:  -1.00 | Avg Steps:  63.6 | Loss: 0.0241
# [PPO] Ep  713 | Avg Reward:  -0.98 | Avg Steps:  70.4 | Loss: 0.0081
# [PPO] Ep  719 | Avg Reward:  -0.88 | Avg Steps:  88.8 | Loss: 0.0188
# [PPO] Ep  724 | Avg Reward:  -0.78 | Avg Steps: 101.2 | Loss: 0.0032
# [PPO] Ep  767 | Avg Reward:  -0.86 | Avg Steps:  74.5 | Loss: 0.1454
# [PPO] Ep  800 | Avg Reward:  -1.00 | Avg Steps:  66.9 | Loss: 0.1536
# [PPO] Ep  806 | Avg Reward:  -0.96 | Avg Steps:  77.4 | Loss: 0.0215
# [PPO] Ep  824 | Avg Reward:  -0.96 | Avg Steps:  83.0 | Loss: 0.0603
# [PPO] Ep  831 | Avg Reward:  -0.94 | Avg Steps:  84.7 | Loss: 0.0382
# [PPO] Ep  835 | Avg Reward:  -0.92 | Avg Steps:  87.0 | Loss: 0.0011
# [PPO] Ep  837 | Avg Reward:  -0.92 | Avg Steps:  93.6 | Loss: 0.0039
# [PPO] Ep  847 | Avg Reward:  -0.84 | Avg Steps: 103.0 | Loss: 0.0112
# [PPO] Ep  859 | Avg Reward:  -0.86 | Avg Steps: 109.1 | Loss: 0.0603
# [PPO] Ep  866 | Avg Reward:  -0.84 | Avg Steps: 109.0 | Loss: 0.0088
# [PPO] Ep  880 | Avg Reward:  -0.81 | Avg Steps: 122.1 | Loss: 0.0439
# [PPO] Ep  887 | Avg Reward:  -0.83 | Avg Steps: 119.9 | Loss: 0.0726
# [PPO] Ep  922 | Avg Reward:  -0.98 | Avg Steps:  92.3 | Loss: 0.0837
# [PPO] Ep  929 | Avg Reward:  -0.98 | Avg Steps:  86.1 | Loss: 0.0201
# [PPO] Ep  940 | Avg Reward:  -1.00 | Avg Steps:  93.4 | Loss: 0.0150
# [PPO] Ep  946 | Avg Reward:  -1.00 | Avg Steps: 108.9 | Loss: -0.0039
# [PPO] Ep  954 | Avg Reward:  -0.94 | Avg Steps: 115.9 | Loss: -0.0131
# [PPO] Ep  959 | Avg Reward:  -0.92 | Avg Steps: 121.9 | Loss: 0.0020
# [PPO] Ep  966 | Avg Reward:  -0.88 | Avg Steps: 124.7 | Loss: -0.0148
# [PPO] Ep  970 | Avg Reward:  -0.84 | Avg Steps: 127.0 | Loss: -0.0027
# [PPO] Ep  988 | Avg Reward:  -0.78 | Avg Steps: 111.8 | Loss: 0.0159
# [PPO] Ep  991 | Avg Reward:  -0.70 | Avg Steps: 110.4 | Loss: -0.0164
# [PPO] Ep 1001 | Avg Reward:  -0.70 | Avg Steps:  99.7 | Loss: -0.0047
# [PPO] Ep 1003 | Avg Reward:  -0.70 | Avg Steps:  98.7 | Loss: -0.0253
# [PPO] Ep 1014 | Avg Reward:  -0.70 | Avg Steps:  96.2 | Loss: 0.0025
# [PPO] Ep 1021 | Avg Reward:  -0.68 | Avg Steps:  92.8 | Loss: -0.0143
# [PPO] Ep 1029 | Avg Reward:  -0.66 | Avg Steps: 102.7 | Loss: -0.0159
# [PPO] Ep 1033 | Avg Reward:  -0.62 | Avg Steps: 105.1 | Loss: -0.0188
# [PPO] Ep 1039 | Avg Reward:  -0.60 | Avg Steps: 108.3 | Loss: -0.0201
# [PPO] Ep 1051 | Avg Reward:  -0.52 | Avg Steps: 119.8 | Loss: -0.0028
# [PPO] Ep 1061 | Avg Reward:  -0.52 | Avg Steps: 127.5 | Loss: 0.0160
# [PPO] Ep 1064 | Avg Reward:  -0.46 | Avg Steps: 126.8 | Loss: -0.0327
# [PPO] Ep 1072 | Avg Reward:  -0.36 | Avg Steps: 129.7 | Loss: -0.0410
# [PPO] Ep 1136 | Avg Reward:  -1.00 | Avg Steps:  49.5 | Loss: 0.0322
# [PPO] Ep 1160 | Avg Reward:  -0.93 | Avg Steps:  52.0 | Loss: 0.0668
# [PPO] Ep 1174 | Avg Reward:  -0.90 | Avg Steps:  63.1 | Loss: 0.0081
# [PPO] Ep 1178 | Avg Reward:  -0.86 | Avg Steps:  67.5 | Loss: -0.0223
# [PPO] Ep 1190 | Avg Reward:  -0.84 | Avg Steps:  83.2 | Loss: -0.0062
# [PPO] Ep 1193 | Avg Reward:  -0.82 | Avg Steps:  91.6 | Loss: -0.0283
# [PPO] Ep 1214 | Avg Reward:  -0.80 | Avg Steps: 105.6 | Loss: 0.0181
# [PPO] Ep 1220 | Avg Reward:  -0.84 | Avg Steps: 104.5 | Loss: 0.0101
# [PPO] Ep 1225 | Avg Reward:  -0.82 | Avg Steps: 109.5 | Loss: -0.0149
# [PPO] Ep 1230 | Avg Reward:  -0.85 | Avg Steps: 114.1 | Loss: -0.0094
# [PPO] Ep 1237 | Avg Reward:  -0.81 | Avg Steps: 117.7 | Loss: -0.0244
# [PPO] Ep 1242 | Avg Reward:  -0.79 | Avg Steps: 115.4 | Loss: -0.0284
# [PPO] Ep 1282 | Avg Reward:  -0.90 | Avg Steps:  56.4 | Loss: 0.0138
# [PPO] Ep 1314 | Avg Reward:  -1.00 | Avg Steps:  53.7 | Loss: 0.1252
# [PPO] Ep 1319 | Avg Reward:  -1.00 | Avg Steps:  56.4 | Loss: 0.0174
# [PPO] Ep 1320 | Avg Reward:  -1.00 | Avg Steps:  60.1 | Loss: -0.0241
# [PPO] Ep 1329 | Avg Reward:  -0.94 | Avg Steps:  71.3 | Loss: -0.0094
# [PPO] Ep 1336 | Avg Reward:  -0.83 | Avg Steps:  78.6 | Loss: -0.0394
# [PPO] Ep 1344 | Avg Reward:  -0.73 | Avg Steps:  83.3 | Loss: 0.0065
# [PPO] Ep 1348 | Avg Reward:  -0.73 | Avg Steps:  91.0 | Loss: -0.0142
# [PPO] Ep 1357 | Avg Reward:  -0.65 | Avg Steps:  97.8 | Loss: -0.0247
# [PPO] Ep 1365 | Avg Reward:  -0.57 | Avg Steps: 101.1 | Loss: -0.0047
# [PPO] Ep 1368 | Avg Reward:  -0.53 | Avg Steps: 103.2 | Loss: -0.0321
# [PPO] Ep 1371 | Avg Reward:  -0.53 | Avg Steps: 101.4 | Loss: -0.0238
# [PPO] Ep 1375 | Avg Reward:  -0.47 | Avg Steps: 107.5 | Loss: -0.0231
# [PPO] Ep 1386 | Avg Reward:  -0.51 | Avg Steps:  96.4 | Loss: 0.0177
# [PPO] Ep 1394 | Avg Reward:  -0.55 | Avg Steps:  99.1 | Loss: -0.0356
# [PPO] Ep 1399 | Avg Reward:  -0.53 | Avg Steps:  94.4 | Loss: -0.0375
# [PPO] Ep 1402 | Avg Reward:  -0.51 | Avg Steps: 102.1 | Loss: -0.0306
# [PPO] Ep 1408 | Avg Reward:  -0.49 | Avg Steps: 103.6 | Loss: -0.0229
# [PPO] Ep 1439 | Avg Reward:  -0.75 | Avg Steps:  69.3 | Loss: 0.0318
# [PPO] Ep 1478 | Avg Reward:  -0.94 | Avg Steps:  52.0 | Loss: 0.0825
# [PPO] Ep 1481 | Avg Reward:  -0.96 | Avg Steps:  55.2 | Loss: -0.0195
# [PPO] Ep 1484 | Avg Reward:  -0.96 | Avg Steps:  53.9 | Loss: -0.0242
# [PPO] Ep 1486 | Avg Reward:  -0.92 | Avg Steps:  58.0 | Loss: -0.0406
# [PPO] Ep 1503 | Avg Reward:  -0.84 | Avg Steps:  77.4 | Loss: 0.0045
# [PPO] Ep 1514 | Avg Reward:  -0.77 | Avg Steps:  90.6 | Loss: 0.0020
# [PPO] Ep 1516 | Avg Reward:  -0.73 | Avg Steps:  86.5 | Loss: -0.0258
# [PPO] Ep 1526 | Avg Reward:  -0.73 | Avg Steps:  95.2 | Loss: -0.0241
# [PPO] Ep 1584 | Avg Reward:  -1.00 | Avg Steps:  37.4 | Loss: 0.0807
# [PPO] Ep 1595 | Avg Reward:  -0.98 | Avg Steps:  50.4 | Loss: 0.0309
# [PPO] Ep 1600 | Avg Reward:  -0.96 | Avg Steps:  51.6 | Loss: -0.0177
# [PPO] Ep 1602 | Avg Reward:  -0.94 | Avg Steps:  55.3 | Loss: -0.0273
# [PPO] Ep 1611 | Avg Reward:  -0.88 | Avg Steps:  71.9 | Loss: -0.0092
# [PPO] Ep 1613 | Avg Reward:  -0.84 | Avg Steps:  77.8 | Loss: -0.0500
# [PPO] Ep 1627 | Avg Reward:  -0.76 | Avg Steps:  90.3 | Loss: -0.0074
# [PPO] Ep 1631 | Avg Reward:  -0.74 | Avg Steps:  95.5 | Loss: -0.0185
# [PPO] Ep 1663 | Avg Reward:  -0.84 | Avg Steps:  58.2 | Loss: 0.0139
# [PPO] Ep 1674 | Avg Reward:  -0.88 | Avg Steps:  58.5 | Loss: 0.0485
# [PPO] Ep 1679 | Avg Reward:  -0.88 | Avg Steps:  56.8 | Loss: -0.0392
# [PPO] Ep 1682 | Avg Reward:  -0.88 | Avg Steps:  59.0 | Loss: -0.0202
# [PPO] Ep 1691 | Avg Reward:  -0.78 | Avg Steps:  81.2 | Loss: -0.0256
# [PPO] Ep 1696 | Avg Reward:  -0.78 | Avg Steps:  89.6 | Loss: -0.0307
# [PPO] Ep 1700 | Avg Reward:  -0.76 | Avg Steps:  95.7 | Loss: -0.0251
# [PPO] Ep 1708 | Avg Reward:  -0.72 | Avg Steps: 106.3 | Loss: -0.0136
# [PPO] Ep 1724 | Avg Reward:  -0.66 | Avg Steps: 110.7 | Loss: -0.0042
# [PPO] Ep 1733 | Avg Reward:  -0.66 | Avg Steps: 109.9 | Loss: -0.0100
# [PPO] Ep 1748 | Avg Reward:  -0.80 | Avg Steps: 101.6 | Loss: 0.0534
# [PPO] Ep 1754 | Avg Reward:  -0.82 | Avg Steps: 100.5 | Loss: -0.0241
# [PPO] Ep 1765 | Avg Reward:  -0.80 | Avg Steps:  97.7 | Loss: -0.0046
# [PPO] Ep 1770 | Avg Reward:  -0.80 | Avg Steps:  96.5 | Loss: -0.0199
# [PPO] Ep 1782 | Avg Reward:  -0.80 | Avg Steps: 104.4 | Loss: -0.0058
# [PPO] Ep 1787 | Avg Reward:  -0.78 | Avg Steps: 112.8 | Loss: -0.0201
# [PPO] Ep 1823 | Avg Reward:  -0.87 | Avg Steps:  79.3 | Loss: 0.0388
# [PPO] Ep 1851 | Avg Reward:  -0.96 | Avg Steps:  65.3 | Loss: 0.0684
# [PPO] Ep 1866 | Avg Reward:  -0.96 | Avg Steps:  73.7 | Loss: 0.0103
# [PPO] Ep 1869 | Avg Reward:  -0.96 | Avg Steps:  78.4 | Loss: -0.0148
# [PPO] Ep 1875 | Avg Reward:  -0.94 | Avg Steps:  91.4 | Loss: -0.0199
# [PPO] Ep 1885 | Avg Reward:  -0.92 | Avg Steps: 100.9 | Loss: -0.0014
# [PPO] Ep 1892 | Avg Reward:  -0.88 | Avg Steps: 106.1 | Loss: -0.0004
# [PPO] Ep 1899 | Avg Reward:  -0.84 | Avg Steps: 110.8 | Loss: -0.0069
# [PPO] Ep 1903 | Avg Reward:  -0.84 | Avg Steps: 121.4 | Loss: 0.0044
# [PPO] Ep 1910 | Avg Reward:  -0.74 | Avg Steps: 118.9 | Loss: -0.0145
# [PPO] Ep 1920 | Avg Reward:  -0.72 | Avg Steps: 111.6 | Loss: -0.0043
# [PPO] Ep 1924 | Avg Reward:  -0.65 | Avg Steps: 112.2 | Loss: -0.0198
# [PPO] Ep 1933 | Avg Reward:  -0.62 | Avg Steps: 115.0 | Loss: 0.0013
# [PPO] Ep 1939 | Avg Reward:  -0.64 | Avg Steps: 114.6 | Loss: -0.0135
# [PPO] Ep 1949 | Avg Reward:  -0.68 | Avg Steps: 103.7 | Loss: -0.0065
# [PPO] Ep 1952 | Avg Reward:  -0.62 | Avg Steps: 105.2 | Loss: -0.0226
# [PPO] Ep 1960 | Avg Reward:  -0.64 | Avg Steps: 119.7 | Loss: -0.0345
# [PPO] Ep 1965 | Avg Reward:  -0.66 | Avg Steps: 123.3 | Loss: 0.0092
# [PPO] Ep 1970 | Avg Reward:  -0.57 | Avg Steps: 114.9 | Loss: -0.0259
# [PPO] Ep 1975 | Avg Reward:  -0.60 | Avg Steps: 117.2 | Loss: -0.0236
# [PPO] Ep 1980 | Avg Reward:  -0.63 | Avg Steps: 124.8 | Loss: -0.0435
# [PPO] Ep 1987 | Avg Reward:  -0.57 | Avg Steps: 124.0 | Loss: -0.0101
# [PPO] Ep 1994 | Avg Reward:  -0.53 | Avg Steps: 125.9 | Loss: -0.0296
# [PPO] Ep 1998 | Avg Reward:  -0.53 | Avg Steps: 122.6 | Loss: 0.0036
# [PPO] Ep 2003 | Avg Reward:  -0.53 | Avg Steps: 124.1 | Loss: -0.0365
# [PPO] Ep 2008 | Avg Reward:  -0.55 | Avg Steps: 121.6 | Loss: 0.0006
# [PPO] Ep 2013 | Avg Reward:  -0.51 | Avg Steps: 119.8 | Loss: -0.0236
# [PPO] Ep 2043 | Avg Reward:  -0.80 | Avg Steps:  82.7 | Loss: 0.1063
# [PPO] Ep 2081 | Avg Reward:  -0.96 | Avg Steps:  51.4 | Loss: 0.1094
# [PPO] Ep 2089 | Avg Reward:  -0.96 | Avg Steps:  58.9 | Loss: 0.0401
# [PPO] Ep 2097 | Avg Reward:  -0.96 | Avg Steps:  60.8 | Loss: -0.0041
# [PPO] Ep 2103 | Avg Reward:  -0.96 | Avg Steps:  74.9 | Loss: 0.0319
# [PPO] Ep 2111 | Avg Reward:  -0.86 | Avg Steps:  84.4 | Loss: -0.0314
# [PPO] Ep 2118 | Avg Reward:  -0.82 | Avg Steps:  97.8 | Loss: 0.0021
# [PPO] Ep 2122 | Avg Reward:  -0.80 | Avg Steps: 100.2 | Loss: -0.0329
# [PPO] Ep 2130 | Avg Reward:  -0.74 | Avg Steps: 108.6 | Loss: -0.0004
# [PPO] Ep 2134 | Avg Reward:  -0.72 | Avg Steps: 115.7 | Loss: -0.0073
# [PPO] Ep 2151 | Avg Reward:  -0.74 | Avg Steps: 116.6 | Loss: 0.0451
# [PPO] Ep 2161 | Avg Reward:  -0.80 | Avg Steps: 106.4 | Loss: 0.0058
# [PPO] Ep 2167 | Avg Reward:  -0.84 | Avg Steps: 101.9 | Loss: 0.0223
# [PPO] Ep 2174 | Avg Reward:  -0.86 | Avg Steps: 105.1 | Loss: 0.0077
# [PPO] Ep 2182 | Avg Reward:  -0.86 | Avg Steps: 102.7 | Loss: -0.0014
# [PPO] Ep 2190 | Avg Reward:  -0.84 | Avg Steps: 102.0 | Loss: 0.0182
# [PPO] Ep 2198 | Avg Reward:  -0.82 | Avg Steps: 107.5 | Loss: 0.0055
# [PPO] Ep 2206 | Avg Reward:  -0.84 | Avg Steps: 112.6 | Loss: 0.0197
# [PPO] Ep 2208 | Avg Reward:  -0.82 | Avg Steps: 116.2 | Loss: 0.0071
# [PPO] Ep 2214 | Avg Reward:  -0.78 | Avg Steps: 114.8 | Loss: -0.0199
# [PPO] Ep 2221 | Avg Reward:  -0.74 | Avg Steps: 126.3 | Loss: 0.0061
# [PPO] Ep 2228 | Avg Reward:  -0.68 | Avg Steps: 120.4 | Loss: -0.0114
# [PPO] Ep 2236 | Avg Reward:  -0.70 | Avg Steps: 115.8 | Loss: 0.0020
# [PPO] Ep 2243 | Avg Reward:  -0.62 | Avg Steps: 112.7 | Loss: -0.0176
# [PPO] Ep 2250 | Avg Reward:  -0.62 | Avg Steps: 115.5 | Loss: 0.0212
# [PPO] Ep 2254 | Avg Reward:  -0.60 | Avg Steps: 116.1 | Loss: -0.0157
# [PPO] Ep 2260 | Avg Reward:  -0.62 | Avg Steps: 114.9 | Loss: -0.0120
# [PPO] Ep 2267 | Avg Reward:  -0.56 | Avg Steps: 116.1 | Loss: -0.0057
# [PPO] Ep 2277 | Avg Reward:  -0.57 | Avg Steps: 117.9 | Loss: -0.0049
# [PPO] Ep 2283 | Avg Reward:  -0.55 | Avg Steps: 130.2 | Loss: 0.0012
# [PPO] Ep 2293 | Avg Reward:  -0.62 | Avg Steps: 124.9 | Loss: -0.0068
# [PPO] Ep 2298 | Avg Reward:  -0.62 | Avg Steps: 126.5 | Loss: 0.0193
# [PPO] Ep 2305 | Avg Reward:  -0.62 | Avg Steps: 118.1 | Loss: -0.0181
# [PPO] Ep 2317 | Avg Reward:  -0.67 | Avg Steps: 110.0 | Loss: 0.0924
# [PPO] Ep 2324 | Avg Reward:  -0.65 | Avg Steps: 113.6 | Loss: -0.0077
# [PPO] Ep 2334 | Avg Reward:  -0.71 | Avg Steps:  99.2 | Loss: 0.0455
# [PPO] Ep 2342 | Avg Reward:  -0.71 | Avg Steps:  97.1 | Loss: -0.0153
# [PPO] Ep 2346 | Avg Reward:  -0.63 | Avg Steps:  98.0 | Loss: -0.0154
# [PPO] Ep 2351 | Avg Reward:  -0.65 | Avg Steps: 104.9 | Loss: -0.0154
# [PPO] Ep 2361 | Avg Reward:  -0.64 | Avg Steps: 109.1 | Loss: 0.0362
# [PPO] Ep 2370 | Avg Reward:  -0.68 | Avg Steps: 100.0 | Loss: 0.0153
# [PPO] Ep 2375 | Avg Reward:  -0.73 | Avg Steps:  95.2 | Loss: 0.0140
# [PPO] Ep 2385 | Avg Reward:  -0.72 | Avg Steps:  97.9 | Loss: -0.0010
# [PPO] Ep 2409 | Avg Reward:  -0.86 | Avg Steps:  89.3 | Loss: 0.0937
# [PPO] Ep 2421 | Avg Reward:  -0.86 | Avg Steps:  89.5 | Loss: 0.0372
# [PPO] Ep 2431 | Avg Reward:  -0.88 | Avg Steps:  94.9 | Loss: 0.0216
# [PPO] Ep 2438 | Avg Reward:  -0.79 | Avg Steps:  96.5 | Loss: 0.0143
# [PPO] Ep 2450 | Avg Reward:  -0.81 | Avg Steps: 100.1 | Loss: 0.0500
# [PPO] Ep 2463 | Avg Reward:  -0.77 | Avg Steps: 105.4 | Loss: 0.0307
# [PPO] Ep 2467 | Avg Reward:  -0.77 | Avg Steps: 112.2 | Loss: 0.0000
# [PPO] Ep 2473 | Avg Reward:  -0.77 | Avg Steps: 117.7 | Loss: 0.0167
# [PPO] Ep 2489 | Avg Reward:  -0.84 | Avg Steps: 115.6 | Loss: 0.1109
# [PPO] Ep 2503 | Avg Reward:  -0.84 | Avg Steps: 109.5 | Loss: 0.0423
# [PPO] Ep 2506 | Avg Reward:  -0.84 | Avg Steps: 117.6 | Loss: -0.0131
# [PPO] Ep 2514 | Avg Reward:  -0.90 | Avg Steps: 114.8 | Loss: 0.0190
# [PPO] Ep 2521 | Avg Reward:  -0.85 | Avg Steps: 110.1 | Loss: 0.0390
# [PPO] Ep 2529 | Avg Reward:  -0.81 | Avg Steps: 112.1 | Loss: 0.0195
# [PPO] Ep 2534 | Avg Reward:  -0.81 | Avg Steps: 116.8 | Loss: -0.0001
# [PPO] Ep 2541 | Avg Reward:  -0.77 | Avg Steps: 121.8 | Loss: 0.0041
# [PPO] Ep 2547 | Avg Reward:  -0.79 | Avg Steps: 129.3 | Loss: 0.0015
# [PPO] Ep 2559 | Avg Reward:  -0.71 | Avg Steps: 118.1 | Loss: 0.0031
# [PPO] Ep 2564 | Avg Reward:  -0.69 | Avg Steps: 118.2 | Loss: -0.0038
# [PPO] Ep 2569 | Avg Reward:  -0.70 | Avg Steps: 122.0 | Loss: 0.0180
# [PPO] Ep 2572 | Avg Reward:  -0.72 | Avg Steps: 118.2 | Loss: -0.0185
# [PPO] Ep 2580 | Avg Reward:  -0.64 | Avg Steps: 113.9 | Loss: 0.0079
# [PPO] Ep 2589 | Avg Reward:  -0.62 | Avg Steps: 106.9 | Loss: 0.0546
# [PPO] Ep 2592 | Avg Reward:  -0.62 | Avg Steps: 106.0 | Loss: 0.0093
# [PPO] Ep 2596 | Avg Reward:  -0.60 | Avg Steps: 106.2 | Loss: 0.0029
# [PPO] Ep 2605 | Avg Reward:  -0.54 | Avg Steps: 110.8 | Loss: 0.0188
# [PPO] Ep 2612 | Avg Reward:  -0.54 | Avg Steps: 107.1 | Loss: -0.0101
# [PPO] Ep 2618 | Avg Reward:  -0.57 | Avg Steps: 117.3 | Loss: 0.0437
# [PPO] Ep 2623 | Avg Reward:  -0.57 | Avg Steps: 119.8 | Loss: 0.0114
# [PPO] Ep 2632 | Avg Reward:  -0.63 | Avg Steps: 120.6 | Loss: 0.0571
# [PPO] Ep 2634 | Avg Reward:  -0.61 | Avg Steps: 124.5 | Loss: -0.0027
# [PPO] Ep 2643 | Avg Reward:  -0.62 | Avg Steps: 125.1 | Loss: 0.0108
# [PPO] Ep 2653 | Avg Reward:  -0.62 | Avg Steps: 127.4 | Loss: 0.0090
# [PPO] Ep 2656 | Avg Reward:  -0.62 | Avg Steps: 129.3 | Loss: 0.0007
# [PPO] Ep 2660 | Avg Reward:  -0.64 | Avg Steps: 134.9 | Loss: 0.0422
# [PPO] Ep 2668 | Avg Reward:  -0.58 | Avg Steps: 130.0 | Loss: -0.0065
# [PPO] Ep 2673 | Avg Reward:  -0.58 | Avg Steps: 123.3 | Loss: 0.0333
# [PPO] Ep 2686 | Avg Reward:  -0.65 | Avg Steps: 123.7 | Loss: 0.0384
# [PPO] Ep 2687 | Avg Reward:  -0.62 | Avg Steps: 125.4 | Loss: -0.0014
# [PPO] Ep 2704 | Avg Reward:  -0.66 | Avg Steps: 124.8 | Loss: 0.0592
# [PPO] Ep 2711 | Avg Reward:  -0.72 | Avg Steps: 112.7 | Loss: 0.0133
# [PPO] Ep 2720 | Avg Reward:  -0.78 | Avg Steps: 107.8 | Loss: 0.0191
# [PPO] Ep 2732 | Avg Reward:  -0.83 | Avg Steps: 105.4 | Loss: 0.0556
# [PPO] Ep 2744 | Avg Reward:  -0.82 | Avg Steps: 102.1 | Loss: 0.0208
# [PPO] Ep 2751 | Avg Reward:  -0.80 | Avg Steps:  92.8 | Loss: 0.0314
# [PPO] Ep 2757 | Avg Reward:  -0.73 | Avg Steps:  97.3 | Loss: 0.0268
# [PPO] Ep 2760 | Avg Reward:  -0.71 | Avg Steps: 102.6 | Loss: 0.0380
# [PPO] Ep 2767 | Avg Reward:  -0.67 | Avg Steps: 105.0 | Loss: 0.0420
# [PPO] Ep 2777 | Avg Reward:  -0.66 | Avg Steps: 111.9 | Loss: 0.1400
# [PPO] Ep 2791 | Avg Reward:  -0.63 | Avg Steps: 121.0 | Loss: 0.0477
# [PPO] Ep 2801 | Avg Reward:  -0.72 | Avg Steps: 113.3 | Loss: 0.0572
# [PPO] Ep 2805 | Avg Reward:  -0.74 | Avg Steps: 113.1 | Loss: 0.0151
# [PPO] Ep 2810 | Avg Reward:  -0.77 | Avg Steps: 104.4 | Loss: 0.0093
# [PPO] Ep 2819 | Avg Reward:  -0.75 | Avg Steps: 110.6 | Loss: 0.0133
# [PPO] Ep 2826 | Avg Reward:  -0.75 | Avg Steps: 113.5 | Loss: 0.0242
# [PPO] Ep 2830 | Avg Reward:  -0.75 | Avg Steps: 112.3 | Loss: -0.0001
# [PPO] Ep 2839 | Avg Reward:  -0.74 | Avg Steps: 116.1 | Loss: 0.0422
# [PPO] Ep 2865 | Avg Reward:  -0.78 | Avg Steps: 106.7 | Loss: 0.0965
# [PPO] Ep 2872 | Avg Reward:  -0.75 | Avg Steps: 100.5 | Loss: 0.0846
# [PPO] Ep 2877 | Avg Reward:  -0.77 | Avg Steps:  89.9 | Loss: -0.0033
# [PPO] Ep 2884 | Avg Reward:  -0.85 | Avg Steps:  95.4 | Loss: 0.0459
# [PPO] Ep 2892 | Avg Reward:  -0.74 | Avg Steps:  93.0 | Loss: 0.0159
# [PPO] Ep 2895 | Avg Reward:  -0.73 | Avg Steps:  97.6 | Loss: -0.0100
# [PPO] Ep 2902 | Avg Reward:  -0.70 | Avg Steps: 101.3 | Loss: 0.0150
# [PPO] Ep 2906 | Avg Reward:  -0.64 | Avg Steps: 104.7 | Loss: 0.0192
# [PPO] Ep 2916 | Avg Reward:  -0.47 | Avg Steps: 103.3 | Loss: 0.0004
# [PPO] Ep 2921 | Avg Reward:  -0.51 | Avg Steps: 103.6 | Loss: 0.0247
# [PPO] Ep 2927 | Avg Reward:  -0.50 | Avg Steps: 103.6 | Loss: -0.0064
# [PPO] Ep 2933 | Avg Reward:  -0.42 | Avg Steps: 100.6 | Loss: 0.0337
# [PPO] Ep 2941 | Avg Reward:  -0.36 | Avg Steps: 108.8 | Loss: 0.0047
# [PPO] Ep 2947 | Avg Reward:  -0.37 | Avg Steps: 109.4 | Loss: 0.0460
# [PPO] Ep 2952 | Avg Reward:  -0.38 | Avg Steps: 107.4 | Loss: 0.0102
# [PPO] Ep 2959 | Avg Reward:  -0.35 | Avg Steps: 104.2 | Loss: 0.0285
# [PPO] Ep 2965 | Avg Reward:  -0.44 | Avg Steps:  99.0 | Loss: 0.0091
# [PPO] Ep 2973 | Avg Reward:  -0.36 | Avg Steps: 104.9 | Loss: 0.0104
# [PPO] Ep 2978 | Avg Reward:  -0.38 | Avg Steps: 102.1 | Loss: -0.0040
# [PPO] Ep 2984 | Avg Reward:  -0.36 | Avg Steps:  97.9 | Loss: 0.0221
# [PPO] Ep 3000 | Avg Reward:  -0.61 | Avg Steps:  78.4 | Loss: 0.0522
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ✅ Success
#
# [2/10] PPO with lr=0.001, entropy=0.01, steps=250, epochs=8
#
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  279 | Avg Reward:  -1.00 | Avg Steps:  14.8 | Loss: 0.3817
# [PPO] Ep  408 | Avg Reward:  -1.00 | Avg Steps:  27.6 | Loss: 0.2833
# [PPO] Ep  434 | Avg Reward:  -1.00 | Avg Steps:  56.2 | Loss: 0.3189
# [PPO] Ep  442 | Avg Reward:  -1.00 | Avg Steps:  71.4 | Loss: 0.0552
# [PPO] Ep  444 | Avg Reward:  -1.00 | Avg Steps:  78.7 | Loss: 0.0172
# [PPO] Ep  498 | Avg Reward:  -0.92 | Avg Steps:  46.5 | Loss: 0.0726
# [PPO] Ep  501 | Avg Reward:  -0.92 | Avg Steps:  51.7 | Loss: 0.0034
# [PPO] Ep  518 | Avg Reward:  -0.88 | Avg Steps:  59.7 | Loss: 0.0433
# [PPO] Ep  521 | Avg Reward:  -0.88 | Avg Steps:  65.1 | Loss: -0.0072
# [PPO] Ep  527 | Avg Reward:  -0.78 | Avg Steps:  82.5 | Loss: -0.0184
# [PPO] Ep  531 | Avg Reward:  -0.76 | Avg Steps:  85.9 | Loss: -0.0437
# [PPO] Ep  550 | Avg Reward:  -0.76 | Avg Steps:  87.0 | Loss: 0.0095
# [PPO] Ep  577 | Avg Reward:  -0.88 | Avg Steps:  78.9 | Loss: 0.0206
# [PPO] Ep  590 | Avg Reward:  -0.94 | Avg Steps:  75.6 | Loss: 0.0073
# [PPO] Ep  613 | Avg Reward:  -1.00 | Avg Steps:  84.7 | Loss: 0.0248
# [PPO] Ep  620 | Avg Reward:  -1.00 | Avg Steps:  84.3 | Loss: -0.0062
# [PPO] Ep  640 | Avg Reward:  -0.96 | Avg Steps:  89.2 | Loss: 0.0295
# [PPO] Ep  648 | Avg Reward:  -0.94 | Avg Steps:  93.8 | Loss: 0.0070
# [PPO] Ep  649 | Avg Reward:  -0.94 | Avg Steps:  93.6 | Loss: -0.0521
# [PPO] Ep  651 | Avg Reward:  -0.92 | Avg Steps:  92.5 | Loss: -0.0276
# [PPO] Ep  659 | Avg Reward:  -0.80 | Avg Steps: 101.6 | Loss: -0.0292
# [PPO] Ep  673 | Avg Reward:  -0.68 | Avg Steps: 109.2 | Loss: -0.0311
# [PPO] Ep  679 | Avg Reward:  -0.68 | Avg Steps: 115.7 | Loss: -0.0232
# [PPO] Ep  681 | Avg Reward:  -0.68 | Avg Steps: 119.9 | Loss: -0.0503
# [PPO] Ep  687 | Avg Reward:  -0.64 | Avg Steps: 119.8 | Loss: -0.0392
# [PPO] Ep  695 | Avg Reward:  -0.60 | Avg Steps: 123.1 | Loss: -0.0282
# [PPO] Ep  702 | Avg Reward:  -0.60 | Avg Steps: 119.4 | Loss: 0.0151
# [PPO] Ep  705 | Avg Reward:  -0.66 | Avg Steps: 113.5 | Loss: -0.0512
# [PPO] Ep  713 | Avg Reward:  -0.72 | Avg Steps: 112.1 | Loss: -0.0032
# [PPO] Ep  717 | Avg Reward:  -0.72 | Avg Steps: 119.4 | Loss: -0.0430
# [PPO] Ep  727 | Avg Reward:  -0.72 | Avg Steps: 103.5 | Loss: 0.0006
# [PPO] Ep  740 | Avg Reward:  -0.76 | Avg Steps:  90.3 | Loss: -0.0111
# [PPO] Ep  745 | Avg Reward:  -0.78 | Avg Steps:  89.6 | Loss: -0.0421
# [PPO] Ep  748 | Avg Reward:  -0.74 | Avg Steps:  94.3 | Loss: -0.0481
# [PPO] Ep  760 | Avg Reward:  -0.76 | Avg Steps:  99.6 | Loss: 0.0374
# [PPO] Ep  768 | Avg Reward:  -0.67 | Avg Steps:  96.4 | Loss: -0.0392
# [PPO] Ep  783 | Avg Reward:  -0.75 | Avg Steps: 103.7 | Loss: 0.0100
# [PPO] Ep  801 | Avg Reward:  -0.78 | Avg Steps:  89.3 | Loss: -0.0287
# [PPO] Ep  803 | Avg Reward:  -0.78 | Avg Steps:  92.3 | Loss: -0.0380
# [PPO] Ep  807 | Avg Reward:  -0.76 | Avg Steps:  96.0 | Loss: -0.0465
# [PPO] Ep  816 | Avg Reward:  -0.82 | Avg Steps:  91.4 | Loss: -0.0262
# [PPO] Ep  831 | Avg Reward:  -0.81 | Avg Steps:  86.4 | Loss: -0.0016
# [PPO] Ep  833 | Avg Reward:  -0.81 | Avg Steps:  81.6 | Loss: -0.0553
# [PPO] Ep  840 | Avg Reward:  -0.81 | Avg Steps:  92.9 | Loss: -0.0398
# [PPO] Ep  874 | Avg Reward:  -0.94 | Avg Steps:  74.2 | Loss: 0.0399
# [PPO] Ep  883 | Avg Reward:  -0.93 | Avg Steps:  79.1 | Loss: -0.0154
# [PPO] Ep  889 | Avg Reward:  -0.95 | Avg Steps:  75.6 | Loss: -0.0134
# [PPO] Ep  894 | Avg Reward:  -0.95 | Avg Steps:  89.2 | Loss: -0.0352
# [PPO] Ep  907 | Avg Reward:  -0.87 | Avg Steps:  97.5 | Loss: -0.0137
# [PPO] Ep  917 | Avg Reward:  -0.81 | Avg Steps: 105.0 | Loss: -0.0199
# [PPO] Ep  922 | Avg Reward:  -0.81 | Avg Steps: 107.6 | Loss: -0.0313
# [PPO] Ep  937 | Avg Reward:  -0.84 | Avg Steps: 105.9 | Loss: -0.0151
# [PPO] Ep  950 | Avg Reward:  -0.88 | Avg Steps: 109.2 | Loss: -0.0136
# [PPO] Ep  957 | Avg Reward:  -0.84 | Avg Steps: 107.8 | Loss: -0.0175
# [PPO] Ep  965 | Avg Reward:  -0.87 | Avg Steps: 113.4 | Loss: -0.0044
# [PPO] Ep  968 | Avg Reward:  -0.87 | Avg Steps: 113.1 | Loss: -0.0430
# [PPO] Ep  974 | Avg Reward:  -0.81 | Avg Steps: 116.1 | Loss: -0.0173
# [PPO] Ep  982 | Avg Reward:  -0.72 | Avg Steps: 126.5 | Loss: -0.0251
# [PPO] Ep  992 | Avg Reward:  -0.66 | Avg Steps: 132.2 | Loss: -0.0361
# [PPO] Ep  995 | Avg Reward:  -0.63 | Avg Steps: 133.9 | Loss: -0.0498
# [PPO] Ep 1003 | Avg Reward:  -0.64 | Avg Steps: 135.0 | Loss: -0.0185
# [PPO] Ep 1013 | Avg Reward:  -0.57 | Avg Steps: 130.8 | Loss: -0.0301
# [PPO] Ep 1022 | Avg Reward:  -0.58 | Avg Steps: 124.9 | Loss: -0.0306
# [PPO] Ep 1033 | Avg Reward:  -0.56 | Avg Steps: 110.5 | Loss: -0.0209
# [PPO] Ep 1055 | Avg Reward:  -0.57 | Avg Steps:  85.8 | Loss: 0.0154
# [PPO] Ep 1073 | Avg Reward:  -0.71 | Avg Steps:  70.9 | Loss: 0.0081
# [PPO] Ep 1088 | Avg Reward:  -0.79 | Avg Steps:  66.8 | Loss: -0.0116
# [PPO] Ep 1096 | Avg Reward:  -0.75 | Avg Steps:  80.1 | Loss: -0.0246
# [PPO] Ep 1113 | Avg Reward:  -0.66 | Avg Steps:  91.8 | Loss: -0.0119
# [PPO] Ep 1122 | Avg Reward:  -0.53 | Avg Steps:  92.2 | Loss: -0.0259
# [PPO] Ep 1236 | Avg Reward:  -0.97 | Avg Steps:  29.8 | Loss: 0.0476
# [PPO] Ep 1279 | Avg Reward:  -1.00 | Avg Steps:  42.1 | Loss: 0.0563
# [PPO] Ep 1283 | Avg Reward:  -1.00 | Avg Steps:  48.6 | Loss: -0.0281
# [PPO] Ep 1291 | Avg Reward:  -0.90 | Avg Steps:  67.0 | Loss: -0.0299
# [PPO] Ep 1294 | Avg Reward:  -0.90 | Avg Steps:  70.3 | Loss: -0.0190
# [PPO] Ep 1308 | Avg Reward:  -0.81 | Avg Steps:  83.5 | Loss: -0.0122
# [PPO] Ep 1322 | Avg Reward:  -0.76 | Avg Steps:  90.3 | Loss: 0.0132
# [PPO] Ep 1326 | Avg Reward:  -0.69 | Avg Steps:  99.6 | Loss: -0.0430
# [PPO] Ep 1331 | Avg Reward:  -0.64 | Avg Steps: 111.5 | Loss: -0.0151
# [PPO] Ep 1340 | Avg Reward:  -0.60 | Avg Steps: 112.7 | Loss: -0.0174
# [PPO] Ep 1350 | Avg Reward:  -0.62 | Avg Steps: 112.1 | Loss: -0.0196
# [PPO] Ep 1357 | Avg Reward:  -0.55 | Avg Steps: 108.3 | Loss: -0.0241
# [PPO] Ep 1425 | Avg Reward:  -0.93 | Avg Steps:  45.1 | Loss: 0.0207
# [PPO] Ep 1467 | Avg Reward:  -0.98 | Avg Steps:  50.0 | Loss: 0.0938
# [PPO] Ep 1476 | Avg Reward:  -0.91 | Avg Steps:  67.2 | Loss: -0.0117
# [PPO] Ep 1476 | Avg Reward:  -0.91 | Avg Steps:  67.2 | Loss: -0.0354
# [PPO] Ep 1483 | Avg Reward:  -0.85 | Avg Steps:  89.2 | Loss: -0.0288
# [PPO] Ep 1485 | Avg Reward:  -0.81 | Avg Steps:  95.8 | Loss: -0.0408
# [PPO] Ep 1495 | Avg Reward:  -0.68 | Avg Steps: 109.4 | Loss: -0.0208
# [PPO] Ep 1498 | Avg Reward:  -0.66 | Avg Steps: 107.4 | Loss: -0.0192
# [PPO] Ep 1503 | Avg Reward:  -0.58 | Avg Steps: 117.8 | Loss: -0.0447
# [PPO] Ep 1508 | Avg Reward:  -0.54 | Avg Steps: 123.9 | Loss: -0.0279
# [PPO] Ep 1518 | Avg Reward:  -0.44 | Avg Steps: 128.5 | Loss: -0.0271
# [PPO] Ep 1522 | Avg Reward:  -0.40 | Avg Steps: 126.7 | Loss: -0.0398
# [PPO] Ep 1529 | Avg Reward:  -0.45 | Avg Steps: 122.1 | Loss: -0.0265
# [PPO] Ep 1539 | Avg Reward:  -0.51 | Avg Steps: 110.8 | Loss: -0.0060
# [PPO] Ep 1544 | Avg Reward:  -0.49 | Avg Steps: 108.3 | Loss: -0.0300
# [PPO] Ep 1551 | Avg Reward:  -0.55 | Avg Steps: 105.8 | Loss: -0.0208
# [PPO] Ep 1555 | Avg Reward:  -0.61 | Avg Steps: 102.0 | Loss: -0.0386
# [PPO] Ep 1561 | Avg Reward:  -0.59 | Avg Steps: 103.3 | Loss: -0.0408
# [PPO] Ep 1569 | Avg Reward:  -0.63 | Avg Steps: 102.4 | Loss: -0.0152
# [PPO] Ep 1575 | Avg Reward:  -0.60 | Avg Steps: 104.7 | Loss: -0.0332
# [PPO] Ep 1579 | Avg Reward:  -0.58 | Avg Steps: 102.2 | Loss: -0.0292
# [PPO] Ep 1587 | Avg Reward:  -0.50 | Avg Steps: 112.7 | Loss: -0.0258
# [PPO] Ep 1591 | Avg Reward:  -0.46 | Avg Steps: 113.7 | Loss: -0.0330
# [PPO] Ep 1605 | Avg Reward:  -0.37 | Avg Steps: 112.8 | Loss: -0.0285
# [PPO] Ep 1615 | Avg Reward:  -0.31 | Avg Steps: 116.1 | Loss: -0.0153
# [PPO] Ep 1633 | Avg Reward:  -0.50 | Avg Steps: 114.1 | Loss: 0.0185
# [PPO] Ep 1638 | Avg Reward:  -0.58 | Avg Steps: 102.0 | Loss: -0.0254
# [PPO] Ep 1642 | Avg Reward:  -0.64 | Avg Steps: 107.0 | Loss: -0.0328
# [PPO] Ep 1648 | Avg Reward:  -0.64 | Avg Steps: 115.5 | Loss: -0.0248
# [PPO] Ep 1654 | Avg Reward:  -0.65 | Avg Steps: 114.3 | Loss: -0.0304
# [PPO] Ep 1666 | Avg Reward:  -0.72 | Avg Steps: 111.4 | Loss: -0.0185
# [PPO] Ep 1678 | Avg Reward:  -0.68 | Avg Steps: 109.9 | Loss: 0.0129
# [PPO] Ep 1689 | Avg Reward:  -0.62 | Avg Steps: 108.2 | Loss: -0.0076
# [PPO] Ep 1720 | Avg Reward:  -0.83 | Avg Steps:  73.2 | Loss: 0.0613
# [PPO] Ep 1730 | Avg Reward:  -0.70 | Avg Steps:  78.7 | Loss: -0.0338
# [PPO] Ep 1743 | Avg Reward:  -0.65 | Avg Steps:  79.9 | Loss: -0.0145
# [PPO] Ep 1754 | Avg Reward:  -0.69 | Avg Steps:  95.8 | Loss: -0.0066
# [PPO] Ep 1761 | Avg Reward:  -0.61 | Avg Steps:  97.2 | Loss: -0.0341
# [PPO] Ep 1770 | Avg Reward:  -0.57 | Avg Steps: 106.8 | Loss: -0.0084
# [PPO] Ep 1826 | Avg Reward:  -0.93 | Avg Steps:  46.5 | Loss: 0.0670
# [PPO] Ep 1837 | Avg Reward:  -0.93 | Avg Steps:  57.6 | Loss: -0.0097
# [PPO] Ep 1852 | Avg Reward:  -0.93 | Avg Steps:  62.1 | Loss: -0.0160
# [PPO] Ep 1857 | Avg Reward:  -0.93 | Avg Steps:  77.2 | Loss: -0.0184
# [PPO] Ep 1868 | Avg Reward:  -0.87 | Avg Steps:  90.8 | Loss: -0.0276
# [PPO] Ep 1875 | Avg Reward:  -0.81 | Avg Steps:  98.7 | Loss: -0.0358
# [PPO] Ep 1883 | Avg Reward:  -0.78 | Avg Steps: 110.7 | Loss: -0.0307
# [PPO] Ep 1888 | Avg Reward:  -0.74 | Avg Steps: 107.8 | Loss: -0.0369
# [PPO] Ep 1897 | Avg Reward:  -0.71 | Avg Steps: 122.3 | Loss: -0.0068
# [PPO] Ep 1910 | Avg Reward:  -0.63 | Avg Steps: 119.7 | Loss: 0.0021
# [PPO] Ep 1916 | Avg Reward:  -0.63 | Avg Steps: 116.0 | Loss: -0.0199
# [PPO] Ep 1921 | Avg Reward:  -0.59 | Avg Steps: 115.7 | Loss: -0.0174
# [PPO] Ep 1931 | Avg Reward:  -0.61 | Avg Steps: 110.8 | Loss: -0.0248
# [PPO] Ep 1939 | Avg Reward:  -0.60 | Avg Steps: 106.3 | Loss: -0.0184
# [PPO] Ep 1945 | Avg Reward:  -0.51 | Avg Steps: 106.4 | Loss: -0.0332
# [PPO] Ep 1957 | Avg Reward:  -0.47 | Avg Steps:  93.7 | Loss: -0.0314
# [PPO] Ep 1966 | Avg Reward:  -0.42 | Avg Steps:  92.7 | Loss: -0.0361
# [PPO] Ep 1982 | Avg Reward:  -0.51 | Avg Steps:  79.2 | Loss: -0.0175
# [PPO] Ep 1990 | Avg Reward:  -0.50 | Avg Steps:  86.2 | Loss: -0.0295
# [PPO] Ep 2002 | Avg Reward:  -0.57 | Avg Steps:  84.2 | Loss: 0.0017
# [PPO] Ep 2006 | Avg Reward:  -0.54 | Avg Steps:  85.5 | Loss: -0.0100
# [PPO] Ep 2013 | Avg Reward:  -0.52 | Avg Steps:  90.4 | Loss: -0.0427
# [PPO] Ep 2027 | Avg Reward:  -0.38 | Avg Steps: 102.2 | Loss: 0.0030
# [PPO] Ep 2039 | Avg Reward:  -0.18 | Avg Steps: 102.3 | Loss: -0.0162
# [PPO] Ep 2046 | Avg Reward:  -0.16 | Avg Steps: 106.8 | Loss: -0.0289
# [PPO] Ep 2057 | Avg Reward:  -0.11 | Avg Steps: 107.9 | Loss: -0.0083
# [PPO] Ep 2068 | Avg Reward:  -0.15 | Avg Steps: 106.2 | Loss: -0.0113
# [PPO] Ep 2084 | Avg Reward:  -0.25 | Avg Steps: 102.7 | Loss: 0.0048
# [PPO] Ep 2095 | Avg Reward:  -0.33 | Avg Steps:  98.8 | Loss: -0.0023
# [PPO] Ep 2101 | Avg Reward:  -0.37 | Avg Steps: 107.2 | Loss: -0.0354
# [PPO] Ep 2112 | Avg Reward:  -0.41 | Avg Steps: 104.3 | Loss: -0.0156
# [PPO] Ep 2123 | Avg Reward:  -0.51 | Avg Steps: 106.0 | Loss: -0.0112
# [PPO] Ep 2132 | Avg Reward:  -0.52 | Avg Steps: 104.7 | Loss: -0.0274
# [PPO] Ep 2144 | Avg Reward:  -0.48 | Avg Steps: 108.1 | Loss: -0.0251
# [PPO] Ep 2154 | Avg Reward:  -0.47 | Avg Steps: 100.5 | Loss: -0.0127
# [PPO] Ep 2160 | Avg Reward:  -0.44 | Avg Steps: 104.8 | Loss: -0.0366
# [PPO] Ep 2174 | Avg Reward:  -0.32 | Avg Steps: 105.9 | Loss: 0.0108
# [PPO] Ep 2189 | Avg Reward:  -0.43 | Avg Steps: 112.4 | Loss: -0.0040
# [PPO] Ep 2196 | Avg Reward:  -0.48 | Avg Steps: 114.5 | Loss: -0.0006
# [PPO] Ep 2267 | Avg Reward:  -0.92 | Avg Steps:  37.1 | Loss: 0.0494
# [PPO] Ep 2289 | Avg Reward:  -0.89 | Avg Steps:  62.3 | Loss: 0.0342
# [PPO] Ep 2301 | Avg Reward:  -0.86 | Avg Steps:  82.6 | Loss: -0.0209
# [PPO] Ep 2311 | Avg Reward:  -0.86 | Avg Steps:  89.6 | Loss: 0.0053
# [PPO] Ep 2327 | Avg Reward:  -0.80 | Avg Steps: 110.8 | Loss: -0.0046
# [PPO] Ep 2340 | Avg Reward:  -0.75 | Avg Steps: 116.9 | Loss: -0.0288
# [PPO] Ep 2354 | Avg Reward:  -0.79 | Avg Steps: 108.2 | Loss: -0.0063
# [PPO] Ep 2364 | Avg Reward:  -0.82 | Avg Steps: 109.8 | Loss: -0.0070
# [PPO] Ep 2375 | Avg Reward:  -0.81 | Avg Steps: 110.6 | Loss: -0.0219
# [PPO] Ep 2387 | Avg Reward:  -0.71 | Avg Steps: 110.2 | Loss: -0.0121
# [PPO] Ep 2396 | Avg Reward:  -0.56 | Avg Steps: 109.9 | Loss: -0.0128
# [PPO] Ep 2410 | Avg Reward:  -0.42 | Avg Steps: 112.6 | Loss: -0.0055
# [PPO] Ep 2421 | Avg Reward:  -0.38 | Avg Steps: 109.8 | Loss: -0.0101
# [PPO] Ep 2433 | Avg Reward:  -0.36 | Avg Steps: 112.0 | Loss: -0.0074
# [PPO] Ep 2444 | Avg Reward:  -0.43 | Avg Steps: 116.7 | Loss: -0.0105
# [PPO] Ep 2449 | Avg Reward:  -0.42 | Avg Steps: 109.6 | Loss: -0.0296
# [PPO] Ep 2465 | Avg Reward:  -0.55 | Avg Steps: 106.0 | Loss: -0.0092
# [PPO] Ep 2474 | Avg Reward:  -0.58 | Avg Steps: 103.4 | Loss: -0.0066
# [PPO] Ep 2483 | Avg Reward:  -0.58 | Avg Steps:  92.2 | Loss: -0.0127
# [PPO] Ep 2489 | Avg Reward:  -0.65 | Avg Steps:  98.1 | Loss: -0.0338
# [PPO] Ep 2494 | Avg Reward:  -0.70 | Avg Steps:  88.7 | Loss: -0.0022
# [PPO] Ep 2504 | Avg Reward:  -0.63 | Avg Steps: 108.6 | Loss: -0.0275
# [PPO] Ep 2514 | Avg Reward:  -0.51 | Avg Steps: 102.8 | Loss: -0.0057
# [PPO] Ep 2524 | Avg Reward:  -0.37 | Avg Steps: 111.9 | Loss: -0.0198
# [PPO] Ep 2530 | Avg Reward:  -0.27 | Avg Steps: 115.5 | Loss: -0.0196
# [PPO] Ep 2543 | Avg Reward:  -0.11 | Avg Steps: 119.5 | Loss: -0.0023
# [PPO] Ep 2562 | Avg Reward:  -0.03 | Avg Steps: 106.1 | Loss: 0.0169
# [PPO] Ep 2580 | Avg Reward:  -0.18 | Avg Steps:  93.8 | Loss: 0.0097
# [PPO] Ep 2598 | Avg Reward:  -0.29 | Avg Steps: 106.8 | Loss: 0.0056
# [PPO] Ep 2610 | Avg Reward:  -0.31 | Avg Steps: 107.1 | Loss: 0.0008
# [PPO] Ep 2621 | Avg Reward:  -0.21 | Avg Steps: 115.0 | Loss: 0.0090
# [PPO] Ep 2635 | Avg Reward:  -0.07 | Avg Steps: 113.8 | Loss: 0.0151
# [PPO] Ep 2657 | Avg Reward:  -0.17 | Avg Steps: 112.4 | Loss: 0.0058
# [PPO] Ep 2672 | Avg Reward:  -0.27 | Avg Steps: 102.3 | Loss: 0.0070
# [PPO] Ep 2733 | Avg Reward:  -0.93 | Avg Steps:  51.9 | Loss: 0.0581
# [PPO] Ep 2764 | Avg Reward:  -0.92 | Avg Steps:  68.3 | Loss: 0.0569
# [PPO] Ep 2779 | Avg Reward:  -0.85 | Avg Steps:  80.8 | Loss: -0.0155
# [PPO] Ep 2796 | Avg Reward:  -0.71 | Avg Steps:  99.6 | Loss: 0.0326
# [PPO] Ep 2813 | Avg Reward:  -0.57 | Avg Steps: 101.3 | Loss: 0.0119
# [PPO] Ep 2830 | Avg Reward:  -0.36 | Avg Steps:  94.7 | Loss: 0.0092
# [PPO] Ep 2841 | Avg Reward:  -0.27 | Avg Steps:  98.4 | Loss: -0.0109
# [PPO] Ep 2849 | Avg Reward:  -0.07 | Avg Steps: 100.4 | Loss: -0.0107
# [PPO] Ep 2868 | Avg Reward:  -0.21 | Avg Steps: 100.5 | Loss: 0.0065
# [PPO] Ep 2879 | Avg Reward:  -0.36 | Avg Steps: 109.2 | Loss: 0.0282
# [PPO] Ep 2894 | Avg Reward:  -0.39 | Avg Steps: 108.5 | Loss: 0.0078
# [PPO] Ep 2904 | Avg Reward:  -0.52 | Avg Steps: 110.7 | Loss: 0.0026
# [PPO] Ep 2978 | Avg Reward:  -1.00 | Avg Steps:  45.7 | Loss: 0.0523
# [PPO] Ep 3000 | Avg Reward:  -1.00 | Avg Steps:  58.6 | Loss: 0.0247
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ✅ Success
#
# [3/10] PPO with lr=0.0003, entropy=0.01, steps=500, epochs=16
#
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  550 | Avg Reward:  -1.00 | Avg Steps:  12.5 | Loss: 0.3437
# [PPO] Ep  803 | Avg Reward:  -1.00 | Avg Steps:  26.9 | Loss: 0.3417
# [PPO] Ep  829 | Avg Reward:  -1.00 | Avg Steps:  80.3 | Loss: 0.2427
# [PPO] Ep  840 | Avg Reward:  -0.98 | Avg Steps: 112.1 | Loss: 0.0266
# [PPO] Ep  852 | Avg Reward:  -0.82 | Avg Steps: 153.6 | Loss: 0.1001
# [PPO] Ep  935 | Avg Reward:  -1.00 | Avg Steps:  83.3 | Loss: 0.1438
# [PPO] Ep  964 | Avg Reward:  -1.00 | Avg Steps: 121.8 | Loss: 0.1080
# [PPO] Ep  975 | Avg Reward:  -1.00 | Avg Steps: 151.5 | Loss: 0.0115
# [PPO] Ep  990 | Avg Reward:  -0.78 | Avg Steps: 187.5 | Loss: -0.0025
# [PPO] Ep  996 | Avg Reward:  -0.70 | Avg Steps: 198.5 | Loss: -0.0105
# [PPO] Ep 1008 | Avg Reward:  -0.45 | Avg Steps: 222.1 | Loss: -0.0380
# [PPO] Ep 1111 | Avg Reward:  -1.00 | Avg Steps:  69.9 | Loss: 0.0894
# [PPO] Ep 1137 | Avg Reward:  -1.00 | Avg Steps: 125.7 | Loss: 0.0685
# [PPO] Ep 1145 | Avg Reward:  -0.96 | Avg Steps: 152.1 | Loss: -0.0090
# [PPO] Ep 1157 | Avg Reward:  -0.82 | Avg Steps: 190.4 | Loss: -0.0126
# [PPO] Ep 1172 | Avg Reward:  -0.72 | Avg Steps: 223.3 | Loss: -0.0251
# [PPO] Ep 1177 | Avg Reward:  -0.62 | Avg Steps: 231.5 | Loss: -0.0465
# [PPO] Ep 1197 | Avg Reward:  -0.47 | Avg Steps: 230.0 | Loss: -0.0217
# [PPO] Ep 1203 | Avg Reward:  -0.45 | Avg Steps: 231.5 | Loss: -0.0461
# [PPO] Ep 1219 | Avg Reward:  -0.43 | Avg Steps: 217.4 | Loss: -0.0230
# [PPO] Ep 1230 | Avg Reward:  -0.47 | Avg Steps: 223.1 | Loss: -0.0254
# [PPO] Ep 1241 | Avg Reward:  -0.45 | Avg Steps: 225.2 | Loss: -0.0245
# [PPO] Ep 1257 | Avg Reward:  -0.51 | Avg Steps: 216.2 | Loss: -0.0066
# [PPO] Ep 1260 | Avg Reward:  -0.49 | Avg Steps: 224.5 | Loss: -0.0543
# [PPO] Ep 1340 | Avg Reward:  -0.92 | Avg Steps:  81.4 | Loss: 0.0517
# [PPO] Ep 1369 | Avg Reward:  -0.96 | Avg Steps:  70.4 | Loss: 0.0516
# [PPO] Ep 1387 | Avg Reward:  -0.83 | Avg Steps: 100.1 | Loss: -0.0294
# [PPO] Ep 1392 | Avg Reward:  -0.73 | Avg Steps: 114.6 | Loss: -0.0521
# [PPO] Ep 1403 | Avg Reward:  -0.57 | Avg Steps: 165.8 | Loss: -0.0532
# [PPO] Ep 1413 | Avg Reward:  -0.47 | Avg Steps: 176.9 | Loss: -0.0551
# [PPO] Ep 1423 | Avg Reward:  -0.35 | Avg Steps: 202.7 | Loss: -0.0464
# [PPO] Ep 1432 | Avg Reward:  -0.34 | Avg Steps: 195.7 | Loss: -0.0550
# [PPO] Ep 1443 | Avg Reward:  -0.34 | Avg Steps: 217.2 | Loss: -0.0442
# [PPO] Ep 1453 | Avg Reward:  -0.38 | Avg Steps: 199.4 | Loss: -0.0467
# [PPO] Ep 1466 | Avg Reward:  -0.38 | Avg Steps: 222.3 | Loss: -0.0411
# [PPO] Ep 1505 | Avg Reward:  -0.82 | Avg Steps: 140.2 | Loss: 0.0335
# [PPO] Ep 1524 | Avg Reward:  -0.90 | Avg Steps: 156.8 | Loss: 0.0214
# [PPO] Ep 1539 | Avg Reward:  -0.88 | Avg Steps: 196.2 | Loss: -0.0277
# [PPO] Ep 1555 | Avg Reward:  -0.84 | Avg Steps: 189.2 | Loss: -0.0124
# [PPO] Ep 1564 | Avg Reward:  -0.82 | Avg Steps: 223.2 | Loss: -0.0307
# [PPO] Ep 1575 | Avg Reward:  -0.66 | Avg Steps: 206.2 | Loss: -0.0617
# [PPO] Ep 1590 | Avg Reward:  -0.59 | Avg Steps: 219.2 | Loss: -0.0354
# [PPO] Ep 1598 | Avg Reward:  -0.53 | Avg Steps: 228.6 | Loss: -0.0358
# [PPO] Ep 1612 | Avg Reward:  -0.47 | Avg Steps: 232.2 | Loss: -0.0357
# [PPO] Ep 1630 | Avg Reward:  -0.66 | Avg Steps: 208.7 | Loss: 0.0170
# [PPO] Ep 1642 | Avg Reward:  -0.67 | Avg Steps: 189.9 | Loss: -0.0381
# [PPO] Ep 1653 | Avg Reward:  -0.65 | Avg Steps: 193.5 | Loss: -0.0473
# [PPO] Ep 1664 | Avg Reward:  -0.63 | Avg Steps: 187.9 | Loss: -0.0449
# [PPO] Ep 1674 | Avg Reward:  -0.52 | Avg Steps: 207.8 | Loss: -0.0266
# [PPO] Ep 1686 | Avg Reward:  -0.51 | Avg Steps: 251.0 | Loss: -0.0363
# [PPO] Ep 1708 | Avg Reward:  -0.67 | Avg Steps: 226.9 | Loss: -0.0048
# [PPO] Ep 1719 | Avg Reward:  -0.69 | Avg Steps: 218.8 | Loss: -0.0244
# [PPO] Ep 1735 | Avg Reward:  -0.75 | Avg Steps: 177.5 | Loss: -0.0116
# [PPO] Ep 1746 | Avg Reward:  -0.73 | Avg Steps: 206.7 | Loss: -0.0252
# [PPO] Ep 1758 | Avg Reward:  -0.65 | Avg Steps: 213.6 | Loss: -0.0126
# [PPO] Ep 1770 | Avg Reward:  -0.60 | Avg Steps: 223.7 | Loss: -0.0334
# [PPO] Ep 1778 | Avg Reward:  -0.58 | Avg Steps: 228.9 | Loss: -0.0342
# [PPO] Ep 1789 | Avg Reward:  -0.46 | Avg Steps: 266.9 | Loss: -0.0612
# [PPO] Ep 1805 | Avg Reward:  -0.48 | Avg Steps: 248.5 | Loss: -0.0212
# [PPO] Ep 1814 | Avg Reward:  -0.50 | Avg Steps: 255.4 | Loss: -0.0447
# [PPO] Ep 1822 | Avg Reward:  -0.42 | Avg Steps: 257.4 | Loss: -0.0520
# [PPO] Ep 1833 | Avg Reward:  -0.46 | Avg Steps: 254.6 | Loss: -0.0501
# [PPO] Ep 1856 | Avg Reward:  -0.56 | Avg Steps: 211.3 | Loss: -0.0278
# [PPO] Ep 1870 | Avg Reward:  -0.66 | Avg Steps: 201.7 | Loss: -0.0081
# [PPO] Ep 1887 | Avg Reward:  -0.74 | Avg Steps: 198.3 | Loss: -0.0237
# [PPO] Ep 1959 | Avg Reward:  -1.00 | Avg Steps:  97.3 | Loss: 0.0851
# [PPO] Ep 2001 | Avg Reward:  -1.00 | Avg Steps: 101.5 | Loss: 0.1037
# [PPO] Ep 2009 | Avg Reward:  -0.98 | Avg Steps: 128.8 | Loss: -0.0085
# [PPO] Ep 2021 | Avg Reward:  -0.84 | Avg Steps: 172.8 | Loss: -0.0367
# [PPO] Ep 2030 | Avg Reward:  -0.76 | Avg Steps: 202.2 | Loss: -0.0391
# [PPO] Ep 2038 | Avg Reward:  -0.64 | Avg Steps: 210.5 | Loss: -0.0388
# [PPO] Ep 2050 | Avg Reward:  -0.48 | Avg Steps: 212.0 | Loss: -0.0464
# [PPO] Ep 2114 | Avg Reward:  -1.00 | Avg Steps: 105.1 | Loss: 0.0695
# [PPO] Ep 2153 | Avg Reward:  -1.00 | Avg Steps:  96.5 | Loss: 0.1062
# [PPO] Ep 2163 | Avg Reward:  -0.95 | Avg Steps: 112.0 | Loss: -0.0192
# [PPO] Ep 2171 | Avg Reward:  -0.85 | Avg Steps: 134.2 | Loss: -0.0455
# [PPO] Ep 2200 | Avg Reward:  -0.77 | Avg Steps: 179.6 | Loss: 0.0247
# [PPO] Ep 2218 | Avg Reward:  -0.86 | Avg Steps: 168.3 | Loss: 0.0264
# [PPO] Ep 2241 | Avg Reward:  -0.88 | Avg Steps: 159.6 | Loss: -0.0186
# [PPO] Ep 2250 | Avg Reward:  -0.78 | Avg Steps: 162.3 | Loss: -0.0217
# [PPO] Ep 2269 | Avg Reward:  -0.68 | Avg Steps: 196.0 | Loss: -0.0140
# [PPO] Ep 2281 | Avg Reward:  -0.64 | Avg Steps: 233.1 | Loss: -0.0253
# [PPO] Ep 2295 | Avg Reward:  -0.61 | Avg Steps: 246.3 | Loss: -0.0136
# [PPO] Ep 2306 | Avg Reward:  -0.63 | Avg Steps: 245.2 | Loss: -0.0330
# [PPO] Ep 2349 | Avg Reward:  -0.81 | Avg Steps: 125.4 | Loss: 0.0270
# [PPO] Ep 2364 | Avg Reward:  -0.90 | Avg Steps: 115.6 | Loss: 0.0081
# [PPO] Ep 2381 | Avg Reward:  -0.84 | Avg Steps: 160.1 | Loss: 0.0070
# [PPO] Ep 2390 | Avg Reward:  -0.80 | Avg Steps: 152.3 | Loss: -0.0328
# [PPO] Ep 2404 | Avg Reward:  -0.68 | Avg Steps: 196.2 | Loss: -0.0163
# [PPO] Ep 2411 | Avg Reward:  -0.60 | Avg Steps: 220.7 | Loss: -0.0458
# [PPO] Ep 2448 | Avg Reward:  -0.76 | Avg Steps: 158.9 | Loss: -0.0086
# [PPO] Ep 2488 | Avg Reward:  -0.94 | Avg Steps: 112.6 | Loss: 0.1379
# [PPO] Ep 2502 | Avg Reward:  -0.94 | Avg Steps: 123.0 | Loss: 0.0343
# [PPO] Ep 2514 | Avg Reward:  -0.80 | Avg Steps: 155.7 | Loss: -0.0418
# [PPO] Ep 2553 | Avg Reward:  -0.74 | Avg Steps: 130.3 | Loss: 0.0618
# [PPO] Ep 2583 | Avg Reward:  -0.92 | Avg Steps: 139.4 | Loss: 0.0693
# [PPO] Ep 2602 | Avg Reward:  -0.94 | Avg Steps: 166.7 | Loss: 0.0774
# [PPO] Ep 2613 | Avg Reward:  -0.90 | Avg Steps: 199.0 | Loss: 0.0169
# [PPO] Ep 2624 | Avg Reward:  -0.84 | Avg Steps: 202.5 | Loss: -0.0311
# [PPO] Ep 2636 | Avg Reward:  -0.74 | Avg Steps: 206.9 | Loss: 0.0205
# [PPO] Ep 2654 | Avg Reward:  -0.59 | Avg Steps: 170.8 | Loss: 0.0096
# [PPO] Ep 2678 | Avg Reward:  -0.63 | Avg Steps: 177.7 | Loss: 0.0184
# [PPO] Ep 2692 | Avg Reward:  -0.72 | Avg Steps: 193.7 | Loss: 0.0396
# [PPO] Ep 2703 | Avg Reward:  -0.69 | Avg Steps: 213.1 | Loss: -0.0159
# [PPO] Ep 2712 | Avg Reward:  -0.64 | Avg Steps: 251.2 | Loss: -0.0285
# [PPO] Ep 2722 | Avg Reward:  -0.50 | Avg Steps: 277.3 | Loss: -0.0376
# [PPO] Ep 2741 | Avg Reward:  -0.51 | Avg Steps: 233.7 | Loss: 0.0345
# [PPO] Ep 2749 | Avg Reward:  -0.52 | Avg Steps: 238.7 | Loss: -0.0071
# [PPO] Ep 2762 | Avg Reward:  -0.54 | Avg Steps: 200.0 | Loss: -0.0158
# [PPO] Ep 2777 | Avg Reward:  -0.64 | Avg Steps: 179.4 | Loss: 0.0127
# [PPO] Ep 2790 | Avg Reward:  -0.56 | Avg Steps: 190.6 | Loss: -0.0082
# [PPO] Ep 2800 | Avg Reward:  -0.58 | Avg Steps: 178.3 | Loss: 0.0097
# [PPO] Ep 2828 | Avg Reward:  -0.66 | Avg Steps: 163.0 | Loss: 0.0419
# [PPO] Ep 2845 | Avg Reward:  -0.76 | Avg Steps: 148.7 | Loss: 0.0448
# [PPO] Ep 2863 | Avg Reward:  -0.75 | Avg Steps: 183.1 | Loss: 0.0407
# [PPO] Ep 2869 | Avg Reward:  -0.73 | Avg Steps: 190.0 | Loss: -0.0010
# [PPO] Ep 2889 | Avg Reward:  -0.65 | Avg Steps: 221.9 | Loss: 0.0057
# [PPO] Ep 2898 | Avg Reward:  -0.65 | Avg Steps: 220.9 | Loss: 0.0269
# [PPO] Ep 2907 | Avg Reward:  -0.55 | Avg Steps: 239.3 | Loss: -0.0195
# [PPO] Ep 2923 | Avg Reward:  -0.57 | Avg Steps: 215.9 | Loss: 0.0119
# [PPO] Ep 2929 | Avg Reward:  -0.51 | Avg Steps: 213.9 | Loss: -0.0145
# [PPO] Ep 2941 | Avg Reward:  -0.47 | Avg Steps: 206.6 | Loss: -0.0143
# [PPO] Ep 2962 | Avg Reward:  -0.55 | Avg Steps: 182.8 | Loss: 0.0635
# [PPO] Ep 2986 | Avg Reward:  -0.82 | Avg Steps: 169.2 | Loss: 0.0942
# [PPO] Ep 3000 | Avg Reward:  -0.85 | Avg Steps: 163.6 | Loss: 0.0493
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ✅ Success
#
# [4/10] PPO with lr=0.0003, entropy=0.01, steps=500, epochs=4
#
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  535 | Avg Reward:  -1.00 | Avg Steps:  14.8 | Loss: 0.3502
# [PPO] Ep  836 | Avg Reward:  -1.00 | Avg Steps:  35.6 | Loss: 0.3818
# [PPO] Ep 1005 | Avg Reward:  -1.00 | Avg Steps:  50.6 | Loss: 0.4144
# [PPO] Ep 1096 | Avg Reward:  -1.00 | Avg Steps:  84.4 | Loss: 0.2734
# [PPO] Ep 1120 | Avg Reward:  -1.00 | Avg Steps: 127.5 | Loss: 0.1478
# [PPO] Ep 1169 | Avg Reward:  -0.96 | Avg Steps: 105.3 | Loss: 0.0732
# [PPO] Ep 1202 | Avg Reward:  -0.96 | Avg Steps: 133.9 | Loss: 0.1242
# [PPO] Ep 1216 | Avg Reward:  -0.98 | Avg Steps: 136.7 | Loss: 0.0294
# [PPO] Ep 1243 | Avg Reward:  -0.94 | Avg Steps: 165.1 | Loss: 0.0634
# [PPO] Ep 1258 | Avg Reward:  -0.88 | Avg Steps: 195.6 | Loss: 0.0479
# [PPO] Ep 1268 | Avg Reward:  -0.73 | Avg Steps: 204.7 | Loss: 0.0234
# [PPO] Ep 1303 | Avg Reward:  -0.73 | Avg Steps: 189.9 | Loss: 0.0668
# [PPO] Ep 1314 | Avg Reward:  -0.80 | Avg Steps: 177.6 | Loss: 0.0235
# [PPO] Ep 1414 | Avg Reward:  -1.00 | Avg Steps:  74.7 | Loss: 0.1415
# [PPO] Ep 1434 | Avg Reward:  -1.00 | Avg Steps: 118.7 | Loss: 0.0776
# [PPO] Ep 1456 | Avg Reward:  -0.98 | Avg Steps: 160.9 | Loss: 0.0226
# [PPO] Ep 1487 | Avg Reward:  -0.91 | Avg Steps: 156.9 | Loss: 0.0806
# [PPO] Ep 1493 | Avg Reward:  -0.89 | Avg Steps: 164.3 | Loss: 0.0068
# [PPO] Ep 1514 | Avg Reward:  -0.73 | Avg Steps: 175.3 | Loss: 0.0339
# [PPO] Ep 1535 | Avg Reward:  -0.74 | Avg Steps: 170.1 | Loss: 0.0296
# [PPO] Ep 1572 | Avg Reward:  -0.93 | Avg Steps: 143.0 | Loss: 0.1150
# [PPO] Ep 1596 | Avg Reward:  -0.98 | Avg Steps: 143.3 | Loss: 0.0198
# [PPO] Ep 1620 | Avg Reward:  -0.98 | Avg Steps: 149.6 | Loss: 0.0762
# [PPO] Ep 1640 | Avg Reward:  -0.96 | Avg Steps: 180.2 | Loss: 0.0260
# [PPO] Ep 1646 | Avg Reward:  -0.92 | Avg Steps: 159.6 | Loss: 0.0301
# [PPO] Ep 1660 | Avg Reward:  -0.76 | Avg Steps: 196.9 | Loss: 0.0032
# [PPO] Ep 1672 | Avg Reward:  -0.68 | Avg Steps: 208.6 | Loss: 0.0210
# [PPO] Ep 1679 | Avg Reward:  -0.62 | Avg Steps: 215.2 | Loss: 0.0027
# [PPO] Ep 1689 | Avg Reward:  -0.46 | Avg Steps: 222.6 | Loss: 0.0163
# [PPO] Ep 1699 | Avg Reward:  -0.42 | Avg Steps: 250.9 | Loss: 0.0150
# [PPO] Ep 1717 | Avg Reward:  -0.54 | Avg Steps: 220.4 | Loss: 0.0308
# [PPO] Ep 1722 | Avg Reward:  -0.52 | Avg Steps: 212.7 | Loss: 0.0132
# [PPO] Ep 1735 | Avg Reward:  -0.50 | Avg Steps: 209.2 | Loss: 0.0022
# [PPO] Ep 1741 | Avg Reward:  -0.52 | Avg Steps: 193.1 | Loss: 0.0136
# [PPO] Ep 1766 | Avg Reward:  -0.47 | Avg Steps: 177.5 | Loss: 0.0370
# [PPO] Ep 1770 | Avg Reward:  -0.47 | Avg Steps: 183.3 | Loss: 0.0098
# [PPO] Ep 1781 | Avg Reward:  -0.45 | Avg Steps: 205.8 | Loss: 0.0192
# [PPO] Ep 1789 | Avg Reward:  -0.49 | Avg Steps: 207.1 | Loss: 0.0114
# [PPO] Ep 1803 | Avg Reward:  -0.49 | Avg Steps: 210.8 | Loss: 0.0091
# [PPO] Ep 1820 | Avg Reward:  -0.56 | Avg Steps: 178.0 | Loss: 0.0246
# [PPO] Ep 1832 | Avg Reward:  -0.58 | Avg Steps: 163.3 | Loss: 0.0062
# [PPO] Ep 1845 | Avg Reward:  -0.62 | Avg Steps: 145.1 | Loss: 0.0268
# [PPO] Ep 1856 | Avg Reward:  -0.56 | Avg Steps: 165.9 | Loss: 0.0012
# [PPO] Ep 1867 | Avg Reward:  -0.50 | Avg Steps: 193.9 | Loss: 0.0197
# [PPO] Ep 1895 | Avg Reward:  -0.64 | Avg Steps: 172.3 | Loss: 0.0262
# [PPO] Ep 1905 | Avg Reward:  -0.69 | Avg Steps: 174.3 | Loss: 0.0131
# [PPO] Ep 1920 | Avg Reward:  -0.72 | Avg Steps: 170.8 | Loss: 0.0114
# [PPO] Ep 1934 | Avg Reward:  -0.65 | Avg Steps: 196.9 | Loss: 0.0267
# [PPO] Ep 1942 | Avg Reward:  -0.51 | Avg Steps: 210.7 | Loss: 0.0043
# [PPO] Ep 1956 | Avg Reward:  -0.47 | Avg Steps: 218.8 | Loss: 0.0155
# [PPO] Ep 1964 | Avg Reward:  -0.45 | Avg Steps: 219.3 | Loss: 0.0075
# [PPO] Ep 1973 | Avg Reward:  -0.35 | Avg Steps: 239.9 | Loss: -0.0037
# [PPO] Ep 1984 | Avg Reward:  -0.27 | Avg Steps: 237.6 | Loss: -0.0019
# [PPO] Ep 1995 | Avg Reward:  -0.37 | Avg Steps: 239.6 | Loss: -0.0006
# [PPO] Ep 2009 | Avg Reward:  -0.33 | Avg Steps: 223.6 | Loss: 0.0024
# [PPO] Ep 2018 | Avg Reward:  -0.35 | Avg Steps: 230.7 | Loss: 0.0130
# [PPO] Ep 2027 | Avg Reward:  -0.43 | Avg Steps: 225.2 | Loss: 0.0120
# [PPO] Ep 2042 | Avg Reward:  -0.52 | Avg Steps: 218.5 | Loss: 0.0142
# [PPO] Ep 2053 | Avg Reward:  -0.54 | Avg Steps: 230.4 | Loss: 0.0136
# [PPO] Ep 2063 | Avg Reward:  -0.46 | Avg Steps: 249.7 | Loss: -0.0063
# [PPO] Ep 2079 | Avg Reward:  -0.43 | Avg Steps: 234.1 | Loss: -0.0013
# [PPO] Ep 2088 | Avg Reward:  -0.33 | Avg Steps: 236.3 | Loss: 0.0050
# [PPO] Ep 2096 | Avg Reward:  -0.35 | Avg Steps: 235.2 | Loss: -0.0017
# [PPO] Ep 2106 | Avg Reward:  -0.31 | Avg Steps: 223.8 | Loss: 0.0107
# [PPO] Ep 2120 | Avg Reward:  -0.29 | Avg Steps: 209.7 | Loss: 0.0207
# [PPO] Ep 2130 | Avg Reward:  -0.44 | Avg Steps: 196.2 | Loss: 0.0085
# [PPO] Ep 2147 | Avg Reward:  -0.47 | Avg Steps: 178.8 | Loss: 0.0154
# [PPO] Ep 2157 | Avg Reward:  -0.45 | Avg Steps: 202.1 | Loss: 0.0028
# [PPO] Ep 2181 | Avg Reward:  -0.64 | Avg Steps: 166.9 | Loss: 0.0182
# [PPO] Ep 2186 | Avg Reward:  -0.60 | Avg Steps: 198.2 | Loss: 0.0075
# [PPO] Ep 2209 | Avg Reward:  -0.65 | Avg Steps: 162.2 | Loss: 0.0022
# [PPO] Ep 2223 | Avg Reward:  -0.67 | Avg Steps: 195.7 | Loss: 0.0228
# [PPO] Ep 2233 | Avg Reward:  -0.56 | Avg Steps: 196.0 | Loss: 0.0028
# [PPO] Ep 2243 | Avg Reward:  -0.44 | Avg Steps: 224.6 | Loss: -0.0088
# [PPO] Ep 2257 | Avg Reward:  -0.42 | Avg Steps: 231.7 | Loss: 0.0189
# [PPO] Ep 2265 | Avg Reward:  -0.36 | Avg Steps: 249.0 | Loss: -0.0114
# [PPO] Ep 2272 | Avg Reward:  -0.28 | Avg Steps: 236.7 | Loss: 0.0028
# [PPO] Ep 2282 | Avg Reward:  -0.33 | Avg Steps: 216.3 | Loss: -0.0055
# [PPO] Ep 2300 | Avg Reward:  -0.49 | Avg Steps: 198.3 | Loss: 0.0458
# ...
# [PPO] Ep 2954 | Avg Reward:  -0.59 | Avg Steps: 178.0 | Loss: 0.0137
# [PPO] Ep 2960 | Avg Reward:  -0.57 | Avg Steps: 198.0 | Loss: -0.0174
# [PPO] Ep 2975 | Avg Reward:  -0.53 | Avg Steps: 203.1 | Loss: 0.0071
# [PPO] Ep 2985 | Avg Reward:  -0.57 | Avg Steps: 214.7 | Loss: -0.0164
# [PPO] Ep 2999 | Avg Reward:  -0.51 | Avg Steps: 239.5 | Loss: -0.0113
# [PPO] Ep 3000 | Avg Reward:  -0.51 | Avg Steps: 239.7 | Loss: 0.0622
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ✅ Success
#
# [9/10] PPO with lr=0.0003, entropy=0.0, steps=500, epochs=4
#
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  594 | Avg Reward:  -1.00 | Avg Steps:  14.1 | Loss: 0.3918
# [PPO] Ep  913 | Avg Reward:  -1.00 | Avg Steps:  37.9 | Loss: 0.4308
# [PPO] Ep 1034 | Avg Reward:  -1.00 | Avg Steps:  71.2 | Loss: 0.4325
# [PPO] Ep 1070 | Avg Reward:  -1.00 | Avg Steps: 115.7 | Loss: 0.2508
# [PPO] Ep 1099 | Avg Reward:  -1.00 | Avg Steps: 175.7 | Loss: 0.1229
# [PPO] Ep 1185 | Avg Reward:  -1.00 | Avg Steps:  71.3 | Loss: 0.1023
# [PPO] Ep 1200 | Avg Reward:  -1.00 | Avg Steps: 101.4 | Loss: 0.1020
# [PPO] Ep 1232 | Avg Reward:  -0.96 | Avg Steps: 108.2 | Loss: 0.0435
# [PPO] Ep 1246 | Avg Reward:  -0.82 | Avg Steps: 133.1 | Loss: 0.0973
# [PPO] Ep 1297 | Avg Reward:  -0.92 | Avg Steps: 102.0 | Loss: 0.0269
# [PPO] Ep 1309 | Avg Reward:  -0.92 | Avg Steps: 140.1 | Loss: 0.2020
# [PPO] Ep 1321 | Avg Reward:  -0.82 | Avg Steps: 184.8 | Loss: 0.0261
# [PPO] Ep 1332 | Avg Reward:  -0.76 | Avg Steps: 211.7 | Loss: 0.0385
# [PPO] Ep 1373 | Avg Reward:  -0.84 | Avg Steps: 108.6 | Loss: 0.0271
# [PPO] Ep 1384 | Avg Reward:  -0.84 | Avg Steps: 111.3 | Loss: 0.0617
# [PPO] Ep 1404 | Avg Reward:  -0.82 | Avg Steps: 143.8 | Loss: 0.0300
# [PPO] Ep 1437 | Avg Reward:  -0.88 | Avg Steps: 117.1 | Loss: 0.1020
# [PPO] Ep 1445 | Avg Reward:  -0.82 | Avg Steps: 131.7 | Loss: 0.0175
# [PPO] Ep 1466 | Avg Reward:  -0.78 | Avg Steps: 184.4 | Loss: 0.0327
# [PPO] Ep 1475 | Avg Reward:  -0.76 | Avg Steps: 207.1 | Loss: 0.0220
# [PPO] Ep 1491 | Avg Reward:  -0.66 | Avg Steps: 219.5 | Loss: 0.0197
# [PPO] Ep 1507 | Avg Reward:  -0.68 | Avg Steps: 220.1 | Loss: 0.0228
# [PPO] Ep 1514 | Avg Reward:  -0.66 | Avg Steps: 201.9 | Loss: 0.0204
# [PPO] Ep 1527 | Avg Reward:  -0.54 | Avg Steps: 199.3 | Loss: 0.0096
# [PPO] Ep 1532 | Avg Reward:  -0.48 | Avg Steps: 214.5 | Loss: 0.0138
# [PPO] Ep 1553 | Avg Reward:  -0.42 | Avg Steps: 194.3 | Loss: 0.0403
# [PPO] Ep 1557 | Avg Reward:  -0.40 | Avg Steps: 184.7 | Loss: 0.0106
# [PPO] Ep 1579 | Avg Reward:  -0.50 | Avg Steps: 161.9 | Loss: 0.0265
# [PPO] Ep 1588 | Avg Reward:  -0.56 | Avg Steps: 189.6 | Loss: 0.0318
# [PPO] Ep 1609 | Avg Reward:  -0.64 | Avg Steps: 174.4 | Loss: 0.0302
# [PPO] Ep 1617 | Avg Reward:  -0.68 | Avg Steps: 197.3 | Loss: 0.0241
# [PPO] Ep 1627 | Avg Reward:  -0.60 | Avg Steps: 206.2 | Loss: 0.0175
# [PPO] Ep 1636 | Avg Reward:  -0.56 | Avg Steps: 193.4 | Loss: 0.0264
# [PPO] Ep 1649 | Avg Reward:  -0.52 | Avg Steps: 190.0 | Loss: 0.0099
# [PPO] Ep 1665 | Avg Reward:  -0.44 | Avg Steps: 183.4 | Loss: 0.0294
# [PPO] Ep 1679 | Avg Reward:  -0.56 | Avg Steps: 149.4 | Loss: 0.0281
# [PPO] Ep 1704 | Avg Reward:  -0.74 | Avg Steps: 154.8 | Loss: 0.0240
# [PPO] Ep 1716 | Avg Reward:  -0.80 | Avg Steps: 128.5 | Loss: 0.0290
# [PPO] Ep 1730 | Avg Reward:  -0.70 | Avg Steps: 165.4 | Loss: 0.0035
# [PPO] Ep 1750 | Avg Reward:  -0.78 | Avg Steps: 185.7 | Loss: 0.0221
# [PPO] Ep 1755 | Avg Reward:  -0.76 | Avg Steps: 180.8 | Loss: 0.0185
# [PPO] Ep 1796 | Avg Reward:  -0.84 | Avg Steps: 137.6 | Loss: 0.0361
# [PPO] Ep 1804 | Avg Reward:  -0.84 | Avg Steps: 134.5 | Loss: 0.0273
# [PPO] Ep 1824 | Avg Reward:  -0.78 | Avg Steps: 181.0 | Loss: 0.0140
# [PPO] Ep 1830 | Avg Reward:  -0.68 | Avg Steps: 204.7 | Loss: 0.0066
# [PPO] Ep 1842 | Avg Reward:  -0.54 | Avg Steps: 237.6 | Loss: 0.0039
# [PPO] Ep 1852 | Avg Reward:  -0.52 | Avg Steps: 211.6 | Loss: 0.0429
# [PPO] Ep 1868 | Avg Reward:  -0.50 | Avg Steps: 222.0 | Loss: 0.0181
# [PPO] Ep 1884 | Avg Reward:  -0.58 | Avg Steps: 181.0 | Loss: 0.0174
# [PPO] Ep 1895 | Avg Reward:  -0.66 | Avg Steps: 158.6 | Loss: 0.0090
# [PPO] Ep 1905 | Avg Reward:  -0.52 | Avg Steps: 170.9 | Loss: 0.0086
# [PPO] Ep 1926 | Avg Reward:  -0.64 | Avg Steps: 179.3 | Loss: 0.0288
# [PPO] Ep 1933 | Avg Reward:  -0.60 | Avg Steps: 187.1 | Loss: 0.0100
# [PPO] Ep 2033 | Avg Reward:  -0.98 | Avg Steps:  95.8 | Loss: 0.0839
# [PPO] Ep 2041 | Avg Reward:  -1.00 | Avg Steps: 104.3 | Loss: 0.0175
# [PPO] Ep 2101 | Avg Reward:  -0.98 | Avg Steps: 108.4 | Loss: 0.0683
# [PPO] Ep 2114 | Avg Reward:  -0.95 | Avg Steps: 133.0 | Loss: 0.0310
# [PPO] Ep 2127 | Avg Reward:  -0.89 | Avg Steps: 165.5 | Loss: 0.0296
# [PPO] Ep 2140 | Avg Reward:  -0.79 | Avg Steps: 193.4 | Loss: 0.0390
# [PPO] Ep 2149 | Avg Reward:  -0.69 | Avg Steps: 220.4 | Loss: -0.0051
# [PPO] Ep 2155 | Avg Reward:  -0.57 | Avg Steps: 237.7 | Loss: 0.0063
# [PPO] Ep 2230 | Avg Reward:  -0.98 | Avg Steps: 107.5 | Loss: 0.0750
# [PPO] Ep 2233 | Avg Reward:  -0.98 | Avg Steps: 115.8 | Loss: 0.0149
# [PPO] Ep 2263 | Avg Reward:  -0.88 | Avg Steps: 158.1 | Loss: 0.0316
# [PPO] Ep 2268 | Avg Reward:  -0.84 | Avg Steps: 168.8 | Loss: 0.0226
# [PPO] Ep 2278 | Avg Reward:  -0.64 | Avg Steps: 208.9 | Loss: 0.0086
# [PPO] Ep 2284 | Avg Reward:  -0.52 | Avg Steps: 209.9 | Loss: 0.0149
# [PPO] Ep 2293 | Avg Reward:  -0.38 | Avg Steps: 255.0 | Loss: 0.0129
# [PPO] Ep 2302 | Avg Reward:  -0.28 | Avg Steps: 259.4 | Loss: 0.0059
# [PPO] Ep 2310 | Avg Reward:  -0.20 | Avg Steps: 266.1 | Loss: 0.0102
# [PPO] Ep 2322 | Avg Reward:  -0.16 | Avg Steps: 253.2 | Loss: 0.0229
# [PPO] Ep 2339 | Avg Reward:  -0.42 | Avg Steps: 232.7 | Loss: 0.0376
# [PPO] Ep 2342 | Avg Reward:  -0.42 | Avg Steps: 218.4 | Loss: -0.0063
# [PPO] Ep 2398 | Avg Reward:  -0.92 | Avg Steps: 100.4 | Loss: 0.0380
# [PPO] Ep 2402 | Avg Reward:  -0.92 | Avg Steps: 122.0 | Loss: 0.0222
# [PPO] Ep 2419 | Avg Reward:  -0.80 | Avg Steps: 177.8 | Loss: 0.0277
# [PPO] Ep 2431 | Avg Reward:  -0.74 | Avg Steps: 193.6 | Loss: 0.0115
# [PPO] Ep 2442 | Avg Reward:  -0.62 | Avg Steps: 243.4 | Loss: 0.0140
# [PPO] Ep 2448 | Avg Reward:  -0.49 | Avg Steps: 257.0 | Loss: 0.0017
# [PPO] Ep 2472 | Avg Reward:  -0.59 | Avg Steps: 229.6 | Loss: 0.0321
# [PPO] Ep 2483 | Avg Reward:  -0.59 | Avg Steps: 215.6 | Loss: 0.0222
# [PPO] Ep 2497 | Avg Reward:  -0.68 | Avg Steps: 191.4 | Loss: 0.0107
# [PPO] Ep 2503 | Avg Reward:  -0.64 | Avg Steps: 197.6 | Loss: 0.0106
# [PPO] Ep 2528 | Avg Reward:  -0.74 | Avg Steps: 216.4 | Loss: 0.0422
# [PPO] Ep 2533 | Avg Reward:  -0.74 | Avg Steps: 208.6 | Loss: 0.0334
# [PPO] Ep 2573 | Avg Reward:  -0.88 | Avg Steps: 160.9 | Loss: 0.0493
# [PPO] Ep 2579 | Avg Reward:  -0.88 | Avg Steps: 164.6 | Loss: 0.0200
# [PPO] Ep 2593 | Avg Reward:  -0.74 | Avg Steps: 207.9 | Loss: 0.0214
# [PPO] Ep 2604 | Avg Reward:  -0.70 | Avg Steps: 237.9 | Loss: 0.0192
# [PPO] Ep 2614 | Avg Reward:  -0.72 | Avg Steps: 256.3 | Loss: 0.0219
# [PPO] Ep 2623 | Avg Reward:  -0.62 | Avg Steps: 266.6 | Loss: 0.0202
# [PPO] Ep 2634 | Avg Reward:  -0.47 | Avg Steps: 271.7 | Loss: 0.0177
# [PPO] Ep 2643 | Avg Reward:  -0.49 | Avg Steps: 247.2 | Loss: 0.0072
# [PPO] Ep 2654 | Avg Reward:  -0.41 | Avg Steps: 251.9 | Loss: 0.0012
# [PPO] Ep 2662 | Avg Reward:  -0.35 | Avg Steps: 239.2 | Loss: 0.0072
# [PPO] Ep 2670 | Avg Reward:  -0.31 | Avg Steps: 240.5 | Loss: 0.0088
# [PPO] Ep 2681 | Avg Reward:  -0.30 | Avg Steps: 233.5 | Loss: 0.0146
# [PPO] Ep 2690 | Avg Reward:  -0.30 | Avg Steps: 240.2 | Loss: 0.0069
# [PPO] Ep 2697 | Avg Reward:  -0.28 | Avg Steps: 237.5 | Loss: 0.0094
# [PPO] Ep 2719 | Avg Reward:  -0.46 | Avg Steps: 209.4 | Loss: 0.0305
# [PPO] Ep 2726 | Avg Reward:  -0.44 | Avg Steps: 224.4 | Loss: 0.0129
# [PPO] Ep 2748 | Avg Reward:  -0.59 | Avg Steps: 203.1 | Loss: 0.0174
# [PPO] Ep 2757 | Avg Reward:  -0.48 | Avg Steps: 232.0 | Loss: 0.0068
# [PPO] Ep 2772 | Avg Reward:  -0.48 | Avg Steps: 227.8 | Loss: 0.0089
# [PPO] Ep 2782 | Avg Reward:  -0.44 | Avg Steps: 238.1 | Loss: -0.0025
# [PPO] Ep 2834 | Avg Reward:  -0.90 | Avg Steps: 118.9 | Loss: 0.0674
# [PPO] Ep 2842 | Avg Reward:  -0.83 | Avg Steps: 144.5 | Loss: 0.0239
# [PPO] Ep 2857 | Avg Reward:  -0.61 | Avg Steps: 203.3 | Loss: 0.0389
# [PPO] Ep 2870 | Avg Reward:  -0.38 | Avg Steps: 213.6 | Loss: 0.0363
# [PPO] Ep 2885 | Avg Reward:  -0.08 | Avg Steps: 243.8 | Loss: 0.0048
# [PPO] Ep 2896 | Avg Reward:  -0.04 | Avg Steps: 258.5 | Loss: 0.0136
# [PPO] Ep 2908 | Avg Reward:   0.06 | Avg Steps: 251.8 | Loss: 0.0116
# [PPO] Ep 2926 | Avg Reward:   0.06 | Avg Steps: 245.2 | Loss: 0.0261
# [PPO] Ep 2956 | Avg Reward:  -0.07 | Avg Steps: 167.5 | Loss: 0.0330
# [PPO] Ep 2981 | Avg Reward:   0.07 | Avg Steps: 143.9 | Loss: 0.0719
# [PPO] Ep 3000 | Avg Reward:   0.46 | Avg Steps: 132.3 | Loss: 0.0319
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ✅ Success
#
# [10/10] PPO with lr=0.0001, entropy=0.01, steps=500, epochs=16
#
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  563 | Avg Reward:  -1.00 | Avg Steps:  11.4 | Loss: 0.3921
# [PPO] Ep  897 | Avg Reward:  -1.00 | Avg Steps:  23.6 | Loss: 0.3627
# [PPO] Ep 1004 | Avg Reward:  -1.00 | Avg Steps:  93.5 | Loss: 0.4213
# [PPO] Ep 1033 | Avg Reward:  -1.00 | Avg Steps: 101.8 | Loss: 0.2074
# [PPO] Ep 1038 | Avg Reward:  -0.96 | Avg Steps: 124.0 | Loss: 0.0137
# [PPO] Ep 1134 | Avg Reward:  -1.00 | Avg Steps:  65.8 | Loss: 0.1206
# [PPO] Ep 1154 | Avg Reward:  -1.00 | Avg Steps: 126.7 | Loss: 0.0470
# [PPO] Ep 1163 | Avg Reward:  -0.98 | Avg Steps: 149.5 | Loss: 0.0053
# [PPO] Ep 1173 | Avg Reward:  -0.84 | Avg Steps: 197.6 | Loss: -0.0022
# [PPO] Ep 1184 | Avg Reward:  -0.72 | Avg Steps: 217.0 | Loss: -0.0056
# [PPO] Ep 1191 | Avg Reward:  -0.60 | Avg Steps: 247.1 | Loss: -0.0104
# [PPO] Ep 1204 | Avg Reward:  -0.42 | Avg Steps: 232.4 | Loss: 0.0152
# [PPO] Ep 1215 | Avg Reward:  -0.36 | Avg Steps: 231.8 | Loss: -0.0017
# [PPO] Ep 1228 | Avg Reward:  -0.38 | Avg Steps: 233.9 | Loss: -0.0081
# [PPO] Ep 1235 | Avg Reward:  -0.36 | Avg Steps: 242.0 | Loss: -0.0100
# [PPO] Ep 1248 | Avg Reward:  -0.38 | Avg Steps: 254.0 | Loss: -0.0174
# [PPO] Ep 1254 | Avg Reward:  -0.40 | Avg Steps: 254.4 | Loss: -0.0033
# [PPO] Ep 1267 | Avg Reward:  -0.38 | Avg Steps: 262.3 | Loss: -0.0158
# [PPO] Ep 1274 | Avg Reward:  -0.36 | Avg Steps: 257.9 | Loss: -0.0045
# [PPO] Ep 1286 | Avg Reward:  -0.25 | Avg Steps: 254.1 | Loss: -0.0237
# [PPO] Ep 1294 | Avg Reward:  -0.29 | Avg Steps: 249.4 | Loss: -0.0215
# [PPO] Ep 1304 | Avg Reward:  -0.25 | Avg Steps: 238.7 | Loss: -0.0265
# [PPO] Ep 1310 | Avg Reward:  -0.21 | Avg Steps: 250.8 | Loss: -0.0258
# [PPO] Ep 1320 | Avg Reward:  -0.15 | Avg Steps: 268.9 | Loss: -0.0188
# [PPO] Ep 1334 | Avg Reward:  -0.28 | Avg Steps: 250.0 | Loss: -0.0136
# [PPO] Ep 1346 | Avg Reward:  -0.36 | Avg Steps: 250.6 | Loss: -0.0119
# [PPO] Ep 1353 | Avg Reward:  -0.36 | Avg Steps: 231.7 | Loss: -0.0195
# [PPO] Ep 1364 | Avg Reward:  -0.38 | Avg Steps: 236.0 | Loss: -0.0237
# [PPO] Ep 1369 | Avg Reward:  -0.38 | Avg Steps: 227.8 | Loss: -0.0305
# [PPO] Ep 1384 | Avg Reward:  -0.34 | Avg Steps: 230.5 | Loss: -0.0175
# [PPO] Ep 1387 | Avg Reward:  -0.30 | Avg Steps: 238.4 | Loss: -0.0377
# [PPO] Ep 1420 | Avg Reward:  -0.64 | Avg Steps: 163.3 | Loss: -0.0150
# [PPO] Ep 1443 | Avg Reward:  -0.86 | Avg Steps: 149.3 | Loss: -0.0076
# [PPO] Ep 1459 | Avg Reward:  -0.92 | Avg Steps: 156.3 | Loss: -0.0369
# [PPO] Ep 1469 | Avg Reward:  -0.82 | Avg Steps: 174.2 | Loss: -0.0315
# [PPO] Ep 1490 | Avg Reward:  -0.67 | Avg Steps: 205.7 | Loss: -0.0357
# [PPO] Ep 1498 | Avg Reward:  -0.57 | Avg Steps: 216.0 | Loss: -0.0320
# [PPO] Ep 1514 | Avg Reward:  -0.59 | Avg Steps: 239.2 | Loss: -0.0323
# [PPO] Ep 1521 | Avg Reward:  -0.57 | Avg Steps: 244.2 | Loss: -0.0326
# [PPO] Ep 1588 | Avg Reward:  -0.96 | Avg Steps: 115.4 | Loss: 0.0052
# [PPO] Ep 1612 | Avg Reward:  -1.00 | Avg Steps: 128.5 | Loss: -0.0189
# [PPO] Ep 1624 | Avg Reward:  -0.87 | Avg Steps: 141.1 | Loss: -0.0347
# [PPO] Ep 1632 | Avg Reward:  -0.77 | Avg Steps: 159.0 | Loss: -0.0244
# [PPO] Ep 1646 | Avg Reward:  -0.66 | Avg Steps: 199.8 | Loss: -0.0273
# [PPO] Ep 1657 | Avg Reward:  -0.49 | Avg Steps: 212.5 | Loss: -0.0305
# [PPO] Ep 1684 | Avg Reward:  -0.67 | Avg Steps: 176.3 | Loss: -0.0307
# [PPO] Ep 1700 | Avg Reward:  -0.77 | Avg Steps: 137.2 | Loss: -0.0272
# [PPO] Ep 1712 | Avg Reward:  -0.72 | Avg Steps: 136.9 | Loss: -0.0494
# [PPO] Ep 1724 | Avg Reward:  -0.64 | Avg Steps: 136.1 | Loss: -0.0456
# [PPO] Ep 1736 | Avg Reward:  -0.48 | Avg Steps: 159.8 | Loss: -0.0626
# [PPO] Ep 1744 | Avg Reward:  -0.41 | Avg Steps: 193.1 | Loss: -0.0501
# [PPO] Ep 1763 | Avg Reward:  -0.47 | Avg Steps: 188.8 | Loss: -0.0384
# [PPO] Ep 1776 | Avg Reward:  -0.43 | Avg Steps: 232.8 | Loss: -0.0495
# [PPO] Ep 1786 | Avg Reward:  -0.47 | Avg Steps: 203.6 | Loss: -0.0432
# [PPO] Ep 1794 | Avg Reward:  -0.46 | Avg Steps: 192.7 | Loss: -0.0466
# [PPO] Ep 1812 | Avg Reward:  -0.40 | Avg Steps: 182.2 | Loss: -0.0549
# [PPO] Ep 1824 | Avg Reward:  -0.44 | Avg Steps: 164.3 | Loss: -0.0604
# [PPO] Ep 1833 | Avg Reward:  -0.46 | Avg Steps: 160.7 | Loss: -0.0459
# [PPO] Ep 1857 | Avg Reward:  -0.61 | Avg Steps: 156.7 | Loss: -0.0428
# [PPO] Ep 1867 | Avg Reward:  -0.50 | Avg Steps: 169.9 | Loss: -0.0513
# [PPO] Ep 1878 | Avg Reward:  -0.40 | Avg Steps: 166.1 | Loss: -0.0442
# [PPO] Ep 1907 | Avg Reward:  -0.38 | Avg Steps: 151.2 | Loss: -0.0151
# [PPO] Ep 1914 | Avg Reward:  -0.41 | Avg Steps: 167.0 | Loss: -0.0558
# [PPO] Ep 1936 | Avg Reward:  -0.40 | Avg Steps: 164.9 | Loss: -0.0371
# [PPO] Ep 1961 | Avg Reward:  -0.38 | Avg Steps: 161.4 | Loss: -0.0420
# [PPO] Ep 1981 | Avg Reward:  -0.31 | Avg Steps: 161.8 | Loss: -0.0236
# [PPO] Ep 1998 | Avg Reward:   0.01 | Avg Steps: 187.6 | Loss: -0.0428
# [PPO] Ep 2014 | Avg Reward:   0.20 | Avg Steps: 190.0 | Loss: -0.0454
# [PPO] Ep 2037 | Avg Reward:   0.10 | Avg Steps: 212.8 | Loss: -0.0438
# [PPO] Ep 2062 | Avg Reward:   0.11 | Avg Steps: 181.3 | Loss: -0.0424
# [PPO] Ep 2285 | Avg Reward:  -0.92 | Avg Steps:  31.8 | Loss: 0.0205
# [PPO] Ep 2373 | Avg Reward:  -0.85 | Avg Steps:  81.5 | Loss: 0.0392
# [PPO] Ep 2414 | Avg Reward:  -0.82 | Avg Steps: 102.8 | Loss: -0.0014
# [PPO] Ep 2435 | Avg Reward:  -0.57 | Avg Steps: 150.2 | Loss: -0.0437
# [PPO] Ep 2450 | Avg Reward:  -0.41 | Avg Steps: 191.4 | Loss: -0.0588
# [PPO] Ep 2467 | Avg Reward:  -0.19 | Avg Steps: 196.2 | Loss: -0.0455
# [PPO] Ep 2493 | Avg Reward:  -0.14 | Avg Steps: 181.1 | Loss: -0.0211
# [PPO] Ep 2506 | Avg Reward:  -0.19 | Avg Steps: 189.1 | Loss: -0.0175
# [PPO] Ep 2634 | Avg Reward:  -0.96 | Avg Steps:  50.4 | Loss: 0.0200
# [PPO] Ep 2692 | Avg Reward:  -0.85 | Avg Steps: 111.6 | Loss: -0.0009
# [PPO] Ep 2711 | Avg Reward:  -0.76 | Avg Steps: 144.2 | Loss: -0.0424
# [PPO] Ep 2724 | Avg Reward:  -0.66 | Avg Steps: 144.9 | Loss: -0.0583
# [PPO] Ep 2831 | Avg Reward:  -1.00 | Avg Steps:  46.4 | Loss: 0.0138
# [PPO] Ep 2882 | Avg Reward:  -0.65 | Avg Steps:  93.2 | Loss: -0.0059
# [PPO] Ep 2898 | Avg Reward:  -0.65 | Avg Steps: 129.6 | Loss: -0.0391
# [PPO] Ep 2910 | Avg Reward:  -0.43 | Avg Steps: 181.8 | Loss: -0.0379
# [PPO] Ep 2936 | Avg Reward:  -0.45 | Avg Steps: 218.4 | Loss: -0.0375
# [PPO] Ep 2943 | Avg Reward:  -0.40 | Avg Steps: 230.5 | Loss: -0.0617
# [PPO] Ep 2964 | Avg Reward:  -0.53 | Avg Steps: 202.1 | Loss: -0.0466
# [PPO] Ep 2980 | Avg Reward:  -0.65 | Avg Steps: 198.9 | Loss: -0.0493
# [PPO] Ep 2999 | Avg Reward:  -0.69 | Avg Steps: 198.2 | Loss: -0.0477
# [PPO] Ep 3000 | Avg Reward:  -0.69 | Avg Steps: 196.0 | Loss: 0.0856
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
# ✅ Success
#
# ============================================================
# Saved summary to ppo_runs_summary.csv
# ============================================================

# %%
ppo_logs = run_experiment('PPO',
                          env_name="MiniGrid-Dynamic-Obstacles-16x16-v0",
    num_episodes=5000,
    max_steps=500,      
    num_envs=16,        
    lr=3e-4,            
    update_epochs=4,    
    minibatch_size=64,  
    entropy_coef=0.0, 
)
# Out:
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  557 | Avg Reward:  -1.00 | Avg Steps:  14.9 | Loss: 0.4052
# [PPO] Ep  855 | Avg Reward:  -1.00 | Avg Steps:  35.6 | Loss: 0.4078
# [PPO] Ep  979 | Avg Reward:  -1.00 | Avg Steps:  56.1 | Loss: 0.4698
# [PPO] Ep 1057 | Avg Reward:  -1.00 | Avg Steps:  90.6 | Loss: 0.4196
# [PPO] Ep 1072 | Avg Reward:  -1.00 | Avg Steps: 107.1 | Loss: 0.1405
# [PPO] Ep 1094 | Avg Reward:  -0.92 | Avg Steps: 149.9 | Loss: 0.0538
# [PPO] Ep 1100 | Avg Reward:  -0.90 | Avg Steps: 167.8 | Loss: 0.0425
# [PPO] Ep 1121 | Avg Reward:  -0.76 | Avg Steps: 185.4 | Loss: 0.0448
# [PPO] Ep 1127 | Avg Reward:  -0.72 | Avg Steps: 191.7 | Loss: 0.0399
# [PPO] Ep 1164 | Avg Reward:  -0.80 | Avg Steps: 126.7 | Loss: 0.0475
# [PPO] Ep 1169 | Avg Reward:  -0.76 | Avg Steps: 120.5 | Loss: 0.0339
# [PPO] Ep 1180 | Avg Reward:  -0.58 | Avg Steps: 154.3 | Loss: 0.0135
# [PPO] Ep 1189 | Avg Reward:  -0.56 | Avg Steps: 161.5 | Loss: 0.0373
# [PPO] Ep 1233 | Avg Reward:  -0.79 | Avg Steps: 124.5 | Loss: 0.0775
# [PPO] Ep 1239 | Avg Reward:  -0.85 | Avg Steps: 137.0 | Loss: 0.0332
# [PPO] Ep 1255 | Avg Reward:  -0.76 | Avg Steps: 181.3 | Loss: 0.0359
# [PPO] Ep 1260 | Avg Reward:  -0.74 | Avg Steps: 190.8 | Loss: 0.0288
# [PPO] Ep 1275 | Avg Reward:  -0.74 | Avg Steps: 203.2 | Loss: 0.0322
# [PPO] Ep 1288 | Avg Reward:  -0.70 | Avg Steps: 199.0 | Loss: 0.0316
# [PPO] Ep 1299 | Avg Reward:  -0.65 | Avg Steps: 191.8 | Loss: 0.0283
# [PPO] Ep 1308 | Avg Reward:  -0.59 | Avg Steps: 175.4 | Loss: 0.0202
# [PPO] Ep 1330 | Avg Reward:  -0.59 | Avg Steps: 170.7 | Loss: 0.0312
# [PPO] Ep 1335 | Avg Reward:  -0.51 | Avg Steps: 179.0 | Loss: 0.0181
# [PPO] Ep 1357 | Avg Reward:  -0.57 | Avg Steps: 166.9 | Loss: 0.0212
# [PPO] Ep 1364 | Avg Reward:  -0.57 | Avg Steps: 183.2 | Loss: 0.0426
# [PPO] Ep 1381 | Avg Reward:  -0.56 | Avg Steps: 194.0 | Loss: 0.0170
# [PPO] Ep 1385 | Avg Reward:  -0.59 | Avg Steps: 185.2 | Loss: 0.0153
# [PPO] Ep 1409 | Avg Reward:  -0.60 | Avg Steps: 191.7 | Loss: 0.0228
# [PPO] Ep 1411 | Avg Reward:  -0.62 | Avg Steps: 186.1 | Loss: 0.0192
# [PPO] Ep 1429 | Avg Reward:  -0.60 | Avg Steps: 185.2 | Loss: 0.0258
# [PPO] Ep 1442 | Avg Reward:  -0.62 | Avg Steps: 187.4 | Loss: 0.0363
# [PPO] Ep 1457 | Avg Reward:  -0.56 | Avg Steps: 191.4 | Loss: 0.0301
# [PPO] Ep 1464 | Avg Reward:  -0.53 | Avg Steps: 198.0 | Loss: 0.0200
# [PPO] Ep 1480 | Avg Reward:  -0.49 | Avg Steps: 187.7 | Loss: 0.0275
# [PPO] Ep 1493 | Avg Reward:  -0.47 | Avg Steps: 207.3 | Loss: 0.0330
# [PPO] Ep 1501 | Avg Reward:  -0.49 | Avg Steps: 225.6 | Loss: 0.0209
# [PPO] Ep 1509 | Avg Reward:  -0.45 | Avg Steps: 237.3 | Loss: 0.0082
# [PPO] Ep 1519 | Avg Reward:  -0.44 | Avg Steps: 233.6 | Loss: 0.0158
# [PPO] Ep 1528 | Avg Reward:  -0.40 | Avg Steps: 234.2 | Loss: 0.0143
# [PPO] Ep 1540 | Avg Reward:  -0.46 | Avg Steps: 222.2 | Loss: 0.0108
# [PPO] Ep 1547 | Avg Reward:  -0.36 | Avg Steps: 222.7 | Loss: 0.0254
# [PPO] Ep 1557 | Avg Reward:  -0.34 | Avg Steps: 206.0 | Loss: 0.0146
# [PPO] Ep 1567 | Avg Reward:  -0.34 | Avg Steps: 218.1 | Loss: 0.0204
# [PPO] Ep 1585 | Avg Reward:  -0.35 | Avg Steps: 208.4 | Loss: 0.0434
# [PPO] Ep 1593 | Avg Reward:  -0.31 | Avg Steps: 208.2 | Loss: 0.0226
# [PPO] Ep 1631 | Avg Reward:  -0.73 | Avg Steps: 158.2 | Loss: 0.0659
# [PPO] Ep 1634 | Avg Reward:  -0.73 | Avg Steps: 149.6 | Loss: 0.0174
# [PPO] Ep 1655 | Avg Reward:  -0.86 | Avg Steps: 184.0 | Loss: 0.0330
# [PPO] Ep 1660 | Avg Reward:  -0.86 | Avg Steps: 178.4 | Loss: 0.0544
# [PPO] Ep 1683 | Avg Reward:  -0.80 | Avg Steps: 187.3 | Loss: 0.0452
# [PPO] Ep 1685 | Avg Reward:  -0.76 | Avg Steps: 187.1 | Loss: 0.0071
# [PPO] Ep 1719 | Avg Reward:  -0.78 | Avg Steps: 168.1 | Loss: 0.0572
# [PPO] Ep 1809 | Avg Reward:  -1.00 | Avg Steps:  80.1 | Loss: 0.1268
# [PPO] Ep 1824 | Avg Reward:  -0.98 | Avg Steps: 113.3 | Loss: 0.0545
# [PPO] Ep 1831 | Avg Reward:  -0.84 | Avg Steps: 146.5 | Loss: 0.0152
# [PPO] Ep 1838 | Avg Reward:  -0.72 | Avg Steps: 163.2 | Loss: 0.0001
# [PPO] Ep 1846 | Avg Reward:  -0.55 | Avg Steps: 200.0 | Loss: 0.0113
# [PPO] Ep 1858 | Avg Reward:  -0.39 | Avg Steps: 228.6 | Loss: 0.0267
# [PPO] Ep 1864 | Avg Reward:  -0.26 | Avg Steps: 252.4 | Loss: 0.0100
# [PPO] Ep 1880 | Avg Reward:  -0.22 | Avg Steps: 218.2 | Loss: 0.0235
# [PPO] Ep 1888 | Avg Reward:  -0.27 | Avg Steps: 208.4 | Loss: 0.0269
# [PPO] Ep 1899 | Avg Reward:  -0.38 | Avg Steps: 204.3 | Loss: 0.0078
# [PPO] Ep 1907 | Avg Reward:  -0.34 | Avg Steps: 197.2 | Loss: 0.0143
# [PPO] Ep 1916 | Avg Reward:  -0.35 | Avg Steps: 208.8 | Loss: 0.0074
# [PPO] Ep 1924 | Avg Reward:  -0.27 | Avg Steps: 219.9 | Loss: 0.0043
# [PPO] Ep 1936 | Avg Reward:  -0.30 | Avg Steps: 213.0 | Loss: 0.0191
# [PPO] Ep 1964 | Avg Reward:  -0.56 | Avg Steps: 150.6 | Loss: 0.0313
# [PPO] Ep 1975 | Avg Reward:  -0.68 | Avg Steps: 165.3 | Loss: 0.0176
# [PPO] Ep 1982 | Avg Reward:  -0.68 | Avg Steps: 155.2 | Loss: 0.0193
# [PPO] Ep 1993 | Avg Reward:  -0.62 | Avg Steps: 189.3 | Loss: 0.0344
# [PPO] Ep 2003 | Avg Reward:  -0.60 | Avg Steps: 195.6 | Loss: 0.0191
# [PPO] Ep 2012 | Avg Reward:  -0.41 | Avg Steps: 220.1 | Loss: 0.0155
# [PPO] Ep 2021 | Avg Reward:  -0.31 | Avg Steps: 218.0 | Loss: 0.0012
# [PPO] Ep 2032 | Avg Reward:  -0.28 | Avg Steps: 205.7 | Loss: 0.0199
# [PPO] Ep 2085 | Avg Reward:  -0.92 | Avg Steps:  89.0 | Loss: 0.0421
# [PPO] Ep 2092 | Avg Reward:  -0.85 | Avg Steps: 108.3 | Loss: 0.0240
# [PPO] Ep 2104 | Avg Reward:  -0.73 | Avg Steps: 155.1 | Loss: -0.0013
# [PPO] Ep 2118 | Avg Reward:  -0.52 | Avg Steps: 175.4 | Loss: 0.0325
# [PPO] Ep 2123 | Avg Reward:  -0.48 | Avg Steps: 185.2 | Loss: 0.0011
# [PPO] Ep 2140 | Avg Reward:  -0.39 | Avg Steps: 199.3 | Loss: 0.0186
# [PPO] Ep 2147 | Avg Reward:  -0.37 | Avg Steps: 207.6 | Loss: -0.0011
# [PPO] Ep 2157 | Avg Reward:  -0.37 | Avg Steps: 224.9 | Loss: 0.0087
# [PPO] Ep 2163 | Avg Reward:  -0.33 | Avg Steps: 237.0 | Loss: 0.0027
# [PPO] Ep 2179 | Avg Reward:  -0.39 | Avg Steps: 247.1 | Loss: 0.0357
# [PPO] Ep 2186 | Avg Reward:  -0.43 | Avg Steps: 263.1 | Loss: 0.0282
# [PPO] Ep 2204 | Avg Reward:  -0.44 | Avg Steps: 255.0 | Loss: 0.0270
# [PPO] Ep 2212 | Avg Reward:  -0.52 | Avg Steps: 239.6 | Loss: 0.0198
# [PPO] Ep 2236 | Avg Reward:  -0.66 | Avg Steps: 208.3 | Loss: 0.0440
# [PPO] Ep 2245 | Avg Reward:  -0.63 | Avg Steps: 223.7 | Loss: 0.0184
# [PPO] Ep 2266 | Avg Reward:  -0.70 | Avg Steps: 188.0 | Loss: 0.0346
# [PPO] Ep 2270 | Avg Reward:  -0.65 | Avg Steps: 189.8 | Loss: 0.0271
# [PPO] Ep 2288 | Avg Reward:  -0.57 | Avg Steps: 160.4 | Loss: 0.0202
# [PPO] Ep 2298 | Avg Reward:  -0.61 | Avg Steps: 160.7 | Loss: 0.0283
# [PPO] Ep 2322 | Avg Reward:  -0.55 | Avg Steps: 157.0 | Loss: 0.0070
# [PPO] Ep 2333 | Avg Reward:  -0.63 | Avg Steps: 167.1 | Loss: 0.0148
# [PPO] Ep 2354 | Avg Reward:  -0.74 | Avg Steps: 167.2 | Loss: 0.0266
# [PPO] Ep 2362 | Avg Reward:  -0.74 | Avg Steps: 175.2 | Loss: 0.0174
# [PPO] Ep 2381 | Avg Reward:  -0.61 | Avg Steps: 175.9 | Loss: 0.0227
# [PPO] Ep 2388 | Avg Reward:  -0.60 | Avg Steps: 189.6 | Loss: 0.0558
# [PPO] Ep 2398 | Avg Reward:  -0.46 | Avg Steps: 217.3 | Loss: 0.0032
# [PPO] Ep 2407 | Avg Reward:  -0.33 | Avg Steps: 228.1 | Loss: 0.0183
# [PPO] Ep 2418 | Avg Reward:  -0.22 | Avg Steps: 262.3 | Loss: -0.0077
# [PPO] Ep 2446 | Avg Reward:  -0.40 | Avg Steps: 181.5 | Loss: 0.0387
# [PPO] Ep 2465 | Avg Reward:  -0.65 | Avg Steps: 130.1 | Loss: 0.0217
# [PPO] Ep 2476 | Avg Reward:  -0.63 | Avg Steps: 141.9 | Loss: 0.0200
# [PPO] Ep 2491 | Avg Reward:  -0.64 | Avg Steps: 170.4 | Loss: 0.0060
# [PPO] Ep 2499 | Avg Reward:  -0.60 | Avg Steps: 165.5 | Loss: 0.0087
# [PPO] Ep 2515 | Avg Reward:  -0.48 | Avg Steps: 177.5 | Loss: 0.0277
# [PPO] Ep 2522 | Avg Reward:  -0.46 | Avg Steps: 190.5 | Loss: 0.0101
# [PPO] Ep 2531 | Avg Reward:  -0.40 | Avg Steps: 198.2 | Loss: 0.0024
# [PPO] Ep 2544 | Avg Reward:  -0.34 | Avg Steps: 190.6 | Loss: 0.0100
# [PPO] Ep 2551 | Avg Reward:  -0.32 | Avg Steps: 192.5 | Loss: 0.0005
# [PPO] Ep 2560 | Avg Reward:  -0.30 | Avg Steps: 192.9 | Loss: 0.0168
# [PPO] Ep 2569 | Avg Reward:  -0.26 | Avg Steps: 188.5 | Loss: 0.0078
# [PPO] Ep 2579 | Avg Reward:  -0.26 | Avg Steps: 173.5 | Loss: -0.0006
# [PPO] Ep 2589 | Avg Reward:  -0.26 | Avg Steps: 177.1 | Loss: 0.0019
# [PPO] Ep 2600 | Avg Reward:  -0.22 | Avg Steps: 177.0 | Loss: 0.0252
# [PPO] Ep 2609 | Avg Reward:  -0.28 | Avg Steps: 171.1 | Loss: 0.0068
# [PPO] Ep 2643 | Avg Reward:  -0.66 | Avg Steps: 146.1 | Loss: 0.0153
# [PPO] Ep 2645 | Avg Reward:  -0.66 | Avg Steps: 145.5 | Loss: 0.0083
# [PPO] Ep 2670 | Avg Reward:  -0.64 | Avg Steps: 172.0 | Loss: -0.0022
# [PPO] Ep 2676 | Avg Reward:  -0.66 | Avg Steps: 173.5 | Loss: 0.0695
# [PPO] Ep 2692 | Avg Reward:  -0.46 | Avg Steps: 195.8 | Loss: 0.0046
# [PPO] Ep 2697 | Avg Reward:  -0.46 | Avg Steps: 199.1 | Loss: 0.0125
# [PPO] Ep 2714 | Avg Reward:  -0.40 | Avg Steps: 234.9 | Loss: -0.0128
# [PPO] Ep 2721 | Avg Reward:  -0.40 | Avg Steps: 224.6 | Loss: 0.0277
# [PPO] Ep 2736 | Avg Reward:  -0.40 | Avg Steps: 249.2 | Loss: 0.0025
# [PPO] Ep 2750 | Avg Reward:  -0.46 | Avg Steps: 239.0 | Loss: 0.0240
# [PPO] Ep 2760 | Avg Reward:  -0.54 | Avg Steps: 216.9 | Loss: -0.0010
# [PPO] Ep 2773 | Avg Reward:  -0.54 | Avg Steps: 204.2 | Loss: 0.0044
# [PPO] Ep 2786 | Avg Reward:  -0.56 | Avg Steps: 188.3 | Loss: 0.0148
# [PPO] Ep 2798 | Avg Reward:  -0.54 | Avg Steps: 184.0 | Loss: 0.0145
# [PPO] Ep 2814 | Avg Reward:  -0.54 | Avg Steps: 184.6 | Loss: 0.0008
# [PPO] Ep 2822 | Avg Reward:  -0.48 | Avg Steps: 188.2 | Loss: 0.0085
# [PPO] Ep 2837 | Avg Reward:  -0.44 | Avg Steps: 190.5 | Loss: -0.0061
# [PPO] Ep 2852 | Avg Reward:  -0.50 | Avg Steps: 209.3 | Loss: 0.0131
# [PPO] Ep 2862 | Avg Reward:  -0.48 | Avg Steps: 206.0 | Loss: -0.0033
# [PPO] Ep 2872 | Avg Reward:  -0.52 | Avg Steps: 223.2 | Loss: 0.0013
# [PPO] Ep 2880 | Avg Reward:  -0.52 | Avg Steps: 228.8 | Loss: 0.0067
# [PPO] Ep 2890 | Avg Reward:  -0.42 | Avg Steps: 225.5 | Loss: -0.0032
# [PPO] Ep 2898 | Avg Reward:  -0.40 | Avg Steps: 219.4 | Loss: 0.0055
# [PPO] Ep 2910 | Avg Reward:  -0.32 | Avg Steps: 240.3 | Loss: 0.0105
# [PPO] Ep 2918 | Avg Reward:  -0.29 | Avg Steps: 229.4 | Loss: 0.0057
# [PPO] Ep 2932 | Avg Reward:  -0.33 | Avg Steps: 219.8 | Loss: 0.0096
# [PPO] Ep 2938 | Avg Reward:  -0.37 | Avg Steps: 211.5 | Loss: 0.0126
# [PPO] Ep 2950 | Avg Reward:  -0.37 | Avg Steps: 223.3 | Loss: 0.0209
# [PPO] Ep 2960 | Avg Reward:  -0.39 | Avg Steps: 206.7 | Loss: 0.0372
# [PPO] Ep 2969 | Avg Reward:  -0.38 | Avg Steps: 231.0 | Loss: -0.0000
# [PPO] Ep 2979 | Avg Reward:  -0.34 | Avg Steps: 254.4 | Loss: 0.0173
# [PPO] Ep 2985 | Avg Reward:  -0.28 | Avg Steps: 270.1 | Loss: -0.0113
# [PPO] Ep 2995 | Avg Reward:  -0.22 | Avg Steps: 291.0 | Loss: 0.0241
# [PPO] Ep 3001 | Avg Reward:  -0.20 | Avg Steps: 301.8 | Loss: 0.0087
# [PPO] Ep 3015 | Avg Reward:  -0.18 | Avg Steps: 321.8 | Loss: 0.0053
# [PPO] Ep 3018 | Avg Reward:  -0.18 | Avg Steps: 314.6 | Loss: 0.0290
# [PPO] Ep 3031 | Avg Reward:  -0.14 | Avg Steps: 320.9 | Loss: 0.0107
# [PPO] Ep 3036 | Avg Reward:  -0.18 | Avg Steps: 296.9 | Loss: 0.0089
# [PPO] Ep 3047 | Avg Reward:  -0.26 | Avg Steps: 288.7 | Loss: 0.0112
# [PPO] Ep 3055 | Avg Reward:  -0.23 | Avg Steps: 262.9 | Loss: 0.0380
# [PPO] Ep 3065 | Avg Reward:  -0.21 | Avg Steps: 243.9 | Loss: 0.0082
# [PPO] Ep 3074 | Avg Reward:  -0.17 | Avg Steps: 243.2 | Loss: 0.0330
# [PPO] Ep 3081 | Avg Reward:  -0.17 | Avg Steps: 225.3 | Loss: 0.0025
# [PPO] Ep 3090 | Avg Reward:  -0.07 | Avg Steps: 252.3 | Loss: 0.0148
# [PPO] Ep 3097 | Avg Reward:  -0.05 | Avg Steps: 239.6 | Loss: 0.0059
# [PPO] Ep 3110 | Avg Reward:  -0.09 | Avg Steps: 256.2 | Loss: 0.0497
# [PPO] Ep 3117 | Avg Reward:  -0.09 | Avg Steps: 265.4 | Loss: -0.0042
# [PPO] Ep 3126 | Avg Reward:  -0.11 | Avg Steps: 262.1 | Loss: 0.0371
# [PPO] Ep 3132 | Avg Reward:  -0.11 | Avg Steps: 244.1 | Loss: -0.0025
# [PPO] Ep 3145 | Avg Reward:  -0.17 | Avg Steps: 235.2 | Loss: 0.0103
# [PPO] Ep 3154 | Avg Reward:  -0.17 | Avg Steps: 224.4 | Loss: 0.0170
# [PPO] Ep 3169 | Avg Reward:  -0.07 | Avg Steps: 225.7 | Loss: 0.0460
# [PPO] Ep 3176 | Avg Reward:  -0.13 | Avg Steps: 224.3 | Loss: 0.0219
# [PPO] Ep 3186 | Avg Reward:  -0.15 | Avg Steps: 268.9 | Loss: 0.0082
# [PPO] Ep 3200 | Avg Reward:  -0.21 | Avg Steps: 266.7 | Loss: 0.0090
# [PPO] Ep 3209 | Avg Reward:  -0.18 | Avg Steps: 295.2 | Loss: -0.0019
# [PPO] Ep 3224 | Avg Reward:  -0.36 | Avg Steps: 249.2 | Loss: 0.0406
# [PPO] Ep 3232 | Avg Reward:  -0.36 | Avg Steps: 246.0 | Loss: 0.0079
# [PPO] Ep 3259 | Avg Reward:  -0.64 | Avg Steps: 166.9 | Loss: 0.0089
# [PPO] Ep 3265 | Avg Reward:  -0.61 | Avg Steps: 179.3 | Loss: 0.0325
# [PPO] Ep 3275 | Avg Reward:  -0.49 | Avg Steps: 180.6 | Loss: 0.0005
# [PPO] Ep 3285 | Avg Reward:  -0.53 | Avg Steps: 175.7 | Loss: 0.0587
# [PPO] Ep 3297 | Avg Reward:  -0.44 | Avg Steps: 198.3 | Loss: -0.0060
# [PPO] Ep 3310 | Avg Reward:  -0.40 | Avg Steps: 207.6 | Loss: 0.0713
# [PPO] Ep 3318 | Avg Reward:  -0.38 | Avg Steps: 213.9 | Loss: -0.0036
# [PPO] Ep 3332 | Avg Reward:  -0.41 | Avg Steps: 216.1 | Loss: 0.0168
# [PPO] Ep 3339 | Avg Reward:  -0.42 | Avg Steps: 215.7 | Loss: 0.0000
# [PPO] Ep 3363 | Avg Reward:  -0.54 | Avg Steps: 198.2 | Loss: 0.0361
# [PPO] Ep 3405 | Avg Reward:  -0.88 | Avg Steps: 101.7 | Loss: 0.0232
# [PPO] Ep 3422 | Avg Reward:  -0.85 | Avg Steps: 141.3 | Loss: 0.0262
# [PPO] Ep 3431 | Avg Reward:  -0.79 | Avg Steps: 170.8 | Loss: 0.0173
# [PPO] Ep 3440 | Avg Reward:  -0.67 | Avg Steps: 196.9 | Loss: 0.0261
# [PPO] Ep 3470 | Avg Reward:  -0.58 | Avg Steps: 192.1 | Loss: 0.0383
# [PPO] Ep 3480 | Avg Reward:  -0.62 | Avg Steps: 171.2 | Loss: 0.0348
# [PPO] Ep 3491 | Avg Reward:  -0.62 | Avg Steps: 174.2 | Loss: -0.0029
# [PPO] Ep 3524 | Avg Reward:  -0.74 | Avg Steps: 176.4 | Loss: 0.0246
# [PPO] Ep 3529 | Avg Reward:  -0.70 | Avg Steps: 189.6 | Loss: 0.0714
# [PPO] Ep 3555 | Avg Reward:  -0.80 | Avg Steps: 186.2 | Loss: 0.0439
# [PPO] Ep 3559 | Avg Reward:  -0.76 | Avg Steps: 184.8 | Loss: 0.0520
# [PPO] Ep 3574 | Avg Reward:  -0.60 | Avg Steps: 206.4 | Loss: 0.0331
# [PPO] Ep 3580 | Avg Reward:  -0.58 | Avg Steps: 192.8 | Loss: 0.0716
# [PPO] Ep 3610 | Avg Reward:  -0.70 | Avg Steps: 166.9 | Loss: 0.0692
# [PPO] Ep 3619 | Avg Reward:  -0.80 | Avg Steps: 170.8 | Loss: 0.0259
# [PPO] Ep 3637 | Avg Reward:  -0.76 | Avg Steps: 174.0 | Loss: 0.0269
# [PPO] Ep 3667 | Avg Reward:  -0.82 | Avg Steps: 154.5 | Loss: 0.0165
# [PPO] Ep 3687 | Avg Reward:  -0.92 | Avg Steps: 125.6 | Loss: 0.0173
# [PPO] Ep 3693 | Avg Reward:  -0.90 | Avg Steps: 147.4 | Loss: 0.0237
# [PPO] Ep 3714 | Avg Reward:  -0.74 | Avg Steps: 170.5 | Loss: 0.0248
# [PPO] Ep 3732 | Avg Reward:  -0.70 | Avg Steps: 177.8 | Loss: 0.0172
# [PPO] Ep 3788 | Avg Reward:  -0.96 | Avg Steps: 107.2 | Loss: 0.0538
# [PPO] Ep 3798 | Avg Reward:  -0.98 | Avg Steps: 132.4 | Loss: 0.0101
# [PPO] Ep 3839 | Avg Reward:  -0.96 | Avg Steps: 137.4 | Loss: 0.0421
# [PPO] Ep 3850 | Avg Reward:  -0.96 | Avg Steps: 154.7 | Loss: 0.0137
# [PPO] Ep 3860 | Avg Reward:  -0.88 | Avg Steps: 187.7 | Loss: 0.0082
# [PPO] Ep 3873 | Avg Reward:  -0.78 | Avg Steps: 206.6 | Loss: 0.0183
# [PPO] Ep 3885 | Avg Reward:  -0.70 | Avg Steps: 196.4 | Loss: 0.0098
# [PPO] Ep 3895 | Avg Reward:  -0.57 | Avg Steps: 222.8 | Loss: 0.0173
# [PPO] Ep 3913 | Avg Reward:  -0.57 | Avg Steps: 181.7 | Loss: 0.0111
# [PPO] Ep 3926 | Avg Reward:  -0.59 | Avg Steps: 189.0 | Loss: 0.0079
# [PPO] Ep 3939 | Avg Reward:  -0.59 | Avg Steps: 178.9 | Loss: 0.0179
# [PPO] Ep 3953 | Avg Reward:  -0.64 | Avg Steps: 211.3 | Loss: -0.0056
# [PPO] Ep 3961 | Avg Reward:  -0.60 | Avg Steps: 212.3 | Loss: 0.0050
# [PPO] Ep 3975 | Avg Reward:  -0.56 | Avg Steps: 231.7 | Loss: -0.0026
# [PPO] Ep 3988 | Avg Reward:  -0.58 | Avg Steps: 230.5 | Loss: 0.0033
# [PPO] Ep 4001 | Avg Reward:  -0.58 | Avg Steps: 221.1 | Loss: 0.0040
# [PPO] Ep 4012 | Avg Reward:  -0.58 | Avg Steps: 212.2 | Loss: 0.0020
# [PPO] Ep 4024 | Avg Reward:  -0.64 | Avg Steps: 192.6 | Loss: -0.0010
# [PPO] Ep 4036 | Avg Reward:  -0.64 | Avg Steps: 214.7 | Loss: 0.0031
# [PPO] Ep 4045 | Avg Reward:  -0.58 | Avg Steps: 222.1 | Loss: 0.0173
# [PPO] Ep 4065 | Avg Reward:  -0.66 | Avg Steps: 204.9 | Loss: 0.0089
# [PPO] Ep 4074 | Avg Reward:  -0.60 | Avg Steps: 188.1 | Loss: 0.0015
# [PPO] Ep 4091 | Avg Reward:  -0.68 | Avg Steps: 182.1 | Loss: 0.0136
# [PPO] Ep 4101 | Avg Reward:  -0.68 | Avg Steps: 186.9 | Loss: 0.0120
# [PPO] Ep 4126 | Avg Reward:  -0.76 | Avg Steps: 175.0 | Loss: 0.0055
# [PPO] Ep 4138 | Avg Reward:  -0.76 | Avg Steps: 169.9 | Loss: 0.0110
# [PPO] Ep 4160 | Avg Reward:  -0.76 | Avg Steps: 188.1 | Loss: 0.0194
# [PPO] Ep 4169 | Avg Reward:  -0.74 | Avg Steps: 207.0 | Loss: 0.0221
# [PPO] Ep 4188 | Avg Reward:  -0.70 | Avg Steps: 232.8 | Loss: 0.0132
# [PPO] Ep 4193 | Avg Reward:  -0.66 | Avg Steps: 248.0 | Loss: -0.0137
# [PPO] Ep 4204 | Avg Reward:  -0.56 | Avg Steps: 282.0 | Loss: -0.0017
# [PPO] Ep 4211 | Avg Reward:  -0.50 | Avg Steps: 265.0 | Loss: -0.0093
# [PPO] Ep 4233 | Avg Reward:  -0.50 | Avg Steps: 256.3 | Loss: 0.0129
# [PPO] Ep 4245 | Avg Reward:  -0.57 | Avg Steps: 238.5 | Loss: 0.0164
# [PPO] Ep 4264 | Avg Reward:  -0.71 | Avg Steps: 213.7 | Loss: 0.0119
# [PPO] Ep 4272 | Avg Reward:  -0.67 | Avg Steps: 238.2 | Loss: 0.0060
# [PPO] Ep 4352 | Avg Reward:  -0.94 | Avg Steps:  68.6 | Loss: 0.0152
# [PPO] Ep 4383 | Avg Reward:  -0.92 | Avg Steps:  82.8 | Loss: 0.0210
# [PPO] Ep 4396 | Avg Reward:  -0.92 | Avg Steps: 112.5 | Loss: 0.0058
# [PPO] Ep 4415 | Avg Reward:  -0.80 | Avg Steps: 164.3 | Loss: 0.0207
# [PPO] Ep 4430 | Avg Reward:  -0.80 | Avg Steps: 162.9 | Loss: 0.0030
# [PPO] Ep 4443 | Avg Reward:  -0.72 | Avg Steps: 176.9 | Loss: 0.0075
# [PPO] Ep 4457 | Avg Reward:  -0.68 | Avg Steps: 218.6 | Loss: 0.0036
# [PPO] Ep 4464 | Avg Reward:  -0.68 | Avg Steps: 200.1 | Loss: 0.0002
# [PPO] Ep 4478 | Avg Reward:  -0.54 | Avg Steps: 248.5 | Loss: 0.0250
# [PPO] Ep 4488 | Avg Reward:  -0.56 | Avg Steps: 247.4 | Loss: 0.0055
# [PPO] Ep 4502 | Avg Reward:  -0.56 | Avg Steps: 223.7 | Loss: 0.0213
# [PPO] Ep 4515 | Avg Reward:  -0.61 | Avg Steps: 210.6 | Loss: 0.0182
# [PPO] Ep 4535 | Avg Reward:  -0.69 | Avg Steps: 179.1 | Loss: 0.0237
# [PPO] Ep 4550 | Avg Reward:  -0.69 | Avg Steps: 189.4 | Loss: 0.0097
# [PPO] Ep 4572 | Avg Reward:  -0.83 | Avg Steps: 209.8 | Loss: 0.0251
# [PPO] Ep 4582 | Avg Reward:  -0.73 | Avg Steps: 215.9 | Loss: 0.0136
# [PPO] Ep 4596 | Avg Reward:  -0.61 | Avg Steps: 223.3 | Loss: 0.0140
# [PPO] Ep 4607 | Avg Reward:  -0.48 | Avg Steps: 213.1 | Loss: 0.0103
# [PPO] Ep 4625 | Avg Reward:  -0.36 | Avg Steps: 224.4 | Loss: 0.0188
# [PPO] Ep 4636 | Avg Reward:  -0.33 | Avg Steps: 233.9 | Loss: 0.0116
# [PPO] Ep 4656 | Avg Reward:  -0.48 | Avg Steps: 208.7 | Loss: 0.0191
# [PPO] Ep 4676 | Avg Reward:  -0.36 | Avg Steps: 183.9 | Loss: 0.0290
# [PPO] Ep 4699 | Avg Reward:  -0.20 | Avg Steps: 178.5 | Loss: 0.0374
# [PPO] Ep 4734 | Avg Reward:   0.11 | Avg Steps: 135.9 | Loss: 0.0815
# [PPO] Ep 4778 | Avg Reward:   0.48 | Avg Steps: 111.2 | Loss: 0.1069
# [PPO] Ep 4844 | Avg Reward:   0.57 | Avg Steps: 109.5 | Loss: 0.1386
# [PPO] Ep 4937 | Avg Reward:   0.76 | Avg Steps:  94.2 | Loss: 0.1818
# [PPO] Ep 5000 | Avg Reward:   0.86 | Avg Steps:  65.7 | Loss: 0.1976
#
# ============================================================
# TRAINING COMPLETED!
# ============================================================
#
# ============================================================
# PERFORMANCE SUMMARY - PPO
# ============================================================
# Final Performance (last 100 episodes):
#   Average Reward: 0.815
#   Average Steps: 72.3
#   Training Loss: 0.1988
#
# Best Performance:
#   Best 100-episode Average Reward: 0.817
#   Total Episodes: 5000
#   Total Training Steps: 135,296
# ============================================================
# Model exported to: models/16x16/ppo_model.pth

# %%
ppo_logs = run_experiment('PPO',
                          env_name="MiniGrid-Dynamic-Obstacles-16x16-v0",
    num_episodes=7500,
    max_steps=500,      
    num_envs=16,        
    lr=3e-4,            
    update_epochs=4,    
    minibatch_size=64,  
    entropy_coef=0.0, 
)
# Out:
# ============================================================
# TRAINING PPO ON MINIGRID-DYNAMIC-OBSTACLES-16X16-V0 WITH 16 ACTORS
# ============================================================
# [PPO] Ep  560 | Avg Reward:  -1.00 | Avg Steps:  14.3 | Loss: 0.3722
# [PPO] Ep  899 | Avg Reward:  -1.00 | Avg Steps:  24.4 | Loss: 0.3941
# [PPO] Ep 1058 | Avg Reward:  -1.00 | Avg Steps:  40.5 | Loss: 0.4465
# [PPO] Ep 1090 | Avg Reward:  -1.00 | Avg Steps: 109.2 | Loss: 0.4143
# [PPO] Ep 1114 | Avg Reward:  -0.98 | Avg Steps: 167.1 | Loss: 0.1408
# [PPO] Ep 1133 | Avg Reward:  -0.92 | Avg Steps: 189.9 | Loss: 0.0905
# [PPO] Ep 1140 | Avg Reward:  -0.88 | Avg Steps: 199.3 | Loss: 0.0552
# [PPO] Ep 1164 | Avg Reward:  -0.76 | Avg Steps: 197.3 | Loss: 0.0522
# [PPO] Ep 1176 | Avg Reward:  -0.74 | Avg Steps: 209.1 | Loss: 0.0986
# [PPO] Ep 1198 | Avg Reward:  -0.82 | Avg Steps: 174.0 | Loss: 0.0500
# [PPO] Ep 1206 | Avg Reward:  -0.78 | Avg Steps: 172.0 | Loss: 0.0905
# [PPO] Ep 1234 | Avg Reward:  -0.81 | Avg Steps: 160.9 | Loss: 0.0473
# [PPO] Ep 1245 | Avg Reward:  -0.77 | Avg Steps: 164.4 | Loss: 0.1158
# [PPO] Ep 1253 | Avg Reward:  -0.75 | Avg Steps: 161.0 | Loss: 0.0225
# [PPO] Ep 1264 | Avg Reward:  -0.63 | Avg Steps: 176.2 | Loss: 0.0250
# [PPO] Ep 1313 | Avg Reward:  -0.87 | Avg Steps:  84.9 | Loss: 0.0740
# [PPO] Ep 1321 | Avg Reward:  -0.91 | Avg Steps:  93.1 | Loss: 0.0588
# [PPO] Ep 1344 | Avg Reward:  -0.78 | Avg Steps: 118.0 | Loss: 0.0423
# [PPO] Ep 1348 | Avg Reward:  -0.70 | Avg Steps: 130.9 | Loss: 0.0147
# [PPO] Ep 1448 | Avg Reward:  -1.00 | Avg Steps:  67.9 | Loss: 0.0882
# [PPO] Ep 1469 | Avg Reward:  -1.00 | Avg Steps:  91.6 | Loss: 0.3871
# [PPO] Ep 1474 | Avg Reward:  -0.96 | Avg Steps: 113.8 | Loss: 0.0747
# [PPO] Ep 1623 | Avg Reward:  -1.00 | Avg Steps:  52.9 | Loss: 0.0966
# [PPO] Ep 1648 | Avg Reward:  -1.00 | Avg Steps:  85.9 | Loss: 0.3592
# [PPO] Ep 1655 | Avg Reward:  -0.98 | Avg Steps: 117.4 | Loss: 0.0268
# [PPO] Ep 1679 | Avg Reward:  -0.84 | Avg Steps: 133.7 | Loss: 0.0382
# [PPO] Ep 1684 | Avg Reward:  -0.74 | Avg Steps: 156.4 | Loss: 0.0111
# [PPO] Ep 1706 | Avg Reward:  -0.60 | Avg Steps: 110.4 | Loss: 0.0241
# [PPO] Ep 1724 | Avg Reward:  -0.58 | Avg Steps: 141.7 | Loss: 0.0466
# [PPO] Ep 1743 | Avg Reward:  -0.68 | Avg Steps: 144.1 | Loss: 0.0275
# [PPO] Ep 1757 | Avg Reward:  -0.66 | Avg Steps: 174.6 | Loss: 0.0399
# [PPO] Ep 1774 | Avg Reward:  -0.62 | Avg Steps: 178.1 | Loss: 0.0346
# [PPO] Ep 1782 | Avg Reward:  -0.64 | Avg Steps: 186.2 | Loss: 0.0380
# [PPO] Ep 1813 | Avg Reward:  -0.68 | Avg Steps: 187.4 | Loss: 0.0583
# [PPO] Ep 1823 | Avg Reward:  -0.74 | Avg Steps: 182.4 | Loss: 0.0362
# [PPO] Ep 1836 | Avg Reward:  -0.76 | Avg Steps: 183.3 | Loss: 0.0131
# [PPO] Ep 1868 | Avg Reward:  -0.80 | Avg Steps: 165.1 | Loss: 0.1181
# [PPO] Ep 1891 | Avg Reward:  -0.94 | Avg Steps: 139.6 | Loss: 0.0438
# [PPO] Ep 1901 | Avg Reward:  -0.88 | Avg Steps: 170.6 | Loss: 0.0497
# [PPO] Ep 1917 | Avg Reward:  -0.78 | Avg Steps: 167.6 | Loss: 0.0293
# [PPO] Ep 1933 | Avg Reward:  -0.72 | Avg Steps: 183.3 | Loss: 0.0370
# [PPO] Ep 1942 | Avg Reward:  -0.62 | Avg Steps: 175.5 | Loss: 0.0309
# [PPO] Ep 1964 | Avg Reward:  -0.68 | Avg Steps: 132.5 | Loss: 0.0591
# [PPO] Ep 1979 | Avg Reward:  -0.64 | Avg Steps: 131.3 | Loss: 0.0366
# [PPO] Ep 1991 | Avg Reward:  -0.60 | Avg Steps: 151.3 | Loss: 0.0142
# [PPO] Ep 2000 | Avg Reward:  -0.54 | Avg Steps: 167.1 | Loss: 0.0077
# [PPO] Ep 2010 | Avg Reward:  -0.44 | Avg Steps: 189.9 | Loss: 0.0057
# [PPO] Ep 2024 | Avg Reward:  -0.40 | Avg Steps: 202.4 | Loss: 0.0137
# [PPO] Ep 2037 | Avg Reward:  -0.38 | Avg Steps: 226.3 | Loss: 0.0130
# [PPO] Ep 2062 | Avg Reward:  -0.64 | Avg Steps: 196.2 | Loss: 0.0510
# [PPO] Ep 2065 | Avg Reward:  -0.60 | Avg Steps: 205.4 | Loss: 0.0081
