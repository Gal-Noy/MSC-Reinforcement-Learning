# %% [markdown]
# # Reinforcement Learning 2025 - Midterm Assignment
#
# **Authors:** Gal Yaacov Noy, Amit Ezer.
#
# **Goal:** Implement and compare SARSA and Double Q-Learning agents in a dynamic obstacle environment.

# %%
# !pip install xxhash minigrid gymnasium matplotlib
# Out:
# Requirement already satisfied: minigrid in ./.venv/lib/python3.10/site-packages (3.0.0)
# Requirement already satisfied: gymnasium in ./.venv/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: matplotlib in ./.venv/lib/python3.10/site-packages (3.10.3)
# Requirement already satisfied: numpy>=1.18.0 in ./.venv/lib/python3.10/site-packages (from minigrid) (2.2.6)
# Requirement already satisfied: pygame>=2.4.0 in ./.venv/lib/python3.10/site-packages (from minigrid) (2.6.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.venv/lib/python3.10/site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.venv/lib/python3.10/site-packages (from gymnasium) (4.14.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.venv/lib/python3.10/site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: fonttools>=4.22.0 in ./.venv/lib/python3.10/site-packages (from matplotlib) (4.58.5)
# Requirement already satisfied: contourpy>=1.0.1 in ./.venv/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: cycler>=0.10 in ./.venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in ./.venv/lib/python3.10/site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./.venv/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import os
import numpy as np
import gymnasium as gym
import itertools
import minigrid
import matplotlib.pyplot as plt
from collections import defaultdict
import pickle
import xxhash

np.random.seed(42)

# %%
def get_state(obs):
    """Convert observation to a hashable state key."""
    image = obs["image"].flatten()
    data = bytes([obs["direction"]]) + image.tobytes()
    return xxhash.xxh64(data).intdigest()

# %%
def init_q_table(env, random_init=False):
    """
    Initialize Q-table with zeros or random values.
    """
    if random_init:
        return defaultdict(lambda: np.random.uniform(0, 0.01, env.action_space.n))
    else:
        return defaultdict(lambda: np.zeros(env.action_space.n))

# %%
def get_reward(obs, reward, use_reward_shaping=False):
    """
    Returns the reward, optionally adding a bonus for proximity to the goal.
    """
    if use_reward_shaping:
        for i in range(7):
            for j in range(7):
                if obs["image"][i][j][0] == 8:  # Goal found
                    dist = abs(i - 3) + abs(j - 3)  # Manhattan distance from agent center
                    return reward + 1 / (dist + 1)  # Closer = higher bonus
    return reward

# %%
def epsilon_greedy_action(state, q_func, epsilon, action_space):
    """Select an action using an epsilon-greedy policy."""
    if np.random.rand() < epsilon:
        return action_space.sample()
    return int(np.argmax(q_func(state)))

def log_episode(logs, reward, steps, success):
    """Store training statistics for later analysis."""
    logs["rewards"].append(reward)
    logs["steps"].append(steps)
    logs["successes"].append(int(success))

# %%
def train_agent(
    env,
    agent_name,
    num_episodes=3000,
    alpha=0.1,
    gamma=0.99,
    epsilon_start=1.0,
    epsilon_min=0.05,
    epsilon_decay=0.995,
    random_q_init=False,
    use_reward_shaping=False,
):
    
    # Validate hyperparameters
    assert 0 < alpha <= 1, "Learning rate must be in (0, 1]"
    assert 0 <= gamma <= 1, "Discount factor must be in [0, 1]"
    assert 0 < epsilon_decay < 1, "Epsilon decay must be in (0, 1)"
    assert 0 <= epsilon_min <= epsilon_start <= 1, "Epsilon values must be valid"
    
    q1 = init_q_table(env, random_q_init)
    q2 = init_q_table(env, random_q_init) if agent_name == "Double Q-Learning" else None

    logs = {"rewards": [], "steps": [], "successes": []}
    epsilon = epsilon_start

    for episode in range(num_episodes):
        obs, _ = env.reset()
        state = get_state(obs)

        # Initial Q-function for action selection
        q_func = lambda s: q1[s] + q2[s] if q2 else q1[s]
        action = epsilon_greedy_action(state, q_func, epsilon, env.action_space)

        total_reward, steps = 0, 0
        terminated = truncated = False

        while not (terminated or truncated):
            next_obs, reward, terminated, truncated, _ = env.step(action)
            reward = get_reward(next_obs, reward, use_reward_shaping)
            next_state = get_state(next_obs)
            done = terminated or truncated
            total_reward += reward
            steps += 1

            if agent_name == "SARSA":
                next_action = epsilon_greedy_action(next_state, lambda s: q1[s], epsilon, env.action_space)
                td_target = reward + gamma * q1[next_state][next_action] * (not done)
                q1[state][action] += alpha * (td_target - q1[state][action])
                action = next_action

            else:  # Double Q-Learning
                use_q1 = np.random.rand() < 0.5
                q_main, q_other = (q1, q2) if use_q1 else (q2, q1)

                a_max = np.argmax(q_main[next_state])
                td_target = reward + gamma * q_other[next_state][a_max] * (not done)
                q_main[state][action] += alpha * (td_target - q_main[state][action])

                # Use combined Q1 + Q2 to select next action
                action = epsilon_greedy_action(next_state, lambda s: q1[s] + q2[s], epsilon, env.action_space)

            state = next_state

        epsilon = max(epsilon_min, epsilon * epsilon_decay)
        log_episode(logs, total_reward, steps, reward > 0)

        if episode % 100 == 0:
            print(f"[{agent_name}] Ep {episode} - reward: {total_reward:.2f}, steps: {steps}, success: {reward > 0}")

    return q1, q2, logs

# %%
def plot_results(sarsa_logs, dq_logs, window=100, title="Training Results"):
    """Plot training results."""
    def moving_average(data, window):
        return np.convolve(data, np.ones(window)/window, mode='valid')

    _, axs = plt.subplots(1, 3, figsize=(15, 4), sharex=False)
    plt.suptitle(title, fontsize=16)

    metrics = [
        ("rewards", "Average Reward", "Reward"),
        ("steps", "Episode Length", "Steps"),
        ("successes", "Success Rate", "Success Rate")
    ]

    for i, (metric, title_text, ylabel) in enumerate(metrics):
        axs[i].plot(moving_average(sarsa_logs[metric], window), label="SARSA", linewidth=2)
        axs[i].plot(moving_average(dq_logs[metric], window), label="Double Q-Learning", linewidth=2)
        axs[i].set_title(title_text)
        axs[i].set_ylabel(ylabel)
        axs[i].legend()
        axs[i].grid(alpha=0.3)
        if i == 1:  # Middle plot gets x-label
            axs[i].set_xlabel("Episode")

    plt.tight_layout()
    plt.show()

def print_performance_summary(sarsa_logs, dq_logs, mode_name):
    """Print performance summary for the current mode."""
    print(f"\n{'='*60}")
    print(f"PERFORMANCE SUMMARY - {mode_name.upper()}")
    print(f"{'='*60}")
    
    # Calculate metrics for both algorithms
    def get_metrics(logs):
        final_success = np.mean(logs["successes"][-100:]) * 100
        best_success = max([np.mean(logs["successes"][i:i+100]) * 100 
                           for i in range(len(logs["successes"])-99)])
        final_reward = np.mean(logs["rewards"][-100:])
        final_steps = np.mean(logs["steps"][-100:])
        return final_success, best_success, final_reward, final_steps
    
    sarsa_metrics = get_metrics(sarsa_logs)
    dq_metrics = get_metrics(dq_logs)
    
    # Print results
    for name, metrics in [("SARSA", sarsa_metrics), ("Double Q-Learning", dq_metrics)]:
        final_success, best_success, final_reward, final_steps = metrics
        print(f"{name} Results:")
        print(f"  Final Success Rate: {final_success:.1f}% | Best: {best_success:.1f}%")
        print(f"  Final Reward: {final_reward:.3f} | Final Steps: {final_steps:.1f}")
    
    # Winner determination
    winner = "SARSA" if sarsa_metrics[0] > dq_metrics[0] else "Double Q-Learning"
    margin = abs(sarsa_metrics[0] - dq_metrics[0])
    print(f"\nWinner: {winner} (by {margin:.1f}%)")
    print(f"{'='*60}")

def save_policies(sarsa_q, double_q1, double_q2, mode="baseline"):
    """
    Save Q-tables into a subfolder under 'policies/' named after the mode.
    For example: policies/baseline/sarsa_q.pkl
    """
    print(f"\nSaving Q-tables for mode: {mode}")
    
    folder = os.path.join("policies", mode)
    os.makedirs(folder, exist_ok=True)

    policies = {
        "sarsa_q": sarsa_q,
        "double_q1": double_q1,
        "double_q2": double_q2
    }

    for name, q_table in policies.items():
        path = os.path.join(folder, f"{name}.pkl")
        with open(path, 'wb') as f:
            pickle.dump(dict(q_table), f)
            
    print(f"Q-tables saved to: {folder}")

def run_experiment(env, config_name, **kwargs):
    """Run complete experiment: train both agents, analyze, plot, and save."""
    print(f"\n{'='*60}")
    print(f"RUNNING EXPERIMENT: {config_name.upper()}")
    print(f"{'='*60}")
    
    # Train both agents
    print("Training SARSA...")
    sarsa_q, _, sarsa_logs = train_agent(env, "SARSA", **kwargs)
    
    print("Training Double Q-Learning...")
    dq_q1, dq_q2, dq_logs = train_agent(env, "Double Q-Learning", **kwargs)
    
    # Analyze and visualize
    print_performance_summary(sarsa_logs, dq_logs, config_name)
    plot_results(sarsa_logs, dq_logs, title=config_name)
    
    # Save policies
    mode = config_name.lower().replace(" ", "_").replace("-", "_")
    save_policies(sarsa_q, dq_q1, dq_q2, mode)
    
    return sarsa_logs, dq_logs

# %%
# Run all experiments
env = gym.make("MiniGrid-Dynamic-Obstacles-6x6-v0")

# Experiment configurations
experiments = [
    ("Baseline", {}),
    ("Random Q-Init", {"random_q_init": True}),
    ("Random Q-Init + Reward Shaping", {"random_q_init": True, "use_reward_shaping": True})
]

# Store results for comparison
all_results = {}
for config_name, config_params in experiments:
    sarsa_logs, dq_logs = run_experiment(env, config_name, **config_params)
    all_results[config_name] = {"sarsa": sarsa_logs, "dq": dq_logs}

print("\n" + "="*80)
print("ALL EXPERIMENTS COMPLETED!")
print("="*80)
# Out:
# ============================================================
# RUNNING EXPERIMENT: BASELINE
# ============================================================
# Training SARSA...
# [SARSA] Ep 0 - reward: -1.00, steps: 10, success: False
# [SARSA] Ep 100 - reward: -1.00, steps: 8, success: False
# [SARSA] Ep 200 - reward: -1.00, steps: 10, success: False
# [SARSA] Ep 300 - reward: -1.00, steps: 137, success: False
# [SARSA] Ep 400 - reward: 0.00, steps: 144, success: False
# [SARSA] Ep 500 - reward: -1.00, steps: 93, success: False
# [SARSA] Ep 600 - reward: -1.00, steps: 3, success: False
# [SARSA] Ep 700 - reward: -1.00, steps: 5, success: False
# [SARSA] Ep 800 - reward: -1.00, steps: 68, success: False
# [SARSA] Ep 900 - reward: -1.00, steps: 2, success: False
# [SARSA] Ep 1000 - reward: -1.00, steps: 64, success: False
# [SARSA] Ep 1100 - reward: -1.00, steps: 66, success: False
# [SARSA] Ep 1200 - reward: 0.00, steps: 144, success: False
# [SARSA] Ep 1300 - reward: -1.00, steps: 17, success: False
# [SARSA] Ep 1400 - reward: 0.00, steps: 144, success: False
# [SARSA] Ep 1500 - reward: 0.00, steps: 144, success: False
# [SARSA] Ep 1600 - reward: 0.49, steps: 81, success: True
# [SARSA] Ep 1700 - reward: -1.00, steps: 34, success: False
# [SARSA] Ep 1800 - reward: -1.00, steps: 6, success: False
# [SARSA] Ep 1900 - reward: -1.00, steps: 6, success: False
# [SARSA] Ep 2000 - reward: 0.59, steps: 66, success: True
# [SARSA] Ep 2100 - reward: 0.30, steps: 112, success: True
# [SARSA] Ep 2200 - reward: 0.00, steps: 144, success: False
# [SARSA] Ep 2300 - reward: 0.64, steps: 58, success: True
# [SARSA] Ep 2400 - reward: 0.69, steps: 50, success: True
# [SARSA] Ep 2500 - reward: 0.69, steps: 49, success: True
# [SARSA] Ep 2600 - reward: 0.88, steps: 20, success: True
# [SARSA] Ep 2700 - reward: 0.88, steps: 20, success: True
# [SARSA] Ep 2800 - reward: 0.76, steps: 38, success: True
# [SARSA] Ep 2900 - reward: 0.68, steps: 51, success: True
# Training Double Q-Learning...
# [Double Q-Learning] Ep 0 - reward: -1.00, steps: 1, success: False
# [Double Q-Learning] Ep 100 - reward: -1.00, steps: 4, success: False
# [Double Q-Learning] Ep 200 - reward: -1.00, steps: 55, success: False
# [Double Q-Learning] Ep 300 - reward: -1.00, steps: 4, success: False
# [Double Q-Learning] Ep 400 - reward: -1.00, steps: 36, success: False
# [Double Q-Learning] Ep 500 - reward: -1.00, steps: 92, success: False
# [Double Q-Learning] Ep 600 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 700 - reward: -1.00, steps: 116, success: False
# [Double Q-Learning] Ep 800 - reward: -1.00, steps: 3, success: False
# [Double Q-Learning] Ep 900 - reward: -1.00, steps: 128, success: False
# [Double Q-Learning] Ep 1000 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 1100 - reward: -1.00, steps: 140, success: False
# [Double Q-Learning] Ep 1200 - reward: -1.00, steps: 27, success: False
# [Double Q-Learning] Ep 1300 - reward: -1.00, steps: 22, success: False
# [Double Q-Learning] Ep 1400 - reward: -1.00, steps: 106, success: False
# [Double Q-Learning] Ep 1500 - reward: -1.00, steps: 111, success: False
# [Double Q-Learning] Ep 1600 - reward: -1.00, steps: 3, success: False
# [Double Q-Learning] Ep 1700 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 1800 - reward: -1.00, steps: 30, success: False
# [Double Q-Learning] Ep 1900 - reward: -1.00, steps: 31, success: False
# [Double Q-Learning] Ep 2000 - reward: -1.00, steps: 82, success: False
# [Double Q-Learning] Ep 2100 - reward: -1.00, steps: 44, success: False
# [Double Q-Learning] Ep 2200 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 2300 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 2400 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 2500 - reward: -1.00, steps: 139, success: False
# [Double Q-Learning] Ep 2600 - reward: -1.00, steps: 43, success: False
# [Double Q-Learning] Ep 2700 - reward: -1.00, steps: 143, success: False
# [Double Q-Learning] Ep 2800 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 2900 - reward: -1.00, steps: 44, success: False
#
# ============================================================
# PERFORMANCE SUMMARY - BASELINE
# ============================================================
# SARSA Results:
#   Final Success Rate: 66.0% | Best: 71.0%
#   Final Reward: 0.128 | Final Steps: 49.4
# Double Q-Learning Results:
#   Final Success Rate: 0.0% | Best: 1.0%
#   Final Reward: -0.650 | Final Steps: 84.5
#
# Winner: SARSA (by 66.0%)
# ============================================================
# Saving Q-tables for mode: baseline
# Q-tables saved to: policies/baseline
#
# ============================================================
# RUNNING EXPERIMENT: RANDOM Q-INIT
# ============================================================
# Training SARSA...
# [SARSA] Ep 0 - reward: -1.00, steps: 3, success: False
# [SARSA] Ep 100 - reward: -1.00, steps: 7, success: False
# [SARSA] Ep 200 - reward: -1.00, steps: 10, success: False
# [SARSA] Ep 300 - reward: -1.00, steps: 22, success: False
# [SARSA] Ep 400 - reward: -1.00, steps: 11, success: False
# [SARSA] Ep 500 - reward: -1.00, steps: 6, success: False
# [SARSA] Ep 600 - reward: -1.00, steps: 77, success: False
# [SARSA] Ep 700 - reward: -1.00, steps: 18, success: False
# [SARSA] Ep 800 - reward: -1.00, steps: 95, success: False
# [SARSA] Ep 900 - reward: -1.00, steps: 7, success: False
# [SARSA] Ep 1000 - reward: -1.00, steps: 91, success: False
# [SARSA] Ep 1100 - reward: -1.00, steps: 35, success: False
# [SARSA] Ep 1200 - reward: 0.79, steps: 34, success: True
# [SARSA] Ep 1300 - reward: -1.00, steps: 47, success: False
# [SARSA] Ep 1400 - reward: -1.00, steps: 83, success: False
# [SARSA] Ep 1500 - reward: 0.86, steps: 23, success: True
# [SARSA] Ep 1600 - reward: 0.82, steps: 28, success: True
# [SARSA] Ep 1700 - reward: 0.88, steps: 20, success: True
# [SARSA] Ep 1800 - reward: -1.00, steps: 9, success: False
# [SARSA] Ep 1900 - reward: 0.72, steps: 44, success: True
# [SARSA] Ep 2000 - reward: 0.64, steps: 58, success: True
# [SARSA] Ep 2100 - reward: 0.72, steps: 45, success: True
# [SARSA] Ep 2200 - reward: 0.24, steps: 122, success: True
# [SARSA] Ep 2300 - reward: 0.00, steps: 144, success: False
# [SARSA] Ep 2400 - reward: -1.00, steps: 35, success: False
# [SARSA] Ep 2500 - reward: -1.00, steps: 20, success: False
# [SARSA] Ep 2600 - reward: 0.63, steps: 59, success: True
# [SARSA] Ep 2700 - reward: -1.00, steps: 15, success: False
# [SARSA] Ep 2800 - reward: -1.00, steps: 3, success: False
# [SARSA] Ep 2900 - reward: 0.76, steps: 38, success: True
# Training Double Q-Learning...
# [Double Q-Learning] Ep 0 - reward: -1.00, steps: 9, success: False
# [Double Q-Learning] Ep 100 - reward: -1.00, steps: 14, success: False
# [Double Q-Learning] Ep 200 - reward: -1.00, steps: 8, success: False
# [Double Q-Learning] Ep 300 - reward: -1.00, steps: 18, success: False
# [Double Q-Learning] Ep 400 - reward: -1.00, steps: 69, success: False
# [Double Q-Learning] Ep 500 - reward: -1.00, steps: 18, success: False
# [Double Q-Learning] Ep 600 - reward: -1.00, steps: 40, success: False
# [Double Q-Learning] Ep 700 - reward: -1.00, steps: 18, success: False
# [Double Q-Learning] Ep 800 - reward: -1.00, steps: 53, success: False
# [Double Q-Learning] Ep 900 - reward: -1.00, steps: 62, success: False
# [Double Q-Learning] Ep 1000 - reward: -1.00, steps: 18, success: False
# [Double Q-Learning] Ep 1100 - reward: -1.00, steps: 7, success: False
# [Double Q-Learning] Ep 1200 - reward: 0.72, steps: 45, success: True
# [Double Q-Learning] Ep 1300 - reward: -1.00, steps: 23, success: False
# [Double Q-Learning] Ep 1400 - reward: 0.68, steps: 52, success: True
# [Double Q-Learning] Ep 1500 - reward: 0.00, steps: 144, success: False
# [Double Q-Learning] Ep 1600 - reward: -1.00, steps: 123, success: False
# [Double Q-Learning] Ep 1700 - reward: 0.17, steps: 133, success: True
# [Double Q-Learning] Ep 1800 - reward: -1.00, steps: 107, success: False
# [Double Q-Learning] Ep 1900 - reward: 0.77, steps: 37, success: True
# [Double Q-Learning] Ep 2000 - reward: -1.00, steps: 39, success: False
# [Double Q-Learning] Ep 2100 - reward: -1.00, steps: 30, success: False
# [Double Q-Learning] Ep 2200 - reward: 0.62, steps: 61, success: True
# [Double Q-Learning] Ep 2300 - reward: 0.79, steps: 34, success: True
# [Double Q-Learning] Ep 2400 - reward: 0.55, steps: 72, success: True
# [Double Q-Learning] Ep 2500 - reward: 0.89, steps: 18, success: True
# [Double Q-Learning] Ep 2600 - reward: -1.00, steps: 18, success: False
# [Double Q-Learning] Ep 2700 - reward: 0.69, steps: 49, success: True
# [Double Q-Learning] Ep 2800 - reward: 0.47, steps: 84, success: True
# [Double Q-Learning] Ep 2900 - reward: -1.00, steps: 75, success: False
#
# ============================================================
# PERFORMANCE SUMMARY - RANDOM Q-INIT
# ============================================================
# SARSA Results:
#   Final Success Rate: 63.0% | Best: 72.0%
#   Final Reward: 0.058 | Final Steps: 45.3
# Double Q-Learning Results:
#   Final Success Rate: 55.0% | Best: 65.0%
#   Final Reward: -0.049 | Final Steps: 46.1
#
# Winner: SARSA (by 8.0%)
# ============================================================
# Saving Q-tables for mode: random_q_init
# Q-tables saved to: policies/random_q_init
#
# ============================================================
# RUNNING EXPERIMENT: RANDOM Q-INIT + REWARD SHAPING
# ============================================================
# Training SARSA...
# [SARSA] Ep 0 - reward: -0.55, steps: 6, success: False
# [SARSA] Ep 100 - reward: -0.55, steps: 2, success: False
# [SARSA] Ep 200 - reward: 0.93, steps: 11, success: False
# [SARSA] Ep 300 - reward: 8.61, steps: 40, success: False
# [SARSA] Ep 400 - reward: 13.60, steps: 84, success: False
# [SARSA] Ep 500 - reward: 1.77, steps: 13, success: False
# [SARSA] Ep 600 - reward: 10.98, steps: 43, success: True
# [SARSA] Ep 700 - reward: 4.94, steps: 37, success: False
# [SARSA] Ep 800 - reward: 4.07, steps: 29, success: False
# [SARSA] Ep 900 - reward: 3.53, steps: 30, success: False
# [SARSA] Ep 1000 - reward: 34.49, steps: 125, success: False
# [SARSA] Ep 1100 - reward: 20.72, steps: 105, success: False
# [SARSA] Ep 1200 - reward: 9.47, steps: 38, success: True
# [SARSA] Ep 1300 - reward: 12.29, steps: 46, success: True
# [SARSA] Ep 1400 - reward: 4.55, steps: 27, success: False
# [SARSA] Ep 1500 - reward: 13.89, steps: 82, success: False
# [SARSA] Ep 1600 - reward: 17.29, steps: 88, success: False
# [SARSA] Ep 1700 - reward: 6.55, steps: 41, success: False
# [SARSA] Ep 1800 - reward: 17.99, steps: 84, success: True
# [SARSA] Ep 1900 - reward: 9.44, steps: 41, success: False
# [SARSA] Ep 2000 - reward: 10.00, steps: 45, success: True
# [SARSA] Ep 2100 - reward: 16.17, steps: 55, success: True
# [SARSA] Ep 2200 - reward: 27.37, steps: 85, success: True
# [SARSA] Ep 2300 - reward: 15.39, steps: 66, success: True
# [SARSA] Ep 2400 - reward: 11.22, steps: 39, success: True
# [SARSA] Ep 2500 - reward: 28.56, steps: 101, success: True
# [SARSA] Ep 2600 - reward: 0.70, steps: 8, success: False
# [SARSA] Ep 2700 - reward: 11.30, steps: 46, success: True
# [SARSA] Ep 2800 - reward: 11.50, steps: 36, success: True
# [SARSA] Ep 2900 - reward: 32.35, steps: 144, success: True
# Training Double Q-Learning...
# [Double Q-Learning] Ep 0 - reward: 3.22, steps: 23, success: False
# [Double Q-Learning] Ep 100 - reward: 0.70, steps: 11, success: False
# [Double Q-Learning] Ep 200 - reward: 0.77, steps: 13, success: False
# [Double Q-Learning] Ep 300 - reward: -0.05, steps: 5, success: False
# [Double Q-Learning] Ep 400 - reward: 2.82, steps: 15, success: False
# [Double Q-Learning] Ep 500 - reward: 10.80, steps: 35, success: False
# [Double Q-Learning] Ep 600 - reward: 13.40, steps: 66, success: False
# [Double Q-Learning] Ep 700 - reward: 3.93, steps: 18, success: False
# [Double Q-Learning] Ep 800 - reward: 8.04, steps: 25, success: True
# [Double Q-Learning] Ep 900 - reward: 1.94, steps: 10, success: False
# [Double Q-Learning] Ep 1000 - reward: 11.51, steps: 46, success: True
# [Double Q-Learning] Ep 1100 - reward: 14.19, steps: 65, success: True
# [Double Q-Learning] Ep 1200 - reward: -0.25, steps: 6, success: False
# [Double Q-Learning] Ep 1300 - reward: -0.05, steps: 5, success: False
# [Double Q-Learning] Ep 1400 - reward: 17.76, steps: 57, success: True
# [Double Q-Learning] Ep 1500 - reward: 12.69, steps: 61, success: True
# [Double Q-Learning] Ep 1600 - reward: 12.88, steps: 46, success: True
# [Double Q-Learning] Ep 1700 - reward: 9.73, steps: 43, success: True
# [Double Q-Learning] Ep 1800 - reward: 4.53, steps: 16, success: True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 14
#      12 all_results = {}
#      13 for config_name, config_params in experiments:
# ---> 14     sarsa_logs, dq_logs = run_experiment(env, config_name, **config_params)
#      15     all_results[config_name] = {"sarsa": sarsa_logs, "dq": dq_logs}
#      17 print("\n" + "="*80)
#
# Cell In[10], line 93, in run_experiment(env, config_name, **kwargs)
#      90 sarsa_q, _, sarsa_logs = train_agent(env, "SARSA", **kwargs)
#      92 print("Training Double Q-Learning...")
# ---> 93 dq_q1, dq_q2, dq_logs = train_agent(env, "Double Q-Learning", **kwargs)
#      95 # Analyze and visualize
#      96 print_performance_summary(sarsa_logs, dq_logs, config_name)
#
# Cell In[9], line 38, in train_agent(env, agent_name, num_episodes, alpha, gamma, epsilon_start, epsilon_min, epsilon_decay, random_q_init, use_reward_shaping)
#      35 terminated = truncated = False
#      37 while not (terminated or truncated):
# ---> 38     next_obs, reward, terminated, truncated, _ = env.step(action)
#      39     reward = get_reward(next_obs, reward, use_reward_shaping)
#      40     next_state = get_state(next_obs)
#
# File ~/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/gymnasium/wrappers/common.py:393, in OrderEnforcing.step(self, action)
#     391 if not self._has_reset:
#     392     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# --> 393 return super().step(action)
#
# File ~/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/gymnasium/core.py:327, in Wrapper.step(self, action)
#     323 def step(
#     324     self, action: WrapperActType
#     325 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     326     """Uses the :meth:`step` of the :attr:`env` that can be overwritten to change the returned data."""
# --> 327     return self.env.step(action)
#
# File ~/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/gymnasium/wrappers/common.py:285, in PassiveEnvChecker.step(self, action)
#     283     return env_step_passive_checker(self.env, action)
#     284 else:
# --> 285     return self.env.step(action)
#
# File ~/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/minigrid/envs/dynamicobstacles.py:151, in DynamicObstaclesEnv.step(self, action)
#     148 top = tuple(map(add, old_pos, (-1, -1)))
#     150 try:
# --> 151     self.place_obj(
#     152         self.obstacles[i_obst], top=top, size=(3, 3), max_tries=100
#     153     )
#     154     self.grid.set(old_pos[0], old_pos[1], None)
#     155 except Exception:
#
# File ~/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/minigrid/minigrid_env.py:357, in MiniGridEnv.place_obj(self, obj, top, size, reject_fn, max_tries)
#     354     continue
#     356 # Don't place the object where the agent is
# --> 357 if np.array_equal(pos, self.agent_pos):
#     358     continue
#     360 # Check if there is a filtering criterion
#
# File ~/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/numpy/_core/numeric.py:2541, in array_equal(a1, a2, equal_nan)
#    2539     return False
#    2540 if not equal_nan:
# -> 2541     return builtins.bool((asanyarray(a1 == a2)).all())
#    2543 if a1 is a2:
#    2544     # nan will compare equal so an array will compare equal to itself.
#    2545     return True
#
# KeyboardInterrupt:

# %%
# Final Comprehensive Analysis
def plot_all_experiments_comparison(all_results):
    """Plot comparison across all experiment configurations."""
    fig, axes = plt.subplots(2, 3, figsize=(18, 10))
    fig.suptitle("Comprehensive Comparison Across All Experiments", fontsize=16, fontweight='bold')
    
    def moving_average(data, window=100):
        return np.convolve(data, np.ones(window)/window, mode='valid')
    
    colors = ['blue', 'green', 'red', 'orange']
    
    # Plot SARSA results
    for i, (config, color) in enumerate(zip(all_results.keys(), colors)):
        sarsa_logs = all_results[config]["sarsa"]
        
        # Success rate
        axes[0, 0].plot(moving_average(sarsa_logs["successes"]), 
                       label=config, color=color, linewidth=2)
        # Rewards
        axes[0, 1].plot(moving_average(sarsa_logs["rewards"]), 
                       label=config, color=color, linewidth=2)
        # Steps
        axes[0, 2].plot(moving_average(sarsa_logs["steps"]), 
                       label=config, color=color, linewidth=2)
    
    # Plot Double Q-Learning results
    for i, (config, color) in enumerate(zip(all_results.keys(), colors)):
        dq_logs = all_results[config]["dq"]
        
        # Success rate
        axes[1, 0].plot(moving_average(dq_logs["successes"]), 
                       label=config, color=color, linewidth=2)
        # Rewards
        axes[1, 1].plot(moving_average(dq_logs["rewards"]), 
                       label=config, color=color, linewidth=2)
        # Steps
        axes[1, 2].plot(moving_average(dq_logs["steps"]), 
                       label=config, color=color, linewidth=2)
    
    # Configure subplots
    titles = [["SARSA - Success Rate", "SARSA - Rewards", "SARSA - Steps"],
              ["Double Q-Learning - Success Rate", "Double Q-Learning - Rewards", "Double Q-Learning - Steps"]]
    
    for i in range(2):
        for j in range(3):
            axes[i, j].set_title(titles[i][j])
            axes[i, j].legend()
            axes[i, j].grid(alpha=0.3)
            axes[i, j].set_xlabel("Episode")
    
    plt.tight_layout()
    plt.show()
    
def final_performance_table(all_results):
    """Print a clean, left-aligned performance summary table."""
    headers = ["Configuration", "Algorithm", "Final Success %", "Best Success %", "Final Reward", "Final Steps"]
    col_widths = [32, 20, 17, 17, 17, 13]
    total_width = sum(col_widths)

    # Format headers (all left-aligned)
    header_fmt = "".join([f"{{:<{w}}}" for w in col_widths])
    row_fmt = (
        f"{{:<{col_widths[0]}}} "  # Configuration
        f"{{:<{col_widths[1]}}} "  # Algorithm
        f"{{:<{col_widths[2]}.1f}} "  # Final Success %
        f"{{:<{col_widths[3]}.1f}} "  # Best Success %
        f"{{:<{col_widths[4]}.3f}} "  # Final Reward
        f"{{:<{col_widths[5]}.1f}}"   # Final Steps
    )

    print("\n" + "=" * total_width)
    print("FINAL PERFORMANCE COMPARISON TABLE")
    print("=" * total_width)
    print(header_fmt.format(*headers))
    print("-" * total_width)

    best_configs = {}

    for config_name, results in all_results.items():
        for alg_name, alg_key in [("SARSA", "sarsa"), ("Double Q-Learning", "dq")]:
            logs = results[alg_key]
            final_success = np.mean(logs["successes"][-100:]) * 100
            best_success = max([
                np.mean(logs["successes"][i:i+100]) * 100
                for i in range(len(logs["successes"]) - 99)
            ])
            final_reward = np.mean(logs["rewards"][-100:])
            final_steps = np.mean(logs["steps"][-100:])

            print(row_fmt.format(
                config_name, alg_name, final_success, best_success, final_reward, final_steps
            ))

            best_configs[f"{config_name} + {alg_name}"] = final_success

    best_config = max(best_configs, key=best_configs.get)
    best_score = best_configs[best_config]

    print("-" * total_width)
    print(f"OVERALL BEST CONFIGURATION: {best_config} with {best_score:.1f}% success rate")
    print("=" * total_width)


# Run final analysis
plot_all_experiments_comparison(all_results)
final_performance_table(all_results)

# Save all results for future analysis
with open("experiment_results.pkl", "wb") as f:
    pickle.dump(all_results, f)

print("\nAll experiment results saved to 'experiment_results.pkl'")
print("Q-tables saved in 'policies/' directory")
print("\nExperiment complete!")
# Out:
# ====================================================================================================================
# FINAL PERFORMANCE COMPARISON TABLE
# ====================================================================================================================
# Configuration                   Algorithm           Final Success %  Best Success %   Final Reward     Final Steps
# --------------------------------------------------------------------------------------------------------------------
# Baseline                         SARSA                69.0              75.0              0.178             43.2
# Baseline                         Double Q-Learning    0.0               0.0               -0.700            80.1
# Random Q-Init                    SARSA                68.0              75.0              0.191             42.3
# Random Q-Init                    Double Q-Learning    59.0              63.0              0.021             46.2
# Random Q-Init + Reward Shaping   SARSA                54.0              78.0              10.668            41.5
# Random Q-Init + Reward Shaping   Double Q-Learning    61.0              76.0              10.521            42.4
# --------------------------------------------------------------------------------------------------------------------
# OVERALL BEST CONFIGURATION: Baseline + SARSA with 69.0% success rate
# ====================================================================================================================
#
# All experiment results saved to 'experiment_results.pkl'
# Q-tables saved in 'policies/' directory
#
# Experiment complete!

# %% [markdown]
# ## Final Experiment: Best Configuration on 8x8 Environment
#
# Now we'll test the best-performing configuration from our experiments on a larger, more challenging 8x8 environment to evaluate how well our learning scales.

# %%
env = gym.make("MiniGrid-Dynamic-Obstacles-8x8-v0")

# Train SARSA and Double Q-Learning on the 8x8 environment
sarsa_logs, dq_logs = run_experiment(env, "8x8 Dynamic Obstacles", num_episodes=10000, alpha=0.05, epsilon_decay=0.998, random_q_init=True, use_reward_shaping=True)
# Out:
# ============================================================
# RUNNING EXPERIMENT: 8X8 DYNAMIC OBSTACLES
# ============================================================
# Training SARSA...
# [SARSA] Ep 0 - reward: -1.00, steps: 2, success: False
# [SARSA] Ep 100 - reward: -1.00, steps: 5, success: False
# [SARSA] Ep 200 - reward: -0.18, steps: 36, success: False
# [SARSA] Ep 300 - reward: -1.00, steps: 2, success: False
# [SARSA] Ep 400 - reward: -1.00, steps: 19, success: False
# [SARSA] Ep 500 - reward: -1.00, steps: 13, success: False
# [SARSA] Ep 600 - reward: -0.35, steps: 20, success: False
# [SARSA] Ep 700 - reward: 0.07, steps: 14, success: False
# [SARSA] Ep 800 - reward: -0.30, steps: 20, success: False
# [SARSA] Ep 900 - reward: -1.00, steps: 9, success: False
# [SARSA] Ep 1000 - reward: -1.00, steps: 4, success: False
# [SARSA] Ep 1100 - reward: 2.42, steps: 59, success: False
# [SARSA] Ep 1200 - reward: 10.44, steps: 51, success: False
# [SARSA] Ep 1300 - reward: 0.62, steps: 31, success: False
# [SARSA] Ep 1400 - reward: -1.00, steps: 1, success: False
# [SARSA] Ep 1500 - reward: -1.00, steps: 26, success: False
# [SARSA] Ep 1600 - reward: 5.01, steps: 49, success: False
# [SARSA] Ep 1700 - reward: -1.00, steps: 8, success: False
# [SARSA] Ep 1800 - reward: -1.00, steps: 3, success: False
# [SARSA] Ep 1900 - reward: 0.15, steps: 25, success: False
# [SARSA] Ep 2000 - reward: -0.43, steps: 15, success: False
# [SARSA] Ep 2100 - reward: 2.28, steps: 59, success: False
# [SARSA] Ep 2200 - reward: 22.21, steps: 106, success: False
# [SARSA] Ep 2300 - reward: -1.00, steps: 2, success: False
# [SARSA] Ep 2400 - reward: 4.13, steps: 62, success: False
# [SARSA] Ep 2500 - reward: 0.32, steps: 29, success: False
# [SARSA] Ep 2600 - reward: 0.78, steps: 54, success: False
# [SARSA] Ep 2700 - reward: 7.70, steps: 96, success: False
# [SARSA] Ep 2800 - reward: 1.88, steps: 22, success: False
# [SARSA] Ep 2900 - reward: 18.02, steps: 162, success: False
# [SARSA] Ep 3000 - reward: 1.83, steps: 45, success: False
# [SARSA] Ep 3100 - reward: 5.40, steps: 44, success: False
# [SARSA] Ep 3200 - reward: 5.49, steps: 57, success: False
# [SARSA] Ep 3300 - reward: 8.00, steps: 42, success: False
# [SARSA] Ep 3400 - reward: -0.13, steps: 15, success: False
# [SARSA] Ep 3500 - reward: 9.70, steps: 43, success: True
# [SARSA] Ep 3600 - reward: 1.20, steps: 36, success: False
# [SARSA] Ep 3700 - reward: 0.57, steps: 36, success: False
# [SARSA] Ep 3800 - reward: 6.39, steps: 40, success: False
# [SARSA] Ep 3900 - reward: 4.42, steps: 35, success: False
# [SARSA] Ep 4000 - reward: -0.63, steps: 19, success: False
# [SARSA] Ep 4100 - reward: 1.88, steps: 56, success: False
# [SARSA] Ep 4200 - reward: -1.00, steps: 18, success: False
# [SARSA] Ep 4300 - reward: -0.22, steps: 8, success: False
# [SARSA] Ep 4400 - reward: 9.24, steps: 60, success: True
# [SARSA] Ep 4500 - reward: 0.82, steps: 39, success: False
# [SARSA] Ep 4600 - reward: -1.00, steps: 5, success: False
# [SARSA] Ep 4700 - reward: 7.85, steps: 42, success: False
# [SARSA] Ep 4800 - reward: -1.00, steps: 3, success: False
# [SARSA] Ep 4900 - reward: 8.96, steps: 75, success: True
# [SARSA] Ep 5000 - reward: 1.23, steps: 32, success: False
# [SARSA] Ep 5100 - reward: 2.75, steps: 45, success: False
# [SARSA] Ep 5200 - reward: -0.30, steps: 18, success: False
# [SARSA] Ep 5300 - reward: 0.23, steps: 19, success: False
# [SARSA] Ep 5400 - reward: 14.82, steps: 90, success: True
# [SARSA] Ep 5500 - reward: -0.35, steps: 31, success: False
# [SARSA] Ep 5600 - reward: -0.47, steps: 13, success: False
# [SARSA] Ep 5700 - reward: -0.60, steps: 35, success: False
# [SARSA] Ep 5800 - reward: 1.93, steps: 60, success: False
# [SARSA] Ep 5900 - reward: 0.22, steps: 38, success: False
# [SARSA] Ep 6000 - reward: -1.00, steps: 10, success: False
# [SARSA] Ep 6100 - reward: 14.08, steps: 138, success: False
# [SARSA] Ep 6200 - reward: -1.00, steps: 11, success: False
# [SARSA] Ep 6300 - reward: 0.82, steps: 37, success: False
# [SARSA] Ep 6400 - reward: 0.45, steps: 21, success: False
# [SARSA] Ep 6500 - reward: 10.16, steps: 50, success: False
# [SARSA] Ep 6600 - reward: 14.10, steps: 78, success: False
# [SARSA] Ep 6700 - reward: 1.22, steps: 31, success: False
# [SARSA] Ep 6800 - reward: 1.15, steps: 31, success: False
# [SARSA] Ep 6900 - reward: 7.88, steps: 67, success: False
# [SARSA] Ep 7000 - reward: 2.53, steps: 58, success: False
# [SARSA] Ep 7100 - reward: 17.67, steps: 82, success: False
# [SARSA] Ep 7200 - reward: 2.10, steps: 52, success: False
# [SARSA] Ep 7300 - reward: 1.20, steps: 36, success: False
# [SARSA] Ep 7400 - reward: 1.23, steps: 29, success: False
# [SARSA] Ep 7500 - reward: -1.00, steps: 9, success: False
# [SARSA] Ep 7600 - reward: -0.05, steps: 13, success: False
# [SARSA] Ep 7700 - reward: 0.05, steps: 23, success: False
# [SARSA] Ep 7800 - reward: 3.00, steps: 39, success: False
# [SARSA] Ep 7900 - reward: 7.14, steps: 61, success: False
# [SARSA] Ep 8000 - reward: -1.00, steps: 13, success: False
# [SARSA] Ep 8100 - reward: 2.67, steps: 46, success: False
# [SARSA] Ep 8200 - reward: -1.00, steps: 3, success: False
# [SARSA] Ep 8300 - reward: -0.63, steps: 16, success: False
# [SARSA] Ep 8400 - reward: 1.81, steps: 27, success: False
# [SARSA] Ep 8500 - reward: 3.43, steps: 41, success: False
# [SARSA] Ep 8600 - reward: -1.00, steps: 5, success: False
# [SARSA] Ep 8700 - reward: 15.56, steps: 108, success: True
# [SARSA] Ep 8800 - reward: -1.00, steps: 2, success: False
# [SARSA] Ep 8900 - reward: 3.41, steps: 27, success: False
# [SARSA] Ep 9000 - reward: 1.73, steps: 36, success: False
# [SARSA] Ep 9100 - reward: 4.80, steps: 44, success: False
# [SARSA] Ep 9200 - reward: 1.37, steps: 16, success: False
# [SARSA] Ep 9300 - reward: 9.22, steps: 61, success: True
# [SARSA] Ep 9400 - reward: 11.77, steps: 98, success: False
# [SARSA] Ep 9500 - reward: 1.60, steps: 26, success: False
# [SARSA] Ep 9600 - reward: 0.68, steps: 26, success: False
# [SARSA] Ep 9700 - reward: 4.57, steps: 52, success: False
# [SARSA] Ep 9800 - reward: 2.90, steps: 38, success: False
# [SARSA] Ep 9900 - reward: 11.60, steps: 97, success: True
# Training Double Q-Learning...
# [Double Q-Learning] Ep 0 - reward: -1.00, steps: 5, success: False
# [Double Q-Learning] Ep 100 - reward: 2.22, steps: 29, success: False
# [Double Q-Learning] Ep 200 - reward: -1.00, steps: 4, success: False
# [Double Q-Learning] Ep 300 - reward: -1.00, steps: 9, success: False
# [Double Q-Learning] Ep 400 - reward: 3.15, steps: 55, success: False
# [Double Q-Learning] Ep 500 - reward: -1.00, steps: 8, success: False
# [Double Q-Learning] Ep 600 - reward: 2.43, steps: 89, success: False
# [Double Q-Learning] Ep 700 - reward: -0.47, steps: 6, success: False
# [Double Q-Learning] Ep 800 - reward: -1.00, steps: 7, success: False
# [Double Q-Learning] Ep 900 - reward: -1.00, steps: 8, success: False
# [Double Q-Learning] Ep 1000 - reward: -0.17, steps: 39, success: False
# [Double Q-Learning] Ep 1100 - reward: 4.35, steps: 61, success: True
# [Double Q-Learning] Ep 1200 - reward: 0.15, steps: 29, success: False
# [Double Q-Learning] Ep 1300 - reward: 1.58, steps: 42, success: False
# [Double Q-Learning] Ep 1400 - reward: -1.00, steps: 3, success: False
# [Double Q-Learning] Ep 1500 - reward: -0.30, steps: 41, success: False
# [Double Q-Learning] Ep 1600 - reward: -0.18, steps: 13, success: False
# [Double Q-Learning] Ep 1700 - reward: -1.00, steps: 6, success: False
# [Double Q-Learning] Ep 1800 - reward: 0.55, steps: 32, success: False
# [Double Q-Learning] Ep 1900 - reward: 0.37, steps: 26, success: False
# [Double Q-Learning] Ep 2000 - reward: 8.50, steps: 99, success: False
# [Double Q-Learning] Ep 2100 - reward: -1.00, steps: 11, success: False
# [Double Q-Learning] Ep 2200 - reward: 1.23, steps: 29, success: False
# [Double Q-Learning] Ep 2300 - reward: -1.00, steps: 14, success: False
# [Double Q-Learning] Ep 2400 - reward: 0.67, steps: 18, success: False
# [Double Q-Learning] Ep 2500 - reward: -1.00, steps: 25, success: False
# [Double Q-Learning] Ep 2600 - reward: 4.87, steps: 84, success: False
# [Double Q-Learning] Ep 2700 - reward: 2.75, steps: 50, success: False
# [Double Q-Learning] Ep 2800 - reward: -1.00, steps: 12, success: False
# [Double Q-Learning] Ep 2900 - reward: -1.00, steps: 3, success: False
# [Double Q-Learning] Ep 3000 - reward: 1.25, steps: 27, success: False
# [Double Q-Learning] Ep 3100 - reward: -0.18, steps: 24, success: False
# [Double Q-Learning] Ep 3200 - reward: -1.00, steps: 8, success: False
# [Double Q-Learning] Ep 3300 - reward: -1.00, steps: 13, success: False
# [Double Q-Learning] Ep 3400 - reward: 1.73, steps: 43, success: False
# [Double Q-Learning] Ep 3500 - reward: 7.35, steps: 100, success: False
# [Double Q-Learning] Ep 3600 - reward: 3.02, steps: 42, success: False
# [Double Q-Learning] Ep 3700 - reward: 3.53, steps: 54, success: False
# [Double Q-Learning] Ep 3800 - reward: 0.82, steps: 43, success: False
# [Double Q-Learning] Ep 3900 - reward: 6.40, steps: 94, success: False
# [Double Q-Learning] Ep 4000 - reward: -1.00, steps: 7, success: False
# [Double Q-Learning] Ep 4100 - reward: 20.02, steps: 83, success: True
# [Double Q-Learning] Ep 4200 - reward: 0.60, steps: 25, success: False
# [Double Q-Learning] Ep 4300 - reward: 3.08, steps: 44, success: False
# [Double Q-Learning] Ep 4400 - reward: 3.84, steps: 31, success: False
# [Double Q-Learning] Ep 4500 - reward: -0.47, steps: 8, success: False
# [Double Q-Learning] Ep 4600 - reward: 10.37, steps: 39, success: True
# [Double Q-Learning] Ep 4700 - reward: -0.05, steps: 20, success: False
# [Double Q-Learning] Ep 4800 - reward: -1.00, steps: 12, success: False
# [Double Q-Learning] Ep 4900 - reward: 6.97, steps: 67, success: False
# [Double Q-Learning] Ep 5000 - reward: -0.30, steps: 17, success: False
# [Double Q-Learning] Ep 5100 - reward: -0.17, steps: 15, success: False
# [Double Q-Learning] Ep 5200 - reward: 2.28, steps: 63, success: False
# [Double Q-Learning] Ep 5300 - reward: 0.12, steps: 24, success: False
# [Double Q-Learning] Ep 5400 - reward: 4.81, steps: 34, success: True
# [Double Q-Learning] Ep 5500 - reward: -1.00, steps: 10, success: False
# [Double Q-Learning] Ep 5600 - reward: -1.00, steps: 46, success: False
# [Double Q-Learning] Ep 5700 - reward: 0.15, steps: 22, success: False
# [Double Q-Learning] Ep 5800 - reward: -1.00, steps: 6, success: False
# [Double Q-Learning] Ep 5900 - reward: -0.38, steps: 28, success: False
# [Double Q-Learning] Ep 6000 - reward: 7.90, steps: 48, success: True
# [Double Q-Learning] Ep 6100 - reward: 13.90, steps: 188, success: False
# [Double Q-Learning] Ep 6200 - reward: -0.15, steps: 19, success: False
# [Double Q-Learning] Ep 6300 - reward: -0.22, steps: 30, success: False
# [Double Q-Learning] Ep 6400 - reward: 7.92, steps: 60, success: False
# [Double Q-Learning] Ep 6500 - reward: 5.57, steps: 66, success: False
# [Double Q-Learning] Ep 6600 - reward: 2.32, steps: 41, success: False
# [Double Q-Learning] Ep 6700 - reward: 1.02, steps: 28, success: False
# [Double Q-Learning] Ep 6800 - reward: 12.97, steps: 136, success: True
# [Double Q-Learning] Ep 6900 - reward: 8.33, steps: 106, success: False
# [Double Q-Learning] Ep 7000 - reward: 0.27, steps: 39, success: False
# [Double Q-Learning] Ep 7100 - reward: 13.13, steps: 104, success: True
# [Double Q-Learning] Ep 7200 - reward: 0.58, steps: 28, success: False
# [Double Q-Learning] Ep 7300 - reward: -1.00, steps: 5, success: False
# [Double Q-Learning] Ep 7400 - reward: 6.67, steps: 47, success: True
# [Double Q-Learning] Ep 7500 - reward: 6.29, steps: 51, success: True
# [Double Q-Learning] Ep 7600 - reward: 4.20, steps: 78, success: False
# [Double Q-Learning] Ep 7700 - reward: 6.76, steps: 40, success: True
# [Double Q-Learning] Ep 7800 - reward: 14.75, steps: 137, success: False
# [Double Q-Learning] Ep 7900 - reward: -1.00, steps: 10, success: False
# [Double Q-Learning] Ep 8000 - reward: 6.04, steps: 54, success: True
# [Double Q-Learning] Ep 8100 - reward: 4.93, steps: 68, success: False
# [Double Q-Learning] Ep 8200 - reward: -1.00, steps: 13, success: False
# [Double Q-Learning] Ep 8300 - reward: 1.25, steps: 35, success: False
# [Double Q-Learning] Ep 8400 - reward: 2.92, steps: 51, success: False
# [Double Q-Learning] Ep 8500 - reward: 1.42, steps: 33, success: False
# [Double Q-Learning] Ep 8600 - reward: 0.95, steps: 38, success: False
# [Double Q-Learning] Ep 8700 - reward: 7.38, steps: 102, success: False
# [Double Q-Learning] Ep 8800 - reward: -1.00, steps: 5, success: False
# [Double Q-Learning] Ep 8900 - reward: -1.00, steps: 22, success: False
# [Double Q-Learning] Ep 9000 - reward: 6.78, steps: 55, success: False
# [Double Q-Learning] Ep 9100 - reward: 6.33, steps: 199, success: False
# [Double Q-Learning] Ep 9200 - reward: 7.80, steps: 48, success: True
# [Double Q-Learning] Ep 9300 - reward: 6.45, steps: 80, success: True
# [Double Q-Learning] Ep 9400 - reward: 0.77, steps: 22, success: False
# [Double Q-Learning] Ep 9500 - reward: 4.03, steps: 41, success: False
# [Double Q-Learning] Ep 9600 - reward: -0.05, steps: 25, success: False
# [Double Q-Learning] Ep 9700 - reward: 0.27, steps: 38, success: False
# [Double Q-Learning] Ep 9800 - reward: 10.97, steps: 69, success: False
# [Double Q-Learning] Ep 9900 - reward: 16.15, steps: 82, success: True
#
# ============================================================
# PERFORMANCE SUMMARY - 8X8 DYNAMIC OBSTACLES
# ============================================================
# SARSA Results:
#   Final Success Rate: 26.0% | Best: 34.0%
#   Final Reward: 4.104 | Final Steps: 40.9
# Double Q-Learning Results:
#   Final Success Rate: 22.0% | Best: 32.0%
#   Final Reward: 3.803 | Final Steps: 43.3
#
# Winner: SARSA (by 4.0%)
# ============================================================
# Saving Q-tables for mode: 8x8_dynamic_obstacles
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7fa5d2fd63b0>>
# Traceback (most recent call last):
#   File "/home/galnoy/git-projects/MSC-Reinforcement-Learning/.venv/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
